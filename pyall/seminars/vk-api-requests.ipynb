# %% [markdown]
# ## Работа с запросами к API ВКонтакте средствами библиотеки `requests`
#
# *Алла Тамбовцева, НИУ ВШЭ*

# %% [markdown]
# ### Введение в API ВКонтакте

# %% [markdown]
# Сегодня мы немного поработаем с API. API – программный интерфейс приложения, сокращение от *Application Programming Interface*. Этот интерфейс позволяет выполнять различные операции автоматически, через приложение. Если API нам нужен исключительно как источник данных, можно писать запросы, позволяющие обратиться к хранилищу информации внутри API. Если мы хотим управлять приложением, которое будет выполнять какие-то действия, удаленно, можно написать код, который будет, например, автоматически отвечать на сообщения, когда мы не онлайн, лайкать новый пост друга через 30 секунд после его появления, пересылать на почту фотографии, которые выложили участники диалога и прочее.
#
# Мы будем работать с API социальной сети ВКонтакте. Использовать API для написания и приема сообщений средствами Python мы не будем, а рассмотрим API как источник данных, позволяющий выгрузить данные о пользователи или посты со страницы сообщества.

# %% [markdown]
# Для работы нам понадобятся две библиотеки: библиотека `requests` для формирования запросов, и библиотека `pandas` для преобразования словаря, который мы получим на основе JSON-файла, в удобный для работы датафрейм.

# %%
import requests
import pandas as pd

# %% [markdown]
# Посмотрим на документацию API ВКонтакте и познакомимся с запросами:
#
# https://vk.com/dev.php?method=api_requests

# %% [markdown]
# Если мы посмотрим на пример запроса, увидим, что он представляет собой особого вида ссылку:
#
# `https://api.vk.com/method/METHOD_NAME?PARAMETERS&access_token=ACCESS_TOKEN&v=V`
#
# В этой ссылке мы указываем:
#
# * метод (`METHOD_NAME`): какого вида запрос хотим сделать;
# * параметры запроса (`PARAMETERS`): какие данные хотим получить;
# * токен доступа (`ACCESS_TOKEN`): токен доступа;
# * версия API (`V`): к какой версии API обращаемся (есть в документации методов).

# %% [markdown]
# Другими словами, запрос – это обычная строка, которую мы можем сформировать, вставить в адресную строку в браузере и получить результат! Однако, чтобы на наш запрос получить ответ, нужно иметь доступ к API. Иногда API бывают совсем открытыми, но чаще всего, необходимо запрашивать доступ (без доступа можно обойтись, но тогда функционал будет сильно ограничен, и мы не сможем получать содержательную информацию).
#
# **Для получения токена доступа:**
#
# 1. Создать приложение ВКонтакте (пройти по ссылке). Дать название, выбрать *Standalone-приложение*.
# 2. Включить приложение, сделать публичным (*Настройки - Состояние и выбрать в выпадающем меню Приложение включено и видно всем*).
# 3. Авторизоваться: скопировать строку ниже в браузер, в `client id` вместо 1 выставить id своего приложения (первая строка в настроках ‒ ID приложения). Если не хочется ни в чем ограничивать свое приложение, можно оставить `scope=all` (у приложения будет доступ ко всему, к чему есть доступ у пользователя).
#
#     `https://oauth.vk.com/authorize?client_id=1&display=page&redirect_uri=http://oauth.vk.com/blank.html&scope=all&response_type=token`
#
#     Скопировать `access token` из обновленной адресной строки (все после `access_token=` и до `&expires_in`, без `&`). Никому не показывать! По этому токену можно получить доступ ко всему аккаунту.

# %% [markdown]
# Итак, теперь попробуем сохранить в переменные название метода, параметры, токен доступа и версию API.

# %% [markdown]
# ### Пример 1: информация о пользователях

# %% [markdown]
# Мы попробуем получить информацию о пользователе по его имени (*screen_name*), которое мы видим в ссылке на его страницу. Для этого нам потребуется метод `users.get` (см. весь перечень методов [здесь](https://vk.com/dev/methods)), параметр `user_ids` для указания id или имени пользователя и версия 5.103 (взята из документации по методу `users.get`).

# %%
METHOD_NAME = "users.get"
PARAMETERS = "user_ids=allatamb"  # enter some id or screen name
ACCESS_TOKEN = "edc29623d7eb58cbedd013376922275dde535d1ec4944fc953527a17b5fdd10cb868ae0f0c7d1d9a4fe77" # enter token
V = "5.103"

# %% [markdown]
# Формируем запрос – подставляем в шаблон запроса (ссылка, которую мы видели в самом начале) значения переменных выше. Удобнее всего это сделать через f-строки:

# %%
request = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"

# %% [markdown]
# Если бы мы не пользовались Python (что неудобно, но технически возможно), мы бы скопировали ссылку выше в адресную строку браузера и посмотрели на результат:

# %%
print(request)
# Out:
# https://api.vk.com/method/users.get?user_ids=allatamb&access_token=edc29623d7eb58cbedd013376922275dde535d1ec4944fc953527a17b5fdd10cb868ae0f0c7d1d9a4fe77&v=5.103

# %% [markdown]
# Но мы поступим иначе – отправим запрос с помощью функции `get()` из библиотеки `requests` (как раньше подставляли в эту функцию ссылку на страницу, которую хотели парсить с помощью BeautifulSoup):

# %%
response = requests.get(request)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Теперь посмотрим на содержимое ответа (*contents*):

# %%
response_str = response.content
print(response_str) # байтовая строка
# Out:
# b'{"response":[{"id":20473269,"first_name":"\xd0\x90\xd0\xbb\xd0\xbb\xd0\xb0","last_name":"\xd0\xa2\xd0\xb0\xd0\xbc\xd0\xb1\xd0\xbe\xd0\xb2\xd1\x86\xd0\xb5\xd0\xb2\xd0\xb0","is_closed":false,"can_access_closed":true}]}'

# %% [markdown]
# Содержимое ответа – это JSON-файл, что расшифровывается как *JavaScript Object Notation*. Изначально этот формат хранения данных использовался в языке JavaScript, но теперь он потерял привязку к конкретному языку программирования и стал универсальным. *Object* здесь можно понимать как некоторую структуру хранения данных (список, кортеж, словарь), которая записывается в специальном виде, внешне напоминающим обычную строку.
#
# Выгрузим из `response` json-файл:

# %%
data = response.json()
data
# Out:
# {'response': [{'id': 20473269,
#    'first_name': 'Алла',
#    'last_name': 'Тамбовцева',
#    'is_closed': False,
#    'can_access_closed': True}]}

# %% [markdown]
# Несложно заметить, что мы получили обычный словарь. Выберем из него запись с ключом *response*, поскольку именно там хранятся все данные:

# %%
print(data["response"])
# Out:
# [{'id': 20473269, 'first_name': 'Алла', 'last_name': 'Тамбовцева', 'is_closed': False, 'can_access_closed': True}]

# %% [markdown]
# Получили список из одного элемента. Его можно извлечь:

# %%
print(data["response"][0])
# Out:
# {'id': 20473269, 'first_name': 'Алла', 'last_name': 'Тамбовцева', 'is_closed': False, 'can_access_closed': True}

# %% [markdown]
# Теперь можем вызывать из полученного словаря записи по ключам:

# %%
data["response"][0]["last_name"]
# Out:
# 'Тамбовцева'

# %% [markdown]
# При желании можем преобразовать словарь в датафрейм pandas, но давайте сделаем это для более объемного примера – выберем сразу несколько пользователей и больше полей с данными:

# %%
users = ["allatamb", "navasilyonok"]  # список строк
users_all = ",".join(users)  # объединяем в одну строку по запятой
print(users_all)
# Out:
# allatamb,navasilyonok

# %%
fields = ["bdate", "city", "universities"]
fields_all = ",".join(fields)
print(fields_all)
# Out:
# bdate,city,universities

# %%
METHOD_NAME = "users.get"
PARAMETERS = "user_ids=" + users_all + '&' + 'fields=' + fields_all

# %%
request = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"

# %%
response = requests.get(request)
data = response.json() 
data
# Out:
# {'response': [{'id': 20473269,
#    'first_name': 'Алла',
#    'last_name': 'Тамбовцева',
#    'is_closed': False,
#    'can_access_closed': True,
#    'bdate': '25.3.1994',
#    'city': {'id': 1, 'title': 'Москва'},
#    'universities': [{'id': 128,
#      'country': 1,
#      'city': 1,
#      'name': 'НИУ ВШЭ (ГУ-ВШЭ)',
#      'graduation': 2016,
#      'education_status': 'Студентка (бакалавр)'}]},
#   {'id': 171544496,
#    'first_name': 'Наталья',
#    'last_name': 'Василёнок',
#    'is_closed': False,
#    'can_access_closed': True,
#    'bdate': '21.7.1996',
#    'city': {'id': 1, 'title': 'Москва'},
#    'universities': [{'id': 128,
#      'country': 1,
#      'city': 1,
#      'name': 'НИУ ВШЭ (ГУ-ВШЭ)',
#      'faculty': 475,
#      'faculty_name': 'Факультет социальных наук',
#      'chair': 2037672,
#      'chair_name': 'Политология',
#      'graduation': 2017,
#      'education_form': 'Очное отделение',
#      'education_status': 'Студентка (бакалавр)'}]}]}

# %%
df = pd.DataFrame(data['response'])
df
# Out:
#           id first_name   last_name  is_closed  can_access_closed      bdate  \
# 0   20473269       Алла  Тамбовцева      False               True  25.3.1994
# 1  171544496    Наталья   Василёнок      False               True  21.7.1996
#
#                            city  \
# 0  {'id': 1, 'title': 'Москва'}
# 1  {'id': 1, 'title': 'Москва'}
#
#                                         universities
# 0  [{'id': 128, 'country': 1, 'city': 1, 'name': ...
# 1  [{'id': 128, 'country': 1, 'city': 1, 'name': ...

# %%
def get_univ(x):
    try:
        y = x[0]["name"]
    except:
        y = None
    return y

# %%
df["City"] = df["city"].apply(lambda x: x["title"]) 
#df['Univ'] = df["universities"].apply(lambda x: x[0]["name"]) 
#df["Year"] = df["universities"].apply(lambda x: x[0]["graduation"]) 

df['Univ'] = df["universities"].apply(get_univ)

# %%
df
# Out:
#           id first_name   last_name  is_closed  can_access_closed      bdate  \
# 0   20473269       Алла  Тамбовцева      False               True  25.3.1994
# 1  171544496    Наталья   Василёнок      False               True  21.7.1996
#
#                            city  \
# 0  {'id': 1, 'title': 'Москва'}
# 1  {'id': 1, 'title': 'Москва'}
#
#                                         universities    City  \
# 0  [{'id': 128, 'country': 1, 'city': 1, 'name': ...  Москва
# 1  [{'id': 128, 'country': 1, 'city': 1, 'name': ...  Москва
#
#                Univ  Year
# 0  НИУ ВШЭ (ГУ-ВШЭ)  2016
# 1  НИУ ВШЭ (ГУ-ВШЭ)  2017

# %% [markdown]
# ### Пример 2:  список друзей

# %%
### Ваш код, маэстро
METHOD_NAME = "users.get"
PARAMETERS = "user_ids=allatamb"  # enter some id or screen name
ACCESS_TOKEN = "edc29623d7eb58cbedd013376922275dde535d1ec4944fc953527a17b5fdd10cb868ae0f0c7d1d9a4fe77" # enter token here
V = "5.103"

request = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"
resp1 = requests.get(request)
data1 = resp1.json()
data1['response'][0]['id']
# Out:
# 20473269

# %%
METHOD_NAME = "friends.get"
PARAMETERS = "user_ids=20473269"
request2 = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"
resp2 = requests.get(request2)
data2 = resp2.json()

# %%
friends = data2['response']['items']  
friends = [str(i) for i in friends]

# %%
friends_all = ",".join(friends)
METHOD_NAME = "users.get"
PARAMETERS = "user_ids=" + friends_all
request3 = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"

# %%
resp3 = requests.get(request3)
data3 = resp3.json()
data3
# Out:
# {'response': [{'id': 97723,
#    'first_name': 'Валерий',
#    'last_name': 'Окунев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 130896,
#    'first_name': 'Егор',
#    'last_name': 'Юрескул',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 251877,
#    'first_name': 'Антон',
#    'last_name': 'Воробьев',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 822104,
#    'first_name': 'Любовь',
#    'last_name': 'Сысоева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 995866,
#    'first_name': 'Антон',
#    'last_name': 'Клименков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 1438878,
#    'first_name': 'Dmitry',
#    'last_name': 'Ekhilevskiy',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 1494733,
#    'first_name': 'Маша',
#    'last_name': 'Пономарева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 1512070,
#    'first_name': 'Виталий',
#    'last_name': 'Пивиков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 1720064,
#    'first_name': 'Ольга',
#    'last_name': 'Гаспарян',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 2118571,
#    'first_name': 'Рита',
#    'last_name': 'Камалова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 2159411,
#    'first_name': 'Вера',
#    'last_name': 'Абелинскайте',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 2263688,
#    'first_name': 'Владимир',
#    'last_name': 'Булкин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 2266846,
#    'first_name': 'Елизавета',
#    'last_name': 'Калашникова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 2312977,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 2955860,
#    'first_name': 'Арина',
#    'last_name': 'Русских',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 3210136,
#    'first_name': 'Алла',
#    'last_name': 'Тамбовцева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 3466063,
#    'first_name': 'Мишаня',
#    'last_name': 'Аникин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 3990163,
#    'first_name': 'Андрей',
#    'last_name': 'Савельев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 4137582,
#    'first_name': 'Кирилл',
#    'last_name': 'Репьев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 4161834,
#    'first_name': 'Роман',
#    'last_name': 'Киселёв-Август',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 4479771,
#    'first_name': 'Дарья',
#    'last_name': 'Шершнева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 4528978,
#    'first_name': 'Елизавета',
#    'last_name': 'Ларина',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 4609237,
#    'first_name': 'Дария',
#    'last_name': 'Денисюк',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 4869729,
#    'first_name': 'Ксюша',
#    'last_name': 'Стрельникова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 4871315,
#    'first_name': 'Матвей',
#    'last_name': 'Колбасов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 5200895,
#    'first_name': 'Татьяна',
#    'last_name': 'Шаврина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 5374691,
#    'first_name': 'Михаил',
#    'last_name': 'Надь',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 5532887,
#    'first_name': 'Anna',
#    'last_name': 'Brindyukova',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 5762876,
#    'first_name': 'Александра',
#    'last_name': 'Ильченко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 5901637,
#    'first_name': 'Катюшка',
#    'last_name': 'Ванькова',
#    'deactivated': 'banned'},
#   {'id': 6026374,
#    'first_name': 'Александр',
#    'last_name': 'Григорьев',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 6084115,
#    'first_name': 'Александр',
#    'last_name': 'Усов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6148620,
#    'first_name': 'Mr',
#    'last_name': 'Window',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6193491,
#    'first_name': 'Ксения',
#    'last_name': 'Борисова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6217442,
#    'first_name': 'Артур',
#    'last_name': 'Смит',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6220747,
#    'first_name': 'Артем',
#    'last_name': 'Семенов',
#    'deactivated': 'banned'},
#   {'id': 6325875,
#    'first_name': 'Тимур',
#    'last_name': 'Славгородский-Казанец',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 6371649,
#    'first_name': 'Сашуля',
#    'last_name': 'Никитина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6466320,
#    'first_name': 'Вадим',
#    'last_name': 'Тукмачев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6505705,
#    'first_name': 'Минар',
#    'last_name': 'Альфара',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 6913224,
#    'first_name': 'Дмитрий',
#    'last_name': 'Проданов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 7249462,
#    'first_name': 'Кирилл',
#    'last_name': 'Перелыгин',
#    'deactivated': 'deleted'},
#   {'id': 7261274,
#    'first_name': 'Наталия',
#    'last_name': 'Сергиевская',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 7280512,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 7644986,
#    'first_name': 'Соня',
#    'last_name': 'Никифорова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 7674545,
#    'first_name': 'Карина',
#    'last_name': 'Петрова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 7797423,
#    'first_name': 'Костя',
#    'last_name': 'Корягин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 7816018,
#    'first_name': 'Дима',
#    'last_name': 'Веселов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 7862619,
#    'first_name': 'Никита',
#    'last_name': 'Майзингер',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8085134,
#    'first_name': 'Сабина',
#    'last_name': 'Гитман',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8258925,
#    'first_name': 'Семён',
#    'last_name': 'Маляров',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8333615,
#    'first_name': 'Иоанна',
#    'last_name': 'Голик',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8439497,
#    'first_name': 'Анастасия',
#    'last_name': 'Озера',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8761370,
#    'first_name': 'Дмитрий',
#    'last_name': 'Турчанинов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 8772597,
#    'first_name': 'David',
#    'last_name': 'Mkrtchyan',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 9224040,
#    'first_name': 'Макс',
#    'last_name': 'Макеев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 9295845,
#    'first_name': 'Юлия',
#    'last_name': 'Балуева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 9805622,
#    'first_name': 'Лена',
#    'last_name': 'Кавкаева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 9883753,
#    'first_name': 'Ирина',
#    'last_name': 'Лоскутова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 10655141,
#    'first_name': 'Таня',
#    'last_name': 'Беляева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 10973905,
#    'first_name': 'Татьяна',
#    'last_name': 'Байдак',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11042040,
#    'first_name': 'Valerie',
#    'last_name': 'Fedotova',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11097728,
#    'first_name': 'Юлия',
#    'last_name': 'Толкачева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11190617,
#    'first_name': 'Иван',
#    'last_name': 'Чернявский',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11330009,
#    'first_name': 'Эльмира',
#    'last_name': 'Мустакимова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11747550,
#    'first_name': 'Дима',
#    'last_name': 'Никульшин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 11910310,
#    'first_name': 'Аня',
#    'last_name': 'Волкова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12097712,
#    'first_name': 'Кира',
#    'last_name': 'Луцишина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12099717,
#    'first_name': 'Антон',
#    'last_name': 'Айсин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12247792,
#    'first_name': 'Соня',
#    'last_name': 'Анисимова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12374247,
#    'first_name': 'Александра',
#    'last_name': 'Елизарова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 12446027,
#    'first_name': 'Майя',
#    'last_name': 'Герштейн',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12519257,
#    'first_name': 'Анастасия',
#    'last_name': 'Верещагина',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 12623342,
#    'first_name': 'Михаил',
#    'last_name': 'Садов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12677045,
#    'first_name': 'Светлана',
#    'last_name': 'Виноградова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 12879540,
#    'first_name': 'Olga',
#    'last_name': 'Mukhina',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 13799574,
#    'first_name': 'Коля',
#    'last_name': 'Кондырев',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 14645198,
#    'first_name': 'Даша',
#    'last_name': 'Волкова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 14653094,
#    'first_name': 'Елизавета',
#    'last_name': 'Демина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 15136035,
#    'first_name': 'Анна',
#    'last_name': 'Еремина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 15324458,
#    'first_name': 'Aleksandra',
#    'last_name': 'Fedorenko',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 15611179,
#    'first_name': 'Роман',
#    'last_name': 'Левин',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 15806556,
#    'first_name': 'Женя',
#    'last_name': 'Ефимова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 16260739,
#    'first_name': 'Дмитрий',
#    'last_name': 'Ефимов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 16758945,
#    'first_name': 'Мария',
#    'last_name': 'Жигульская',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 17961576,
#    'first_name': 'Владимир',
#    'last_name': 'Григорьев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 18721734,
#    'first_name': 'Светлана',
#    'last_name': 'Данилова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 19326420,
#    'first_name': 'Илюха',
#    'last_name': 'Лукьяненко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 19374977,
#    'first_name': 'Анна',
#    'last_name': 'Уварова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 19418128,
#    'first_name': 'Камила',
#    'last_name': 'Джаватова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 20354273,
#    'first_name': 'Анастасия',
#    'last_name': 'Мишунина',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 20529222,
#    'first_name': 'Катерина',
#    'last_name': 'Никифорова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 20883506,
#    'first_name': 'Александр',
#    'last_name': 'Стоев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 20943166,
#    'first_name': 'Полина',
#    'last_name': 'Малютина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 21265165,
#    'first_name': 'Милена',
#    'last_name': 'Гуревич',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 21270400,
#    'first_name': 'Таня',
#    'last_name': 'Лазарева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 21570025,
#    'first_name': 'Ангелина',
#    'last_name': 'Гурова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 21708654,
#    'first_name': 'Анастасия',
#    'last_name': 'Скрипкина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 21865762,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 22032542,
#    'first_name': 'Marina',
#    'last_name': 'Dikareva',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 23540705,
#    'first_name': 'Елизавета',
#    'last_name': 'Кузьменко',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 23555478,
#    'first_name': 'Светка',
#    'last_name': 'Ветхова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 26476793,
#    'first_name': 'Ира',
#    'last_name': 'Павлова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 26653892,
#    'first_name': 'Lera',
#    'last_name': 'Cherepanova',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 26927105,
#    'first_name': 'Наталья',
#    'last_name': 'Зонова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 27783009,
#    'first_name': 'Сергей',
#    'last_name': 'Кабацкий',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 27935195,
#    'first_name': 'Анастасия',
#    'last_name': 'Зыкова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 28609913,
#    'first_name': 'Анфиса',
#    'last_name': 'Рекина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 29200252,
#    'first_name': 'Татьяна',
#    'last_name': 'Чибезова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 29312180,
#    'first_name': 'Мария',
#    'last_name': 'Кулешова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 29713016,
#    'first_name': 'Катя',
#    'last_name': 'Соловьёва',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 31319498,
#    'first_name': 'Анечка',
#    'last_name': 'Агеева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 32263003,
#    'first_name': 'Роман',
#    'last_name': 'Косатый',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 33468269,
#    'first_name': 'Мария',
#    'last_name': 'Малыгина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 34128244,
#    'first_name': 'Анастасия',
#    'last_name': 'Шухова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 34369920,
#    'first_name': 'Илья',
#    'last_name': 'Локшин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 36880634,
#    'first_name': 'Андрей',
#    'last_name': 'Искосков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 37128986,
#    'first_name': 'Алексей',
#    'last_name': 'Шелепов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 38075465,
#    'first_name': 'Анастасия',
#    'last_name': 'Лапунова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 38683379,
#    'first_name': 'Настя',
#    'last_name': 'Макаренкова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 41714547,
#    'first_name': 'Нина',
#    'last_name': 'Сахарова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 41869535,
#    'first_name': 'Константин',
#    'last_name': 'Бутич',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 42187308,
#    'first_name': 'Иван',
#    'last_name': 'Александров',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 42808107,
#    'first_name': 'Антон',
#    'last_name': 'Зародин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 42954321,
#    'first_name': 'Валентина',
#    'last_name': 'Мироник',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 45929253,
#    'first_name': 'Ангелина',
#    'last_name': 'Беличенко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 46558348,
#    'first_name': 'Савва',
#    'last_name': 'Дудин',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 46617220,
#    'first_name': 'Александра',
#    'last_name': 'Бурзаева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 47155251,
#    'first_name': 'Виктория',
#    'last_name': 'Паторова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 47925330,
#    'first_name': 'Кри',
#    'last_name': 'Шубникова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 49249674,
#    'first_name': 'Дарья',
#    'last_name': 'Сальникова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 49576103,
#    'first_name': 'Константин',
#    'last_name': 'Яковлев',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 50177710,
#    'first_name': 'Мария',
#    'last_name': 'Милош',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 50409580,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 50409850,
#    'first_name': 'Мария',
#    'last_name': 'Хмара',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 50467050,
#    'first_name': 'Kirill',
#    'last_name': 'Chmel',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 50508062,
#    'first_name': 'Лена',
#    'last_name': 'Захарова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 53054709,
#    'first_name': 'Тимур',
#    'last_name': 'Науширванов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 54281447,
#    'first_name': 'Злата',
#    'last_name': 'Сергеева',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 54363822,
#    'first_name': 'Варвара',
#    'last_name': 'Гуц',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 55686504,
#    'first_name': 'Лизавета',
#    'last_name': 'Пшеничная',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 56216317,
#    'first_name': 'Светлана',
#    'last_name': 'Жена-Царя',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 56367134,
#    'first_name': 'Анастасия',
#    'last_name': 'Гергель',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 57010241,
#    'first_name': 'Оля',
#    'last_name': 'Шаповалова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 57618306,
#    'first_name': 'Вадим',
#    'last_name': 'Дурман',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 59501116,
#    'first_name': 'Артём',
#    'last_name': 'Клемешов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 62743173,
#    'first_name': 'Роман',
#    'last_name': 'Хромов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 68880602,
#    'first_name': 'Марина',
#    'last_name': 'Сахипова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 68892630,
#    'first_name': 'Иван',
#    'last_name': 'Родин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 70738748,
#    'first_name': 'Анастасия',
#    'last_name': 'Чжан',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 71891235,
#    'first_name': 'Екатерина',
#    'last_name': 'Акимова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 73911353,
#    'first_name': 'Валя',
#    'last_name': 'Копылов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 74752526,
#    'first_name': 'Полина',
#    'last_name': 'Ревина',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 76783324,
#    'first_name': 'Владимир',
#    'last_name': 'Рогожин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 84400876,
#    'first_name': 'Даниил',
#    'last_name': 'Кудреватых',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 85241785,
#    'first_name': 'Svetlana',
#    'last_name': 'Sergeevna',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 86270753,
#    'first_name': 'Ольга',
#    'last_name': 'Дорощенко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 88762746,
#    'first_name': 'Светлана',
#    'last_name': 'Казакова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 90293654,
#    'first_name': 'Наталья',
#    'last_name': 'Казеко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 95182274,
#    'first_name': 'Николай',
#    'last_name': 'Лобанов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 96875393,
#    'first_name': 'Rayona',
#    'last_name': 'Bennett',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 98494130,
#    'first_name': 'Илья',
#    'last_name': 'Щуров',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 100862411,
#    'first_name': 'Ольга',
#    'last_name': 'Маркова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 102177145,
#    'first_name': 'Ekaterina',
#    'last_name': 'Sheremeteva',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 104687424,
#    'first_name': 'Степан',
#    'last_name': 'Кyзнeцoв',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 107384748,
#    'first_name': 'Никита',
#    'last_name': 'Зарипов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 108189307,
#    'first_name': 'Виктория',
#    'last_name': 'Попова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 110354002,
#    'first_name': 'Анна',
#    'last_name': 'Долотенкова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 111222568,
#    'first_name': 'Анастасия',
#    'last_name': 'Смирнова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 111639225,
#    'first_name': 'Виктория',
#    'last_name': 'Волынец',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 116958266,
#    'first_name': 'Никита',
#    'last_name': 'Чугунов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 118637751,
#    'first_name': 'Арина',
#    'last_name': 'Жукова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 122738138,
#    'first_name': 'Павел',
#    'last_name': 'Тюлюков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 123322953,
#    'first_name': 'Ксюша',
#    'last_name': 'Вовк',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 124284320,
#    'first_name': 'Анна',
#    'last_name': 'Скосырева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 124634329,
#    'first_name': 'Анастасия',
#    'last_name': 'Макарова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 131822543,
#    'first_name': 'Анастасия',
#    'last_name': 'Хакало',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 132203999,
#    'first_name': 'Елизавета',
#    'last_name': 'Пивовар',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 132932886,
#    'first_name': 'Геннадий',
#    'last_name': 'Поросенков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 134536149,
#    'first_name': 'Кирилл',
#    'last_name': 'Кудряшов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 136161093,
#    'first_name': 'Илья',
#    'last_name': 'Иншаков',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 136703001,
#    'first_name': 'Дима',
#    'last_name': 'Кочнов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 137286498,
#    'first_name': 'Маргарита',
#    'last_name': 'Сергеева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 137982646,
#    'first_name': 'Виктор',
#    'last_name': 'Калашников',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 140311380,
#    'first_name': 'Артур',
#    'last_name': 'Печериченко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 142413611,
#    'first_name': 'Дарья',
#    'last_name': 'Паршина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 142827645,
#    'first_name': 'Юлия',
#    'last_name': 'Малахова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 143587737,
#    'first_name': 'Лиза',
#    'last_name': 'Старостина',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 146145733,
#    'first_name': 'Анна',
#    'last_name': 'Щербакова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 146832833,
#    'first_name': 'Денис',
#    'last_name': 'Кузнецов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 150519847,
#    'first_name': 'Anna',
#    'last_name': 'Boriskova',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 151202032,
#    'first_name': 'Даша',
#    'last_name': 'Якушева',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 152201386,
#    'first_name': 'Илья',
#    'last_name': 'Колесников',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 152537763,
#    'first_name': 'Никита',
#    'last_name': 'Хохлов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 162620854,
#    'first_name': 'Иван',
#    'last_name': 'Цой',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 162668793,
#    'first_name': 'Михаил',
#    'last_name': 'Мурзин',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 163348762,
#    'first_name': 'Nastya',
#    'last_name': 'Parusnikova',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 167125849,
#    'first_name': 'Дмитрий',
#    'last_name': 'Муравьёв',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 171544496,
#    'first_name': 'Наталья',
#    'last_name': 'Василёнок',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 176852466,
#    'first_name': 'Алина',
#    'last_name': 'Савёлова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 178194663,
#    'first_name': 'Егор',
#    'last_name': 'Гладких',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 178835227,
#    'first_name': 'Cyryla',
#    'last_name': 'Milincević',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 179482020,
#    'first_name': 'Михаил',
#    'last_name': 'Филатов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 179654703,
#    'first_name': 'Иоанн',
#    'last_name': 'Довгополый',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 180577856,
#    'first_name': 'Сергей',
#    'last_name': 'Михайлов',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 181111831,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 181757173,
#    'first_name': 'Иван',
#    'last_name': 'Головченко',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 182648611,
#    'first_name': 'Юлия',
#    'last_name': 'Гребенникова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 184939214,
#    'first_name': 'Александра',
#    'last_name': 'Григорян',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 190780842,
#    'first_name': 'Анна',
#    'last_name': 'Долотенкова',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 194839944,
#    'first_name': 'Азиз',
#    'last_name': 'Тулаганов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 203529302,
#    'first_name': 'Георгий',
#    'last_name': 'Тарасенко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 204887171,
#    'first_name': 'Дима',
#    'last_name': 'Сорокин',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 205824967,
#    'first_name': 'Даниил',
#    'last_name': 'Аксёнов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 206520767,
#    'first_name': 'Георгий',
#    'last_name': 'Мыльников',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 206530321,
#    'first_name': 'Mary',
#    'last_name': 'Heavens',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 206701741,
#    'first_name': 'Вероника',
#    'last_name': 'Земскова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 209740229,
#    'first_name': 'Анастасия',
#    'last_name': 'Успенская',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 212013232,
#    'first_name': 'Всеволод',
#    'last_name': 'Фирсов',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 223067357,
#    'first_name': 'Михаил',
#    'last_name': 'Каплинский',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 238274365,
#    'first_name': 'Никита',
#    'last_name': 'Алексеев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 261963874,
#    'first_name': 'Андрей',
#    'last_name': 'Тамбовцев',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 263861513,
#    'first_name': 'Αнтон',
#    'last_name': 'Οвчинников',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 265793196,
#    'first_name': 'Дмитрий',
#    'last_name': 'Толкачев',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 269113997,
#    'first_name': 'Настя',
#    'last_name': 'Миронова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 277286821,
#    'first_name': 'Таня',
#    'last_name': 'Паутова',
#    'deactivated': 'deleted'},
#   {'id': 280968040,
#    'first_name': 'Юлия',
#    'last_name': 'Михайлова',
#    'deactivated': 'banned'},
#   {'id': 289269459,
#    'first_name': 'Маргарита',
#    'last_name': 'Резниченко',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 291987241,
#    'first_name': 'Sasha',
#    'last_name': 'Starinskaya',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 303570128,
#    'first_name': 'Павел',
#    'last_name': 'Пронин',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 310307054,
#    'first_name': 'Вероника',
#    'last_name': 'Данилова',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 320326729,
#    'first_name': 'Alice',
#    'last_name': 'Woda',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 381606101,
#    'first_name': 'Elena',
#    'last_name': 'Leonchenko',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 388237828,
#    'first_name': 'Anastasiia',
#    'last_name': 'Yuryevna',
#    'is_closed': True,
#    'can_access_closed': True},
#   {'id': 399093719,
#    'first_name': 'Вадим',
#    'last_name': 'Корсун',
#    'is_closed': False,
#    'can_access_closed': True},
#   {'id': 410360271,
#    'first_name': 'DELETED',
#    'last_name': '',
#    'deactivated': 'deleted'},
#   {'id': 450196371,
#    'first_name': 'Furkan',
#    'last_name': 'Firatli',
#    'is_closed': False,
#    'can_access_closed': True}]}

# %% [markdown]
# ### Пример 3: посты со стены сообщества

# %%
group = 'hseofficial'
count = '100'

# %%
METHOD_NAME = "wall.get"
PARAMETERS = "domain=" + group + '&' + 'count=' + count

# %%
req = f"https://api.vk.com/method/{METHOD_NAME}?{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}"

# %%
resp = requests.get(req)
data = resp.json()

# %%
data
# Out:
# {'response': {'count': 8644,
#   'items': [{'id': 33029,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971849,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Что меня огорчает',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://www.hse.ru/our/news/323346844.html',
#        'title': 'Что меня огорчает',
#        'caption': 'www.hse.ru',
#        'description': 'Авторская колонка первого проректора Вадима Радаева',
#        'photo': {'id': 457289885,
#         'album_id': -26,
#         'owner_id': 2000021743,
#         'sizes': [{'type': 'k',
#           'url': 'https://sun9-71.userapi.com/c858024/v858024349/120e4c/to-wJyYBh9w.jpg',
#           'width': 1000,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-32.userapi.com/c858024/v858024349/120e4b/jvKn7gctoWs.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'm',
#           'url': 'https://sun9-12.userapi.com/c858024/v858024349/120e48/c9FrIN8g3F0.jpg',
#           'width': 130,
#           'height': 87},
#          {'type': 'p',
#           'url': 'https://sun9-5.userapi.com/c858024/v858024349/120e4a/k4mOW6y9DRM.jpg',
#           'width': 260,
#           'height': 173},
#          {'type': 's',
#           'url': 'https://sun9-19.userapi.com/c858024/v858024349/120e47/Wr__bx8GuTU.jpg',
#           'width': 75,
#           'height': 50},
#          {'type': 'x',
#           'url': 'https://sun9-44.userapi.com/c858024/v858024349/120e49/p6wvV7kAM9Y.jpg',
#           'width': 150,
#           'height': 100}],
#         'text': '',
#         'date': 1575971849},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 12, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 6670},
#     'is_favorite': False},
#    {'id': 33028,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971665,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 400,
#       'owner_id': -130374393,
#       'from_id': -130374393,
#       'date': 1575887795,
#       'post_type': 'post',
#       'text': 'Дорогие друзья, мы рады сообщить вам, что совсем скоро 20 декабря в 19.00 состоится наш отчётный новогодний концерт! 🎶🎻\n\nНа нем прозвучат произведения Вивальди, Бизе и Манчини. Также в этот раз вы услышите много новых музыкальных сюрпризов, от которых непременно появится новогоднее настроение! \nПоэтому настраивайтесь на праздник вместе с нами🎄🎄🎄\nПредварительно нужно зарегистрироваться по ссылке ниже:\n\nhttps://hse-orchestra.timepad.ru/event/1138504/\n\nМы будем рады видеть вас, до встречи на концерте! 🎶',
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 457240910,
#          'album_id': -5,
#          'owner_id': 54934019,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun1-90.userapi.com/c857032/v857032770/7c35d/8foQmQIBRW8.jpg',
#            'width': 87,
#            'height': 130},
#           {'type': 'o',
#            'url': 'https://sun1-85.userapi.com/c857032/v857032770/7c362/4N_U_ITamgw.jpg',
#            'width': 130,
#            'height': 193},
#           {'type': 'p',
#            'url': 'https://sun1-26.userapi.com/c857032/v857032770/7c363/_h7knU4Ll8s.jpg',
#            'width': 200,
#            'height': 298},
#           {'type': 'q',
#            'url': 'https://sun1-30.userapi.com/c857032/v857032770/7c364/PX4I-Dv8JCQ.jpg',
#            'width': 320,
#            'height': 477},
#           {'type': 'r',
#            'url': 'https://sun1-87.userapi.com/c857032/v857032770/7c365/ZNjvi6JunVE.jpg',
#            'width': 510,
#            'height': 760},
#           {'type': 's',
#            'url': 'https://sun1-23.userapi.com/c857032/v857032770/7c35c/Dw67WpDy-vM.jpg',
#            'width': 50,
#            'height': 75},
#           {'type': 'w',
#            'url': 'https://sun1-91.userapi.com/c857032/v857032770/7c361/WBYDsfz0u88.jpg',
#            'width': 1080,
#            'height': 1609},
#           {'type': 'x',
#            'url': 'https://sun1-15.userapi.com/c857032/v857032770/7c35e/UnDmHjUu8e8.jpg',
#            'width': 406,
#            'height': 604},
#           {'type': 'y',
#            'url': 'https://sun1-92.userapi.com/c857032/v857032770/7c35f/EODELCzNfqQ.jpg',
#            'width': 542,
#            'height': 807},
#           {'type': 'z',
#            'url': 'https://sun1-27.userapi.com/c857032/v857032770/7c360/0F5BAhbbsEc.jpg',
#            'width': 725,
#            'height': 1080}],
#          'text': '',
#          'date': 1575887739,
#          'access_key': '01b15709d9de007646'}},
#        {'type': 'link',
#         'link': {'url': 'https://hse-orchestra.timepad.ru/event/1138504/',
#          'title': 'Концерт Симфонического Оркестра НИУ ВШЭ / События на TimePad.ru',
#          'description': 'На Новогоднем Концерте Оркестра ВШЭ прозвучат Вивальди, Бизе, Штраус, Манчини, Рота и Циммер!',
#          'target': 'internal',
#          'is_favorite': False}}],
#       'post_source': {'type': 'mvk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 14, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 2, 'user_reposted': 0},
#     'views': {'count': 3503},
#     'is_favorite': False},
#    {'id': 33027,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971625,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 95,
#       'owner_id': -185974612,
#       'from_id': -185974612,
#       'date': 1575640597,
#       'post_type': 'post',
#       'text': 'Сидели в перерыве, ели KitKat и изучали прогноз погоды на следующую неделю. Казалось бы, о чем можно написать пост с такой предпосылкой? Но все не так просто.\n\n12 декабря ночью обещают -4. Вот мы и подумали, что самое время провести четвёртую КЦшную встречу! В четверг в 18:30 к нам придёт Виктория Сидякина, корпоративный директор по работе с персоналом «Нестле Россия и Евразия», другими словами, выходим на мировой масштаб!\n\n— Вот это тема! – скажете вы\n— Вот это тема: «Nestlé - one of the five most beloved brands in the world: что это значит?» – ответим мы. \n\nЗачем мне это?\nВсе логично: Вышка – лучший ВУЗ, в лучшем ВУЗе – умные студенты, умные студенты – крутая работа, крутая работа – у одного из лучших работодателей мира, да что мира - России, а один из лучших работодателей России как раз по счастливой случайности будет у нас в КЦ!\n\nРезюмируем:\nЧто: КЦшная встреча\nКогда: 12 декабря в 18:30\nГде: Малый зал КЦ\nКто: Крутой спикер\nСсылка на регистрацию: https://hse-cc-event.timepad.ru/event/1136608/\n\nЗапомнили, закрепили, зарегистрировались. Если что, ориентируйтесь на прогноз погоды!',
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 457239438,
#          'album_id': -7,
#          'owner_id': -185974612,
#          'user_id': 100,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun1-20.userapi.com/c200424/v200424247/339a/0qqpo-RUP0Y.jpg',
#            'width': 130,
#            'height': 73},
#           {'type': 'o',
#            'url': 'https://sun1-91.userapi.com/c200424/v200424247/339e/_jqL2HvqPi8.jpg',
#            'width': 130,
#            'height': 87},
#           {'type': 'p',
#            'url': 'https://sun1-20.userapi.com/c200424/v200424247/339f/XgVRewaaPXo.jpg',
#            'width': 200,
#            'height': 133},
#           {'type': 'q',
#            'url': 'https://sun1-30.userapi.com/c200424/v200424247/33a0/oj5CQzIyg50.jpg',
#            'width': 320,
#            'height': 213},
#           {'type': 'r',
#            'url': 'https://sun1-83.userapi.com/c200424/v200424247/33a1/9-Ri3SJIUb4.jpg',
#            'width': 510,
#            'height': 340},
#           {'type': 's',
#            'url': 'https://sun1-22.userapi.com/c200424/v200424247/3399/7GrHTCxqjq0.jpg',
#            'width': 75,
#            'height': 42},
#           {'type': 'x',
#            'url': 'https://sun1-91.userapi.com/c200424/v200424247/339b/pvVu0oXFYAA.jpg',
#            'width': 604,
#            'height': 340},
#           {'type': 'y',
#            'url': 'https://sun1-22.userapi.com/c200424/v200424247/339c/gF4-YoB5-mo.jpg',
#            'width': 807,
#            'height': 454},
#           {'type': 'z',
#            'url': 'https://sun1-25.userapi.com/c200424/v200424247/339d/-sZpbB_nywM.jpg',
#            'width': 1280,
#            'height': 720}],
#          'text': '',
#          'date': 1575640597,
#          'access_key': '8e60811876e2b25d67'}},
#        {'type': 'link',
#         'link': {'url': 'https://hse-cc-event.timepad.ru/event/1136608/',
#          'title': 'КЦшная встреча с Директором по персоналу ООО «Нестле Россия» Викторией Сидякиной / События на TimePad.ru',
#          'description': 'КЦшная встреча с Директором по персоналу ООО «Нестле Россия» Викторией Сидякиной',
#          'target': 'internal',
#          'is_favorite': False}}],
#       'post_source': {'type': 'api', 'platform': 'iphone'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 2348},
#     'is_favorite': False},
#    {'id': 33026,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971586,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 457240210,
#        'album_id': -7,
#        'owner_id': -132,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun9-72.userapi.com/c850636/v850636606/dc5fd/yUoixGiKQ1I.jpg',
#          'width': 92,
#          'height': 130},
#         {'type': 'o',
#          'url': 'https://sun9-42.userapi.com/c850636/v850636606/dc602/dxdqbUycAM8.jpg',
#          'width': 130,
#          'height': 184},
#         {'type': 'p',
#          'url': 'https://sun9-46.userapi.com/c850636/v850636606/dc603/LhHYqsgF87U.jpg',
#          'width': 200,
#          'height': 283},
#         {'type': 'q',
#          'url': 'https://sun9-31.userapi.com/c850636/v850636606/dc604/022tztVC9wg.jpg',
#          'width': 320,
#          'height': 452},
#         {'type': 'r',
#          'url': 'https://sun9-26.userapi.com/c850636/v850636606/dc605/bW3Ewi8nDQA.jpg',
#          'width': 510,
#          'height': 721},
#         {'type': 's',
#          'url': 'https://sun9-7.userapi.com/c850636/v850636606/dc5fc/nCb5tRmBbAI.jpg',
#          'width': 53,
#          'height': 75},
#         {'type': 'w',
#          'url': 'https://sun9-20.userapi.com/c850636/v850636606/dc601/TbgJPS26UVQ.jpg',
#          'width': 906,
#          'height': 1280},
#         {'type': 'x',
#          'url': 'https://sun9-43.userapi.com/c850636/v850636606/dc5fe/0o6xI-diDbk.jpg',
#          'width': 427,
#          'height': 604},
#         {'type': 'y',
#          'url': 'https://sun9-15.userapi.com/c850636/v850636606/dc5ff/nLVoJPdYLX8.jpg',
#          'width': 571,
#          'height': 807},
#         {'type': 'z',
#          'url': 'https://sun9-71.userapi.com/c850636/v850636606/dc600/_An54EwTtRE.jpg',
#          'width': 764,
#          'height': 1080}],
#        'text': '',
#        'date': 1575971586,
#        'post_id': 33026,
#        'access_key': '6576089fc2c892cf61'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 9, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 5660},
#     'is_favorite': False},
#    {'id': 33025,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971433,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Вышка в прошлом году запустила новый проект, обеспечивающий социальный лифт детям из семей, попавших в сложные обстоятельства. Это те ребята, которые не подпадают под федеральные льготы, но между тем достойны поддержки. Финансирует проект университет. Так видит руководство вуза социальную ответственность университета перед обществом. Мы очень рады, что число участников проекта удвоится в 2020 году. https://www.hse.ru/news/admission/321757804.html',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://www.hse.ru/news/admission/321757804.html',
#        'title': 'Число участников программы «Социальный лифт» в 2020 году вырастет более чем в два раза',
#        'caption': 'www.hse.ru',
#        'description': 'Высшая школа экономики продолжит и расширит программу «Социальный лифт», в рамках которой в бакалавриат зачисляются вне конкурса абитуриенты, оказавшиеся в сложных жизненных обстоятельствах. Об этом 3 декабря было объявлено на круглом столе, посвященном благотворительности в высшем образовании.',
#        'photo': {'id': 457290253,
#         'album_id': -27,
#         'owner_id': 2000021717,
#         'sizes': [{'type': 'k',
#           'url': 'https://sun9-44.userapi.com/c857536/v857536902/11a602/ls6mstk95hs.jpg',
#           'width': 1074,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-12.userapi.com/c857536/v857536902/11a601/3KYePaHUXhA.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'm',
#           'url': 'https://sun9-9.userapi.com/c857536/v857536902/11a5fe/wEK9aNIrTbY.jpg',
#           'width': 130,
#           'height': 87},
#          {'type': 'p',
#           'url': 'https://sun9-39.userapi.com/c857536/v857536902/11a600/S4vpNbLihE4.jpg',
#           'width': 260,
#           'height': 173},
#          {'type': 's',
#           'url': 'https://sun9-13.userapi.com/c857536/v857536902/11a5fd/a7HBY1JCB70.jpg',
#           'width': 75,
#           'height': 50},
#          {'type': 'x',
#           'url': 'https://sun9-62.userapi.com/c857536/v857536902/11a5ff/6_-8gIlXA6w.jpg',
#           'width': 150,
#           'height': 100}],
#         'text': '',
#         'date': 1575971433},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 9, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 2292},
#     'is_favorite': False},
#    {'id': 33024,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575971123,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Поздравляем! Основоположник "Русских хакеров" Максим Дьяков растит достойную смену. Новый состав студенческой организации успешно провел 7 декабря 12-часовой хакатон для новичков в Культурном центре НИУ ВШЭ на Покровке. https://www.hse.ru/news/edu/323373069.html',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://www.hse.ru/news/edu/323373069.html',
#        'title': 'Студенты Вышки заняли третье место на международном хакатоне Junction',
#        'caption': 'www.hse.ru',
#        'description': 'В этом году в масштабном мероприятии приняли участие 1500 участников из 100 стран. Команда студентов второго курса факультета компьютерных наук (Тимофей Смирнов, Игорь Законы и Айнур Нуриев) представила проект умного освещения.',
#        'photo': {'id': 457282109,
#         'album_id': -27,
#         'owner_id': 2000022491,
#         'sizes': [{'type': 'k',
#           'url': 'https://sun9-65.userapi.com/c206524/v206524513/9069/d3Gnd-Kpbfg.jpg',
#           'width': 800,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-39.userapi.com/c206524/v206524513/9068/4V1iYzC5i_U.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'm',
#           'url': 'https://sun9-66.userapi.com/c206524/v206524513/9065/FERwd52dk7E.jpg',
#           'width': 130,
#           'height': 87},
#          {'type': 'p',
#           'url': 'https://sun9-25.userapi.com/c206524/v206524513/9067/OPDjvT81uew.jpg',
#           'width': 260,
#           'height': 173},
#          {'type': 's',
#           'url': 'https://sun9-20.userapi.com/c206524/v206524513/9064/SeHyYgJveNU.jpg',
#           'width': 75,
#           'height': 50},
#          {'type': 'x',
#           'url': 'https://sun9-50.userapi.com/c206524/v206524513/9066/r183RJKpO9Y.jpg',
#           'width': 150,
#           'height': 100}],
#         'text': '',
#         'date': 1575971123},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 8, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 3113},
#     'is_favorite': False},
#    {'id': 33023,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575970990,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Опубликованы решения Ученого совета по стоимости образовательных программ на 2020 год https://ba.hse.ru/icef#pagetop',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://ba.hse.ru/icef#pagetop',
#        'title': 'Стоимость обучения – 2020',
#        'caption': 'ba.hse.ru',
#        'description': '',
#        'photo': {'id': 457284290,
#         'album_id': -28,
#         'owner_id': 2000022257,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun1-16.userapi.com/c855416/v855416728/197d4c/oDLIdhsCgqs.jpg',
#           'width': 130,
#           'height': 68},
#          {'type': 'p',
#           'url': 'https://sun1-88.userapi.com/c855416/v855416728/197d4e/wpVKHsR54VQ.jpg',
#           'width': 260,
#           'height': 136},
#          {'type': 's',
#           'url': 'https://sun1-18.userapi.com/c855416/v855416728/197d4b/6f5q8GhzoU0.jpg',
#           'width': 75,
#           'height': 39},
#          {'type': 'x',
#           'url': 'https://sun1-27.userapi.com/c855416/v855416728/197d4d/b4ISXIaiRqc.jpg',
#           'width': 150,
#           'height': 78}],
#         'text': '',
#         'date': 1575969541},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 2552},
#     'is_favorite': False},
#    {'id': 33022,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575969388,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 3327,
#       'owner_id': -142774925,
#       'from_id': -142774925,
#       'date': 1575965580,
#       'post_type': 'post',
#       'text': 'Неужели всё-таки возможен вариант, что в будущем электроника полностью заменит силы человека? С новыми беспилотными курьерами, которые обещают осуществлять 80% доставок, этот вопрос больше не кажется мистическим ❗\n\n#инновационнаялогистика@popular_logistics \n#логистикараспределения@popular_logistics',
#       'attachments': [{'type': 'link',
#         'link': {'url': 'https://m.vk.com/@-142774925-bespilotnye-letauschie-kurery-v-rossiiskih-gorodah-mogut-poy',
#          'title': '«Беспилотные летающие курьеры» в российских городах могут появиться через 3-4 года',
#          'caption': 'm.vk.com',
#          'description': 'Статья',
#          'photo': {'id': 457241446,
#           'album_id': -66,
#           'owner_id': -142774925,
#           'user_id': 100,
#           'sizes': [{'type': 'm',
#             'url': 'https://sun9-23.userapi.com/c200524/v200524225/40aa/g0YUhHuAfMI.jpg',
#             'width': 130,
#             'height': 68},
#            {'type': 'o',
#             'url': 'https://sun9-47.userapi.com/c200524/v200524225/40ad/c4pIfmBWIzE.jpg',
#             'width': 130,
#             'height': 87},
#            {'type': 'p',
#             'url': 'https://sun9-11.userapi.com/c200524/v200524225/40ae/4Tps45cONeI.jpg',
#             'width': 200,
#             'height': 133},
#            {'type': 'q',
#             'url': 'https://sun9-44.userapi.com/c200524/v200524225/40af/msUMM8PetLs.jpg',
#             'width': 320,
#             'height': 213},
#            {'type': 'r',
#             'url': 'https://sun9-45.userapi.com/c200524/v200524225/40b0/t5WwAFT5NgA.jpg',
#             'width': 510,
#             'height': 319},
#            {'type': 's',
#             'url': 'https://sun9-56.userapi.com/c200524/v200524225/40a9/BYBlaMsSvH0.jpg',
#             'width': 75,
#             'height': 39},
#            {'type': 'x',
#             'url': 'https://sun9-60.userapi.com/c200524/v200524225/40ab/aQP2mCWZ37Q.jpg',
#             'width': 604,
#             'height': 316},
#            {'type': 'y',
#             'url': 'https://sun9-13.userapi.com/c200524/v200524225/40ac/kw_vb_YGxkg.jpg',
#             'width': 610,
#             'height': 319}],
#           'text': '',
#           'date': 1575702606},
#          'button': {'title': 'Читать',
#           'action': {'type': 'open_url',
#            'url': 'https://m.vk.com/@-142774925-bespilotnye-letauschie-kurery-v-rossiiskih-gorodah-mogut-poy'}}}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 1802},
#     'is_favorite': False},
#    {'id': 33021,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575878182,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 4,
#       'owner_id': -189213399,
#       'from_id': -189213399,
#       'date': 1574786652,
#       'post_type': 'post',
#       'text': 'Привет всем любителям спорта!⚽\n\nСпешим сообщить, что совсем скоро состоится Международный студенческий спортивный фестиваль “Students Euro Cup”, приуроченный к Чемпионату Европы по футболу EURO-2020 на базе НИУ ВШЭ СПБ. Фестиваль будет проводиться в формате турнира по мини-футболу (6*6 игроков).\n\nКогда?⏳\n15-17 декабря 2019 года.\n\nКто участвует?🥅\n24 студенческие команды из ведущих вузов России и Европы, состав каждой команды - 8 человек.\n\nГде?📍\nСанкт-Петербург, центр футбольной подготовки «Восхождение».\n\nНаш фестиваль - это прежде всего: \n1. Поддержка культуры молодежного спорта;\n2. Площадка для обмена опытом студентов не только из России, но и Европы.\n\nУчастников и зрителей турнира ждет насыщенная спортивная, образовательная и культурная программа, включающая в себя памятные подарки и розыгрыши призов от наших партнёров. Но самое главное - это дружеская атмосфера и отличное настроение студентов различных городов и стран в процессе коммуникации и обмена опытом.',
#       'signer_id': 153415561,
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 457239020,
#          'album_id': -7,
#          'owner_id': -189213399,
#          'user_id': 100,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun9-48.userapi.com/c858428/v858428608/103b8f/Vxa22aDJTX0.jpg',
#            'width': 130,
#            'height': 87},
#           {'type': 'o',
#            'url': 'https://sun9-39.userapi.com/c858428/v858428608/103b94/4IZ2-5_DZkY.jpg',
#            'width': 130,
#            'height': 87},
#           {'type': 'p',
#            'url': 'https://sun9-69.userapi.com/c858428/v858428608/103b95/ymgtiy_Qtzw.jpg',
#            'width': 200,
#            'height': 135},
#           {'type': 'q',
#            'url': 'https://sun9-40.userapi.com/c858428/v858428608/103b96/0CveTyNc29c.jpg',
#            'width': 320,
#            'height': 216},
#           {'type': 'r',
#            'url': 'https://sun9-39.userapi.com/c858428/v858428608/103b97/qxVMMf__-b0.jpg',
#            'width': 510,
#            'height': 343},
#           {'type': 's',
#            'url': 'https://sun9-68.userapi.com/c858428/v858428608/103b8e/JpK5rBYGiHg.jpg',
#            'width': 75,
#            'height': 50},
#           {'type': 'w',
#            'url': 'https://sun9-62.userapi.com/c858428/v858428608/103b93/56AJAAuMifw.jpg',
#            'width': 2000,
#            'height': 1347},
#           {'type': 'x',
#            'url': 'https://sun9-65.userapi.com/c858428/v858428608/103b90/fhsT68fWNsY.jpg',
#            'width': 604,
#            'height': 406},
#           {'type': 'y',
#            'url': 'https://sun9-69.userapi.com/c858428/v858428608/103b91/gt-2aG08fiI.jpg',
#            'width': 807,
#            'height': 543},
#           {'type': 'z',
#            'url': 'https://sun9-65.userapi.com/c858428/v858428608/103b92/kT69JIwz_Jk.jpg',
#            'width': 1280,
#            'height': 862}],
#          'text': '',
#          'date': 1574786493,
#          'access_key': '32bf8f684d3eb61ff2'}}],
#       'post_source': {'type': 'mvk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 2293},
#     'is_favorite': False},
#    {'id': 33019,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575878062,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Вакансия для наших студентов от Леруа Мерлен https://hh.ru/vacancy/34679990',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://hh.ru/vacancy/34679990',
#        'title': 'Вакансия Практикант / Стажер (IT) в Москве, работа в Леруа Мерлен. Центральный офис',
#        'caption': 'hh.ru',
#        'description': 'Вакансия Практикант / Стажер (IT). Зарплата: не указана. Москва. Требуемый опыт: не требуется. Стажировка. Дата публикации: 21.11.2019.',
#        'photo': {'id': 457280139,
#         'album_id': -25,
#         'owner_id': 2000022015,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun9-33.userapi.com/c857524/v857524245/116b3a/RJy2Izwml2c.jpg',
#           'width': 130,
#           'height': 70},
#          {'type': 's',
#           'url': 'https://sun9-27.userapi.com/c857524/v857524245/116b39/rLBuj3JThD4.jpg',
#           'width': 75,
#           'height': 40},
#          {'type': 'x',
#           'url': 'https://sun9-63.userapi.com/c857524/v857524245/116b3b/5qmkfgDYn4k.jpg',
#           'width': 150,
#           'height': 81}],
#         'text': '',
#         'date': 1575878062},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 3319},
#     'is_favorite': False},
#    {'id': 33018,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1575877997,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 8513,
#       'owner_id': -17015209,
#       'from_id': -17015209,
#       'date': 1575388813,
#       'post_type': 'post',
#       'text': '#мероприятие_PwC\n\nВсе знают, зачем государству налоги. Мы знаем, как с ними жить бизнесу. \n \nХочешь познакомиться с налоговыми консультантами PwC? 😊\n \nПриходи 12 декабря на мероприятие PwC. Мы поговорим о налоговом консалтинге: про современные тренды и вызовы, про передовые технологии и навыки консультанта 21 века, про глобализацию налоговых вопросов. Мы расскажем, чем занимаемся сегодня, в чем видим источник вдохновения в работе, об актуальных вакансиях на зимнюю стажировку, и, конечно, ответим на твои вопросы. \n \nДата: 12 декабря, 18:30. \nАдрес: НИУ ВШЭ (Покровский бульвар, 11). \nАудитория: R-304.\n\nЗарегистрироваться можно здесь: https://vk.cc/a5ZLon\n \nЖдем студентов любых курсов. \nПриходи – будет интересно! 😉',
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 457244359,
#          'album_id': -7,
#          'owner_id': -17015209,
#          'user_id': 100,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun9-59.userapi.com/c857336/v857336926/72346/VQvtpk3Uyq8.jpg',
#            'width': 130,
#            'height': 71},
#           {'type': 'o',
#            'url': 'https://sun9-63.userapi.com/c857336/v857336926/7234b/itUo4HvuLaA.jpg',
#            'width': 130,
#            'height': 87},
#           {'type': 'p',
#            'url': 'https://sun9-23.userapi.com/c857336/v857336926/7234c/0bmxH1ZXw3k.jpg',
#            'width': 200,
#            'height': 133},
#           {'type': 'q',
#            'url': 'https://sun9-22.userapi.com/c857336/v857336926/7234d/TzXcOH_fluA.jpg',
#            'width': 320,
#            'height': 213},
#           {'type': 'r',
#            'url': 'https://sun9-25.userapi.com/c857336/v857336926/7234e/-1FwbLZwg0Y.jpg',
#            'width': 510,
#            'height': 340},
#           {'type': 's',
#            'url': 'https://sun9-48.userapi.com/c857336/v857336926/72345/UMaQdzYORe4.jpg',
#            'width': 75,
#            'height': 41},
#           {'type': 'w',
#            'url': 'https://sun9-42.userapi.com/c857336/v857336926/7234a/8jQDFbdqgYY.jpg',
#            'width': 2058,
#            'height': 1125},
#           {'type': 'x',
#            'url': 'https://sun9-72.userapi.com/c857336/v857336926/72347/EAhlkQCK0bM.jpg',
#            'width': 604,
#            'height': 330},
#           {'type': 'y',
#            'url': 'https://sun9-14.userapi.com/c857336/v857336926/72348/_yPVCaBw40A.jpg',
#            'width': 807,
#            'height': 441},
#           {'type': 'z',
#            'url': 'https://sun9-45.userapi.com/c857336/v857336926/72349/aDY7ai3aMr4.jpg',
#            'width': 1280,
#            'height': 700}],
#          'text': '',
#          'date': 1575387687,
#          'post_id': 8513,
#          'access_key': '4cba7b4f055ec22f28'}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 1941},
#     'is_favorite': False},
#    {'id': 33013,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1574758466,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 560,
#       'owner_id': -78620921,
#       'from_id': -78620921,
#       'date': 1574330092,
#       'post_type': 'post',
#       'text': '5-часовой хакатон от МТС\n \n🔴Стань участником соревнования и получи возможность попасть в команду МТС! \n \n🔺Дата: 7 декабря 2019 \n🔺Место: Дом Правительства Московской области (бул. Строителей, 1, Красногорск) \nПодробная информация и регистрация: https://mosrobot2019.ru/ \n \n🔴В этом году Форум посвящен развитию робототехники и станет дискуссионной и выставочной площадкой в сфере инноваций для лучших молодых инноваторов, предпринимателей, ученых, робототехников, а также представителей ведущих научных школ и инновационных лабораторий Подмосковья. \n \nРегистрация открытыпо ссылке https://rusinnovations.timepad.ru/event/1112112/ до 29.11. \nУспей принять участие!\n\n#mts #АИР #москва #хакатон #московскаяобласть #It',
#       'attachments': [{'type': 'link',
#         'link': {'url': 'https://mosrobot2019.ru',
#          'title': 'Московский областной молодежный форум инноваций и предпринимательства',
#          'caption': 'mosrobot2019.ru',
#          'description': 'Московский областной молодежный форум инноваций и предпринимательства',
#          'photo': {'id': 457283968,
#           'album_id': -28,
#           'owner_id': 2000012434,
#           'sizes': [{'type': 'a',
#             'url': 'https://sun9-8.userapi.com/c858432/v858432978/f18f6/Lv1epT1sP48.jpg',
#             'width': 200,
#             'height': 89},
#            {'type': 'b',
#             'url': 'https://sun9-51.userapi.com/c858432/v858432978/f18f4/qUl93GOPqzQ.jpg',
#             'width': 400,
#             'height': 179},
#            {'type': 'c',
#             'url': 'https://sun9-49.userapi.com/c858432/v858432978/f18f8/xHU3_HKMVjY.jpg',
#             'width': 200,
#             'height': 200},
#            {'type': 'd',
#             'url': 'https://sun9-33.userapi.com/c858432/v858432978/f18f9/19EGm3OpQBU.jpg',
#             'width': 100,
#             'height': 100},
#            {'type': 'e',
#             'url': 'https://sun9-29.userapi.com/c858432/v858432978/f18fa/tol9l793qN8.jpg',
#             'width': 50,
#             'height': 50},
#            {'type': 'k',
#             'url': 'https://sun9-7.userapi.com/c858432/v858432978/f18f5/y1twmu2EhZs.jpg',
#             'width': 1073,
#             'height': 480},
#            {'type': 'l',
#             'url': 'https://sun9-17.userapi.com/c858432/v858432978/f18f7/sfIxMs1SsTw.jpg',
#             'width': 537,
#             'height': 240},
#            {'type': 'o',
#             'url': 'https://sun9-41.userapi.com/c858432/v858432978/f18f3/6-CGzG2LBsM.jpg',
#             'width': 751,
#             'height': 336}],
#           'text': '',
#           'date': 1574330092},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 4708},
#     'is_favorite': False},
#    {'id': 33012,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1574758409,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 3596,
#       'owner_id': -123851409,
#       'from_id': -123851409,
#       'date': 1574679615,
#       'post_type': 'post',
#       'text': '25 ноября стартует набор в Tinkoff Internship — оплачиваемую образовательную программу, которая поможет отточить знания в области программирования и аналитики и поработать над реальными проектами Тинькофф. Программа начнется 29 января 2020 года в Москве, Санкт-Петербурге, Екатеринбурге, Ижевске, Рязани и Нижнем Новгороде. Коротко о том, что ждет студентов:\n\n💫 обучение под началом куратора по направлениям «Frontend-разработка», «Python-разработка», «Аналитика», «Управление проектами», «Системное администрирование» и не только; \n\n⭐ присутствие в офисе Тинькофф от 20 часов в неделю;\n\n🌟 три месяца занятий с реальными проектами Тинькофф;\n\n🏆 возможность попасть к нам в команду после окончания обучения.\n\nВыбрать направление и оставить заявку не позже 8 декабря можно тут: https://l.tinkoff.ru/tinternship20_vk',
#       'attachments': [{'type': 'doc',
#         'doc': {'id': 524983176,
#          'owner_id': 213287907,
#          'title': 'Tinkoff Internship.gif',
#          'size': 13785375,
#          'ext': 'gif',
#          'url': 'https://vk.com/doc213287907_524983176?hash=7e4b18765b879e9c20&dl=GIYDINZTGI3DS:1576675694:78a6c8bac243e2744c&api=1&no_preview=1',
#          'date': 1574678630,
#          'type': 3,
#          'preview': {'photo': {'sizes': [{'src': 'https://sun9-11.userapi.com/c856416/u213287907/d5/-3/m_af312816c8.jpg',
#              'width': 130,
#              'height': 100,
#              'type': 'm'},
#             {'src': 'https://sun9-25.userapi.com/c856416/u213287907/d5/-3/s_af312816c8.jpg',
#              'width': 100,
#              'height': 75,
#              'type': 's'},
#             {'src': 'https://sun9-28.userapi.com/c856416/u213287907/d5/-3/x_af312816c8.jpg',
#              'width': 604,
#              'height': 604,
#              'type': 'x'},
#             {'src': 'https://sun9-67.userapi.com/c856416/u213287907/d5/-3/y_af312816c8.jpg',
#              'width': 807,
#              'height': 807,
#              'type': 'y'},
#             {'src': 'https://sun9-66.userapi.com/c856416/u213287907/d5/-3/o_af312816c8.jpg',
#              'width': 800,
#              'height': 800,
#              'type': 'o'},
#             {'src': 'https://sun9-67.userapi.com/impc/c856416/u213287907/d5/-3/y_af312816c8.jpg?size=288x288&quality=90&sign=400cb5cb828d7121b221d2ea344265e0',
#              'width': 288,
#              'height': 288,
#              'type': 'i'},
#             {'src': 'https://sun9-67.userapi.com/impc/c856416/u213287907/d5/-3/y_af312816c8.jpg?size=192x192&quality=90&sign=8f017fcb5b634eb4630e0d93ad9ea45f',
#              'width': 192,
#              'height': 192,
#              'type': 'd'}]},
#           'video': {'src': 'https://vk.com/doc213287907_524983176?hash=7e4b18765b879e9c20&dl=GIYDINZTGI3DS:1576675694:78a6c8bac243e2744c&api=1&mp4=1',
#            'width': 800,
#            'height': 800,
#            'file_size': 318991}},
#          'access_key': 'fdcf449fd16998de1c'}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 4757},
#     'is_favorite': False},
#    {'id': 33011,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1574752946,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 560,
#       'owner_id': -78620921,
#       'from_id': -78620921,
#       'date': 1574330092,
#       'post_type': 'post',
#       'text': '5-часовой хакатон от МТС\n \n🔴Стань участником соревнования и получи возможность попасть в команду МТС! \n \n🔺Дата: 7 декабря 2019 \n🔺Место: Дом Правительства Московской области (бул. Строителей, 1, Красногорск) \nПодробная информация и регистрация: https://mosrobot2019.ru/ \n \n🔴В этом году Форум посвящен развитию робототехники и станет дискуссионной и выставочной площадкой в сфере инноваций для лучших молодых инноваторов, предпринимателей, ученых, робототехников, а также представителей ведущих научных школ и инновационных лабораторий Подмосковья. \n \nРегистрация открытыпо ссылке https://rusinnovations.timepad.ru/event/1112112/ до 29.11. \nУспей принять участие!\n\n#mts #АИР #москва #хакатон #московскаяобласть #It',
#       'attachments': [{'type': 'link',
#         'link': {'url': 'https://mosrobot2019.ru',
#          'title': 'Московский областной молодежный форум инноваций и предпринимательства',
#          'caption': 'mosrobot2019.ru',
#          'description': 'Московский областной молодежный форум инноваций и предпринимательства',
#          'photo': {'id': 457283968,
#           'album_id': -28,
#           'owner_id': 2000012434,
#           'sizes': [{'type': 'a',
#             'url': 'https://sun9-8.userapi.com/c858432/v858432978/f18f6/Lv1epT1sP48.jpg',
#             'width': 200,
#             'height': 89},
#            {'type': 'b',
#             'url': 'https://sun9-51.userapi.com/c858432/v858432978/f18f4/qUl93GOPqzQ.jpg',
#             'width': 400,
#             'height': 179},
#            {'type': 'c',
#             'url': 'https://sun9-49.userapi.com/c858432/v858432978/f18f8/xHU3_HKMVjY.jpg',
#             'width': 200,
#             'height': 200},
#            {'type': 'd',
#             'url': 'https://sun9-33.userapi.com/c858432/v858432978/f18f9/19EGm3OpQBU.jpg',
#             'width': 100,
#             'height': 100},
#            {'type': 'e',
#             'url': 'https://sun9-29.userapi.com/c858432/v858432978/f18fa/tol9l793qN8.jpg',
#             'width': 50,
#             'height': 50},
#            {'type': 'k',
#             'url': 'https://sun9-7.userapi.com/c858432/v858432978/f18f5/y1twmu2EhZs.jpg',
#             'width': 1073,
#             'height': 480},
#            {'type': 'l',
#             'url': 'https://sun9-17.userapi.com/c858432/v858432978/f18f7/sfIxMs1SsTw.jpg',
#             'width': 537,
#             'height': 240},
#            {'type': 'o',
#             'url': 'https://sun9-41.userapi.com/c858432/v858432978/f18f3/6-CGzG2LBsM.jpg',
#             'width': 751,
#             'height': 336}],
#           'text': '',
#           'date': 1574330092},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 3305},
#     'is_favorite': False},
#    {'id': 33009,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1574405668,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 2359,
#       'owner_id': -89765286,
#       'from_id': -89765286,
#       'date': 1574234988,
#       'post_type': 'post',
#       'text': 'День школьника на ФБМ \n\nУважаемые школьники! \n8 декабря 2019 года у вас будет уникальная возможность окунуться в студенческую жизнь образовательных программ направления «Бизнес-информатика». \n📆8 декабря (воскресенье)\n⌚11:00 – 15:00 \n🏢Факультет бизнеса и менеджмента НИУ ВШЭ, ул. Шаболовка, д. 26, аудитория К10 и другие\n\nРегистрация: https://vk.cc/a2MW6Y',
#       'attachments': [{'type': 'link',
#         'link': {'url': 'https://bi.hse.ru/announcements/318449443.html',
#          'title': 'День Школьника на образовательной программе «Бизнес-информатика»',
#          'caption': 'bi.hse.ru',
#          'description': '',
#          'photo': {'id': 457285836,
#           'album_id': -27,
#           'owner_id': 2000011625,
#           'sizes': [{'type': 'a',
#             'url': 'https://sun9-9.userapi.com/c854324/v854324137/179679/okGbTbBMpvI.jpg',
#             'width': 200,
#             'height': 90},
#            {'type': 'b',
#             'url': 'https://sun9-66.userapi.com/c854324/v854324137/179677/oDUOAqxt0us.jpg',
#             'width': 400,
#             'height': 179},
#            {'type': 'c',
#             'url': 'https://sun9-7.userapi.com/c854324/v854324137/17967b/UFEKTHaJDRI.jpg',
#             'width': 200,
#             'height': 200},
#            {'type': 'd',
#             'url': 'https://sun9-64.userapi.com/c854324/v854324137/17967c/vJBGLUTtvC0.jpg',
#             'width': 100,
#             'height': 100},
#            {'type': 'e',
#             'url': 'https://sun9-17.userapi.com/c854324/v854324137/17967d/2mVnJf42lfw.jpg',
#             'width': 50,
#             'height': 50},
#            {'type': 'k',
#             'url': 'https://sun9-60.userapi.com/c854324/v854324137/179678/Q_snUOUOjG0.jpg',
#             'width': 1070,
#             'height': 480},
#            {'type': 'l',
#             'url': 'https://sun9-50.userapi.com/c854324/v854324137/17967a/gyV3Nvo1Wl0.jpg',
#             'width': 537,
#             'height': 240},
#            {'type': 'o',
#             'url': 'https://sun9-36.userapi.com/c854324/v854324137/179676/j8RDt4ZmRe4.jpg',
#             'width': 896,
#             'height': 402}],
#           'text': '',
#           'date': 1574234988},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 7, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 2, 'user_reposted': 0},
#     'views': {'count': 4335},
#     'is_favorite': False},
#    {'id': 33007,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1574249632,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Приглашает бизнес-информатика!',
#     'copy_history': [{'id': 2359,
#       'owner_id': -89765286,
#       'from_id': -89765286,
#       'date': 1574234988,
#       'post_type': 'post',
#       'text': 'День школьника на ФБМ \n\nУважаемые школьники! \n8 декабря 2019 года у вас будет уникальная возможность окунуться в студенческую жизнь образовательных программ направления «Бизнес-информатика». \n📆8 декабря (воскресенье)\n⌚11:00 – 15:00 \n🏢Факультет бизнеса и менеджмента НИУ ВШЭ, ул. Шаболовка, д. 26, аудитория К10 и другие\n\nРегистрация: https://vk.cc/a2MW6Y',
#       'attachments': [{'type': 'link',
#         'link': {'url': 'https://bi.hse.ru/announcements/318449443.html',
#          'title': 'День Школьника на образовательной программе «Бизнес-информатика»',
#          'caption': 'bi.hse.ru',
#          'description': '',
#          'photo': {'id': 457285836,
#           'album_id': -27,
#           'owner_id': 2000011625,
#           'sizes': [{'type': 'a',
#             'url': 'https://sun9-9.userapi.com/c854324/v854324137/179679/okGbTbBMpvI.jpg',
#             'width': 200,
#             'height': 90},
#            {'type': 'b',
#             'url': 'https://sun9-66.userapi.com/c854324/v854324137/179677/oDUOAqxt0us.jpg',
#             'width': 400,
#             'height': 179},
#            {'type': 'c',
#             'url': 'https://sun9-7.userapi.com/c854324/v854324137/17967b/UFEKTHaJDRI.jpg',
#             'width': 200,
#             'height': 200},
#            {'type': 'd',
#             'url': 'https://sun9-64.userapi.com/c854324/v854324137/17967c/vJBGLUTtvC0.jpg',
#             'width': 100,
#             'height': 100},
#            {'type': 'e',
#             'url': 'https://sun9-17.userapi.com/c854324/v854324137/17967d/2mVnJf42lfw.jpg',
#             'width': 50,
#             'height': 50},
#            {'type': 'k',
#             'url': 'https://sun9-60.userapi.com/c854324/v854324137/179678/Q_snUOUOjG0.jpg',
#             'width': 1070,
#             'height': 480},
#            {'type': 'l',
#             'url': 'https://sun9-50.userapi.com/c854324/v854324137/17967a/gyV3Nvo1Wl0.jpg',
#             'width': 537,
#             'height': 240},
#            {'type': 'o',
#             'url': 'https://sun9-36.userapi.com/c854324/v854324137/179676/j8RDt4ZmRe4.jpg',
#             'width': 896,
#             'height': 402}],
#           'text': '',
#           'date': 1574234988},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 5245},
#     'is_favorite': False},
#    {'id': 33006,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1573854486,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '🍀Приходите на эко-фестиваль «Клеверок» от Зеленой Вышки в воскресенье, 17 ноября!🍀 \n \nНа фестивале выступят спикеры из Экологического движения «РазДельный Сбор» , ГК "ЭкоТехнологии", Repleo_zerowaste, ECOCUP Film Festival, БВШД и РосЭко, а также пройдет мастер-класс по росписи сумок. \nНиже вы можете ознакомиться с расписанием фестиваля: \n \n✔13:00 "Внедрение раздельного сбора отходов в России. Опыт ГК ЭкоТехнологии." - Елена Баранова \n✔13:40 "Искусство и экология" - Валерия Колтунова \n✔14:20 "Концепция «ноль отходов» в теории и на практике." - Анна Расторгуева \n✔15:00 "Раздельный сбор: как начать?" - Луферова Александра \n✔15:40 "Актуальные вопросы климата и экологии в журналистике." - Наталья Парамонова \n✔16:20 "Гид по экологичной жизни в мегаполисе: Полный спектр экологичного образа жизни." - Анна Кочегар и Михаил Антонов \n \n17:00 – 19:00 Мастер-класс по росписи сумок. \n \n🎨 В течение всего фестиваля можно будет посетить выставку работ художников Британской Высшей Школы Дизайна, которые вы сможете приобрести. Часть вырученных средств пойдет на благотворительность. \n \n📍Фестиваль пройдет в «БуквоДом» в парке «Сокольники» . \n \nЗарегистрироваться на отдельные лекции и мастер-класс вы сможете на сайте Букводома - https://vk.cc/9CVmi2 \nЕсли хотите посетить все лекции и мастер-класс, то можете регистрироваться по ссылке - https://vk.cc/a0HbNv \nЕсли же собираетесь прийти на несколько лекций или одну, просим регистрироваться отдельно на конкретное мероприятие.',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://bookvodom.moscow/events',
#        'title': 'Букводом',
#        'caption': 'bookvodom.moscow',
#        'description': '',
#        'photo': {'id': 457276433,
#         'album_id': -28,
#         'owner_id': 2000010409,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun9-31.userapi.com/c854320/v854320521/1664ff/S6FZ_sp8U6I.jpg',
#           'width': 130,
#           'height': 81},
#          {'type': 'p',
#           'url': 'https://sun9-3.userapi.com/c854320/v854320521/166501/Ohbln9QCpTU.jpg',
#           'width': 260,
#           'height': 163},
#          {'type': 's',
#           'url': 'https://sun9-61.userapi.com/c854320/v854320521/1664fe/VayDfROVi8Q.jpg',
#           'width': 75,
#           'height': 47},
#          {'type': 'x',
#           'url': 'https://sun9-23.userapi.com/c854320/v854320521/166500/WBB8VpPX628.jpg',
#           'width': 150,
#           'height': 94}],
#         'text': '',
#         'date': 1573854486},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
# ...
#            'width': 604,
#            'height': 293},
#           {'type': 'y',
#            'url': 'https://sun9-33.userapi.com/c845217/v845217590/1b9f6f/c3kIVRywlGk.jpg',
#            'width': 807,
#            'height': 391},
#           {'type': 'z',
#            'url': 'https://sun9-10.userapi.com/c845217/v845217590/1b9f70/kazZsJmx2o4.jpg',
#            'width': 960,
#            'height': 465}],
#          'text': '',
#          'date': 1551438179,
#          'access_key': '2ccf21ddf6bb737360'}},
#        {'type': 'doc',
#         'doc': {'id': 492709378,
#          'owner_id': -108877455,
#          'title': 'Программа конференции.pdf',
#          'size': 919302,
#          'ext': 'pdf',
#          'url': 'https://vk.com/doc-108877455_492709378?hash=2c58c4e758137c506f&dl=GIYDINZTGI3DS:1576675694:c469df9dc5294f04d7&api=1&no_preview=1',
#          'date': 1551436400,
#          'type': 1,
#          'access_key': 'f365ede2267da076ef'}},
#        {'type': 'doc',
#         'doc': {'id': 492619501,
#          'owner_id': -108877455,
#          'title': 'Критерии статей 2019.pdf',
#          'size': 202921,
#          'ext': 'pdf',
#          'url': 'https://vk.com/doc-108877455_492619501?hash=13872f034d3068cf55&dl=GIYDINZTGI3DS:1576675694:27df49c5b5827280f3&api=1&no_preview=1',
#          'date': 1551363033,
#          'type': 1,
#          'access_key': 'ee2b49141822fc8a81'}}],
#       'post_source': {'type': 'api', 'platform': 'iphone'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 11, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 3, 'user_reposted': 0},
#     'views': {'count': 8160},
#     'is_favorite': False},
#    {'id': 32623,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1553244602,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'В лицее НИУ ВШЭ: https://nnov.hse.ru/management/announcements/251447629.html',
#     'copy_history': [{'id': 268,
#       'owner_id': -170789907,
#       'from_id': -170789907,
#       'date': 1552150140,
#       'post_type': 'post',
#       'text': 'Добрый вечер, воители и поэты!\nВеликий сёгун скончался, и мы должны незамедлительно отправиться в столицу... на встречу по японской истории.\n🈴🎎\nЯпония, 1358 год. Асикага Такаудзи умер, оставив наследнику раздираемую междоусобицей страну, своенравных вассалов и очаги восстаний в отдалённых провинциях. \n\n🔶 Как встретят японские разбойники корейских послов?\n🔶 Чем ответят мятежники на вторжение самураев?\n🔶 Закончит ли Ёсиакира дело отца? \n🔶 Что на самом деле означает быть сёгуном?\n\nА также охота генерала Хосокава за собственным братом, предательство самых верных сторонников Южного Двора и биографические справки о ключевых деятелях эпохи.\n\n— на лекции в субботу 23 марта 15:30 - 17:30 — \n\nНа этот раз к чаю будут печеньки, зарегистрировавшимся участникам мы заранее вышлем доступ к материалам на ГуглДиске, и видео-введение в тему будет заранее записано.\n\n🇯🇵 Для участия необходимо\n(1) зарегистрироваться в форме по ссылке \ndocs.google.com/forms/d/1YVI6uFK5IdI55tZnqIr92O_ohwj4ol1LsBHObPeudKc \n\n(2) лайкнуть этот пост (тогда мы пришлём вам дополнительную информацию и ответим на интересующие вопросы)\n\n(3) > взять паспорт / свидетельство о рождении и прийти в Лицей НИУ ВШЭ по адресу переулок Лялин, дом 3А, аудитория 204 (2 этаж) \nили \n> установить приложение Zoom и подключиться дистанционно по ссылке zoom.us/j/172123665 \n\n(4) если лекция окажется ценной для вас, подумать над тем, чтобы поддержать наш проект финансово :) будем вам весьма благодарны!\n\n😌 К вашим услугам, \nкоманда проекта "Повесть об Императоре"\nvk.com/topic-170789907_42555052',
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 456239712,
#          'album_id': -7,
#          'owner_id': -170789907,
#          'user_id': 100,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun9-29.userapi.com/c846218/v846218585/1bf416/BZkOvC6TvsM.jpg',
#            'width': 90,
#            'height': 130},
#           {'type': 'o',
#            'url': 'https://sun9-54.userapi.com/c846218/v846218585/1bf41a/-N8Fm58K6Ro.jpg',
#            'width': 130,
#            'height': 188},
#           {'type': 'p',
#            'url': 'https://sun9-63.userapi.com/c846218/v846218585/1bf41b/w9v8lpFdaJs.jpg',
#            'width': 200,
#            'height': 290},
#           {'type': 'q',
#            'url': 'https://sun9-71.userapi.com/c846218/v846218585/1bf41c/S7d06ngwZM4.jpg',
#            'width': 320,
#            'height': 464},
#           {'type': 'r',
#            'url': 'https://sun9-56.userapi.com/c846218/v846218585/1bf41d/14OgnzU3f44.jpg',
#            'width': 510,
#            'height': 739},
#           {'type': 's',
#            'url': 'https://sun9-21.userapi.com/c846218/v846218585/1bf415/OJa7q234hz8.jpg',
#            'width': 52,
#            'height': 75},
#           {'type': 'x',
#            'url': 'https://sun9-19.userapi.com/c846218/v846218585/1bf417/2jAjios657Y.jpg',
#            'width': 417,
#            'height': 604},
#           {'type': 'y',
#            'url': 'https://sun9-8.userapi.com/c846218/v846218585/1bf418/qesVndBkPAQ.jpg',
#            'width': 557,
#            'height': 807},
#           {'type': 'z',
#            'url': 'https://sun9-19.userapi.com/c846218/v846218585/1bf419/NNzYhb2FAM0.jpg',
#            'width': 745,
#            'height': 1080}],
#          'text': '',
#          'date': 1552036994,
#          'access_key': '370f5ee98ece1e54e3'}},
#        {'type': 'link',
#         'link': {'url': 'http://docs.google.com/forms/d/1YVI6uFK5IdI55tZnqIr92O_ohwj4ol1LsBHObPeudKc',
#          'title': 'лекция "Ёсиакира - второй сёгун Асикага"',
#          'description': 'Здравствуйте! Если Вы идёте на наше событие пешком, всё не так просто, как кажется)  Стоит пройти эту небольшую анкету и принести с собой паспорт, чтобы пройти в Лицей НИУ ВШЭ.',
#          'target': 'internal',
#          'photo': {'id': 456260987,
#           'album_id': -26,
#           'owner_id': 2000012214,
#           'sizes': [{'type': 'm',
#             'url': 'https://sun9-36.userapi.com/c850132/v850132254/fb30c/t2jiFlMyAjc.jpg',
#             'width': 130,
#             'height': 130},
#            {'type': 'p',
#             'url': 'https://sun9-36.userapi.com/c850132/v850132254/fb30e/IepPvhUZftM.jpg',
#             'width': 260,
#             'height': 260},
#            {'type': 's',
#             'url': 'https://sun9-62.userapi.com/c850132/v850132254/fb30b/3OBU3bEgIpM.jpg',
#             'width': 75,
#             'height': 75},
#            {'type': 'x',
#             'url': 'https://sun9-60.userapi.com/c850132/v850132254/fb30d/wF9kYY6C4Ds.jpg',
#             'width': 150,
#             'height': 150}],
#           'text': '',
#           'date': 1552036994},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 7777},
#     'is_favorite': False},
#    {'id': 32622,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1553244286,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 324,
#       'owner_id': -108877455,
#       'from_id': -108877455,
#       'date': 1552659898,
#       'post_type': 'post',
#       'text': '🔥 У нас замечательная новость! Регистрация на кейс от Unilever открыта!\n\n💡 Наш партнер компания Unilever проведет кейс-чемпионат в рамках конференции по управлению проектами НИУ ВШЭ. Тебе и твоей команде предстоит запустить проект, для чего вам потребуются не только знания по УП, но и по маркетингу и финансам.\n\n🏆 Соревнование пройдет 30 мая, а победители получат фаст-трек на финальный этап отбора на летнюю стажировку в Unilever, а также подарки от компании!\n\n🎯 Если ты студент со специальностью маркетинг, менеджмент или экономика, то срочно регистрируйся тут: https://docs.google.com/forms/d/e/1FAIpQLSd2c8zTbwdVCKvthcjxlK4C8SrXLlwSRBgqEpD-gz3xroz5lQ/viewform\n\n🏁 Зови друзей и собирай свою команду из 3-4 человек. Не забудьте зарегистрировать каждого! Если у тебя нет команды, найти единомышленников можно здесь: https://vk.com/topic-108877455_39901339 \n\n⏰ Не забудь: \nПодать заявку до 29 марта\nА также регистрируйся и приходи на нашу конференцию! https://vk.com/wall-108877455_318',
#       'attachments': [{'type': 'photo',
#         'photo': {'id': 456239389,
#          'album_id': -7,
#          'owner_id': -108877455,
#          'user_id': 100,
#          'sizes': [{'type': 'm',
#            'url': 'https://sun9-58.userapi.com/c848736/v848736827/157d2a/0P3ZPISuFmY.jpg',
#            'width': 130,
#            'height': 63},
#           {'type': 'o',
#            'url': 'https://sun9-39.userapi.com/c848736/v848736827/157d2f/lty92RrRt04.jpg',
#            'width': 130,
#            'height': 87},
#           {'type': 'p',
#            'url': 'https://sun9-35.userapi.com/c848736/v848736827/157d30/I-Qrnb1B6G8.jpg',
#            'width': 200,
#            'height': 133},
#           {'type': 'q',
#            'url': 'https://sun9-51.userapi.com/c848736/v848736827/157d31/EubO-iEoGsc.jpg',
#            'width': 320,
#            'height': 213},
#           {'type': 'r',
#            'url': 'https://sun9-58.userapi.com/c848736/v848736827/157d32/t6dEmFr8ut8.jpg',
#            'width': 510,
#            'height': 340},
#           {'type': 's',
#            'url': 'https://sun9-25.userapi.com/c848736/v848736827/157d29/FW6FEd8RPP8.jpg',
#            'width': 75,
#            'height': 36},
#           {'type': 'w',
#            'url': 'https://sun9-21.userapi.com/c848736/v848736827/157d2e/ccgMyMzh8ac.jpg',
#            'width': 2560,
#            'height': 1243},
#           {'type': 'x',
#            'url': 'https://sun9-69.userapi.com/c848736/v848736827/157d2b/SCDGeQu9T6s.jpg',
#            'width': 604,
#            'height': 293},
#           {'type': 'y',
#            'url': 'https://sun9-9.userapi.com/c848736/v848736827/157d2c/J7e_z2S0RMQ.jpg',
#            'width': 807,
#            'height': 392},
#           {'type': 'z',
#            'url': 'https://sun9-41.userapi.com/c848736/v848736827/157d2d/l0-h__yCEBw.jpg',
#            'width': 1280,
#            'height': 621}],
#          'text': '',
#          'date': 1552659898,
#          'post_id': 324,
#          'access_key': '4c17a90a0ac78fd226'}},
#        {'type': 'link',
#         'link': {'url': 'https://docs.google.com/forms/d/e/1FAIpQLSd2c8zTbwdVCKvthcjxlK4C8SrXLlwSRBgqEpD-gz3xroz5lQ/viewform',
#          'title': 'Регистрация на кейс-чемпионат от компании Unilever',
#          'description': 'Регистрируйся сам и собирай команду из 3 или 4 человек! Найти единомышленников можно в обсуждении группы HSEPMCONF`19 VK. Если после окончания регистрации 29 марта состав твоей команды будет неполным, то мы поможем найти тебе команду.',
#          'target': 'internal',
#          'photo': {'id': 456266185,
#           'album_id': -26,
#           'owner_id': 2000015121,
#           'sizes': [{'type': 'k',
#             'url': 'https://sun9-24.userapi.com/c844521/v844521783/1cc5b7/2l3II5D6uRs.jpg',
#             'width': 1074,
#             'height': 480},
#            {'type': 'l',
#             'url': 'https://sun9-15.userapi.com/c844521/v844521783/1cc5b6/AIxqq-abs1M.jpg',
#             'width': 537,
#             'height': 240},
#            {'type': 'm',
#             'url': 'https://sun9-71.userapi.com/c844521/v844521783/1cc5b3/rirgJStwqrQ.jpg',
#             'width': 130,
#             'height': 70},
#            {'type': 'p',
#             'url': 'https://sun9-34.userapi.com/c844521/v844521783/1cc5b5/YMkgqecz73w.jpg',
#             'width': 260,
#             'height': 140},
#            {'type': 's',
#             'url': 'https://sun9-55.userapi.com/c844521/v844521783/1cc5b2/6wlfrh-vidg.jpg',
#             'width': 75,
#             'height': 39},
#            {'type': 'x',
#             'url': 'https://sun9-63.userapi.com/c844521/v844521783/1cc5b4/q65SVaziqd0.jpg',
#             'width': 150,
#             'height': 80}],
#           'text': '',
#           'date': 1552660311},
#          'is_favorite': False}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 6231},
#     'is_favorite': False},
#    {'id': 32621,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1553244139,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ВШЭ Нижний Новгород: https://nnov.hse.ru/management/announcements/251447629.html',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://nnov.hse.ru/management/announcements/251447629.html',
#        'title': 'Конференция "Бизнес-тренды: цифровые технологии в менеджменте"',
#        'caption': 'nnov.hse.ru',
#        'description': '',
#        'photo': {'id': 456267814,
#         'album_id': -25,
#         'owner_id': 2000017245,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun9-46.userapi.com/c850136/v850136551/10a35d/zoY55jVFUBQ.jpg',
#           'width': 130,
#           'height': 68},
#          {'type': 'p',
#           'url': 'https://sun9-64.userapi.com/c850136/v850136551/10a35f/TYakus-B9Ks.jpg',
#           'width': 260,
#           'height': 136},
#          {'type': 's',
#           'url': 'https://sun9-40.userapi.com/c850136/v850136551/10a35c/3TtGjqwhvWU.jpg',
#           'width': 75,
#           'height': 39},
#          {'type': 'x',
#           'url': 'https://sun9-56.userapi.com/c850136/v850136551/10a35e/qW-0hAqI5_s.jpg',
#           'width': 150,
#           'height': 78}],
#         'text': '',
#         'date': 1553023011},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 5508},
#     'is_favorite': False},
#    {'id': 32620,
#     'from_id': -132,
#     'owner_id': -132,
#     'date': 1553243861,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Шухов Лаб приглашает: https://www.hse.ru/ma/techcity/announcements/251438808.html',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://www.hse.ru/ma/techcity/announcements/251438808.html',
#        'title': 'Воркшоп «Проектирование интерактивных общественных пространств»',
#        'caption': 'www.hse.ru',
#        'description': '',
#        'photo': {'id': 456264055,
#         'album_id': -27,
#         'owner_id': 2000019150,
#         'sizes': [{'type': 'k',
#           'url': 'https://sun9-54.userapi.com/c856016/v856016966/a14d/3AAJqocrpmI.jpg',
#           'width': 1074,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-22.userapi.com/c856016/v856016966/a14c/UnvAbIZIyDg.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'm',
#           'url': 'https://sun9-21.userapi.com/c856016/v856016966/a149/MpfWBW_XvXI.jpg',
#           'width': 130,
#           'height': 92},
#          {'type': 'p',
#           'url': 'https://sun9-62.userapi.com/c856016/v856016966/a14b/2rceSe2pezQ.jpg',
#           'width': 260,
#           'height': 184},
#          {'type': 's',
#           'url': 'https://sun9-52.userapi.com/c856016/v856016966/a148/OkzXasB8nTU.jpg',
#           'width': 75,
#           'height': 53},
#          {'type': 'x',
#           'url': 'https://sun9-31.userapi.com/c856016/v856016966/a14a/6B0iiWBK2rs.jpg',
#           'width': 150,
#           'height': 106}],
#         'text': '',
#         'date': 1553243861},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 5397},
#     'is_favorite': False}]}}

# %%
res = data['response']['items'] 
res
# Out:
# [{'id': 33029,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971849,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Что меня огорчает',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://www.hse.ru/our/news/323346844.html',
#      'title': 'Что меня огорчает',
#      'caption': 'www.hse.ru',
#      'description': 'Авторская колонка первого проректора Вадима Радаева',
#      'photo': {'id': 457289885,
#       'album_id': -26,
#       'owner_id': 2000021743,
#       'sizes': [{'type': 'k',
#         'url': 'https://sun9-71.userapi.com/c858024/v858024349/120e4c/to-wJyYBh9w.jpg',
#         'width': 1000,
#         'height': 480},
#        {'type': 'l',
#         'url': 'https://sun9-32.userapi.com/c858024/v858024349/120e4b/jvKn7gctoWs.jpg',
#         'width': 537,
#         'height': 240},
#        {'type': 'm',
#         'url': 'https://sun9-12.userapi.com/c858024/v858024349/120e48/c9FrIN8g3F0.jpg',
#         'width': 130,
#         'height': 87},
#        {'type': 'p',
#         'url': 'https://sun9-5.userapi.com/c858024/v858024349/120e4a/k4mOW6y9DRM.jpg',
#         'width': 260,
#         'height': 173},
#        {'type': 's',
#         'url': 'https://sun9-19.userapi.com/c858024/v858024349/120e47/Wr__bx8GuTU.jpg',
#         'width': 75,
#         'height': 50},
#        {'type': 'x',
#         'url': 'https://sun9-44.userapi.com/c858024/v858024349/120e49/p6wvV7kAM9Y.jpg',
#         'width': 150,
#         'height': 100}],
#       'text': '',
#       'date': 1575971849},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 12, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 6670},
#   'is_favorite': False},
#  {'id': 33028,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971665,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 400,
#     'owner_id': -130374393,
#     'from_id': -130374393,
#     'date': 1575887795,
#     'post_type': 'post',
#     'text': 'Дорогие друзья, мы рады сообщить вам, что совсем скоро 20 декабря в 19.00 состоится наш отчётный новогодний концерт! 🎶🎻\n\nНа нем прозвучат произведения Вивальди, Бизе и Манчини. Также в этот раз вы услышите много новых музыкальных сюрпризов, от которых непременно появится новогоднее настроение! \nПоэтому настраивайтесь на праздник вместе с нами🎄🎄🎄\nПредварительно нужно зарегистрироваться по ссылке ниже:\n\nhttps://hse-orchestra.timepad.ru/event/1138504/\n\nМы будем рады видеть вас, до встречи на концерте! 🎶',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 457240910,
#        'album_id': -5,
#        'owner_id': 54934019,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun1-90.userapi.com/c857032/v857032770/7c35d/8foQmQIBRW8.jpg',
#          'width': 87,
#          'height': 130},
#         {'type': 'o',
#          'url': 'https://sun1-85.userapi.com/c857032/v857032770/7c362/4N_U_ITamgw.jpg',
#          'width': 130,
#          'height': 193},
#         {'type': 'p',
#          'url': 'https://sun1-26.userapi.com/c857032/v857032770/7c363/_h7knU4Ll8s.jpg',
#          'width': 200,
#          'height': 298},
#         {'type': 'q',
#          'url': 'https://sun1-30.userapi.com/c857032/v857032770/7c364/PX4I-Dv8JCQ.jpg',
#          'width': 320,
#          'height': 477},
#         {'type': 'r',
#          'url': 'https://sun1-87.userapi.com/c857032/v857032770/7c365/ZNjvi6JunVE.jpg',
#          'width': 510,
#          'height': 760},
#         {'type': 's',
#          'url': 'https://sun1-23.userapi.com/c857032/v857032770/7c35c/Dw67WpDy-vM.jpg',
#          'width': 50,
#          'height': 75},
#         {'type': 'w',
#          'url': 'https://sun1-91.userapi.com/c857032/v857032770/7c361/WBYDsfz0u88.jpg',
#          'width': 1080,
#          'height': 1609},
#         {'type': 'x',
#          'url': 'https://sun1-15.userapi.com/c857032/v857032770/7c35e/UnDmHjUu8e8.jpg',
#          'width': 406,
#          'height': 604},
#         {'type': 'y',
#          'url': 'https://sun1-92.userapi.com/c857032/v857032770/7c35f/EODELCzNfqQ.jpg',
#          'width': 542,
#          'height': 807},
#         {'type': 'z',
#          'url': 'https://sun1-27.userapi.com/c857032/v857032770/7c360/0F5BAhbbsEc.jpg',
#          'width': 725,
#          'height': 1080}],
#        'text': '',
#        'date': 1575887739,
#        'access_key': '01b15709d9de007646'}},
#      {'type': 'link',
#       'link': {'url': 'https://hse-orchestra.timepad.ru/event/1138504/',
#        'title': 'Концерт Симфонического Оркестра НИУ ВШЭ / События на TimePad.ru',
#        'description': 'На Новогоднем Концерте Оркестра ВШЭ прозвучат Вивальди, Бизе, Штраус, Манчини, Рота и Циммер!',
#        'target': 'internal',
#        'is_favorite': False}}],
#     'post_source': {'type': 'mvk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 14, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 2, 'user_reposted': 0},
#   'views': {'count': 3503},
#   'is_favorite': False},
#  {'id': 33027,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971625,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 95,
#     'owner_id': -185974612,
#     'from_id': -185974612,
#     'date': 1575640597,
#     'post_type': 'post',
#     'text': 'Сидели в перерыве, ели KitKat и изучали прогноз погоды на следующую неделю. Казалось бы, о чем можно написать пост с такой предпосылкой? Но все не так просто.\n\n12 декабря ночью обещают -4. Вот мы и подумали, что самое время провести четвёртую КЦшную встречу! В четверг в 18:30 к нам придёт Виктория Сидякина, корпоративный директор по работе с персоналом «Нестле Россия и Евразия», другими словами, выходим на мировой масштаб!\n\n— Вот это тема! – скажете вы\n— Вот это тема: «Nestlé - one of the five most beloved brands in the world: что это значит?» – ответим мы. \n\nЗачем мне это?\nВсе логично: Вышка – лучший ВУЗ, в лучшем ВУЗе – умные студенты, умные студенты – крутая работа, крутая работа – у одного из лучших работодателей мира, да что мира - России, а один из лучших работодателей России как раз по счастливой случайности будет у нас в КЦ!\n\nРезюмируем:\nЧто: КЦшная встреча\nКогда: 12 декабря в 18:30\nГде: Малый зал КЦ\nКто: Крутой спикер\nСсылка на регистрацию: https://hse-cc-event.timepad.ru/event/1136608/\n\nЗапомнили, закрепили, зарегистрировались. Если что, ориентируйтесь на прогноз погоды!',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 457239438,
#        'album_id': -7,
#        'owner_id': -185974612,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun1-20.userapi.com/c200424/v200424247/339a/0qqpo-RUP0Y.jpg',
#          'width': 130,
#          'height': 73},
#         {'type': 'o',
#          'url': 'https://sun1-91.userapi.com/c200424/v200424247/339e/_jqL2HvqPi8.jpg',
#          'width': 130,
#          'height': 87},
#         {'type': 'p',
#          'url': 'https://sun1-20.userapi.com/c200424/v200424247/339f/XgVRewaaPXo.jpg',
#          'width': 200,
#          'height': 133},
#         {'type': 'q',
#          'url': 'https://sun1-30.userapi.com/c200424/v200424247/33a0/oj5CQzIyg50.jpg',
#          'width': 320,
#          'height': 213},
#         {'type': 'r',
#          'url': 'https://sun1-83.userapi.com/c200424/v200424247/33a1/9-Ri3SJIUb4.jpg',
#          'width': 510,
#          'height': 340},
#         {'type': 's',
#          'url': 'https://sun1-22.userapi.com/c200424/v200424247/3399/7GrHTCxqjq0.jpg',
#          'width': 75,
#          'height': 42},
#         {'type': 'x',
#          'url': 'https://sun1-91.userapi.com/c200424/v200424247/339b/pvVu0oXFYAA.jpg',
#          'width': 604,
#          'height': 340},
#         {'type': 'y',
#          'url': 'https://sun1-22.userapi.com/c200424/v200424247/339c/gF4-YoB5-mo.jpg',
#          'width': 807,
#          'height': 454},
#         {'type': 'z',
#          'url': 'https://sun1-25.userapi.com/c200424/v200424247/339d/-sZpbB_nywM.jpg',
#          'width': 1280,
#          'height': 720}],
#        'text': '',
#        'date': 1575640597,
#        'access_key': '8e60811876e2b25d67'}},
#      {'type': 'link',
#       'link': {'url': 'https://hse-cc-event.timepad.ru/event/1136608/',
#        'title': 'КЦшная встреча с Директором по персоналу ООО «Нестле Россия» Викторией Сидякиной / События на TimePad.ru',
#        'description': 'КЦшная встреча с Директором по персоналу ООО «Нестле Россия» Викторией Сидякиной',
#        'target': 'internal',
#        'is_favorite': False}}],
#     'post_source': {'type': 'api', 'platform': 'iphone'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 2348},
#   'is_favorite': False},
#  {'id': 33026,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971586,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'attachments': [{'type': 'photo',
#     'photo': {'id': 457240210,
#      'album_id': -7,
#      'owner_id': -132,
#      'user_id': 100,
#      'sizes': [{'type': 'm',
#        'url': 'https://sun9-72.userapi.com/c850636/v850636606/dc5fd/yUoixGiKQ1I.jpg',
#        'width': 92,
#        'height': 130},
#       {'type': 'o',
#        'url': 'https://sun9-42.userapi.com/c850636/v850636606/dc602/dxdqbUycAM8.jpg',
#        'width': 130,
#        'height': 184},
#       {'type': 'p',
#        'url': 'https://sun9-46.userapi.com/c850636/v850636606/dc603/LhHYqsgF87U.jpg',
#        'width': 200,
#        'height': 283},
#       {'type': 'q',
#        'url': 'https://sun9-31.userapi.com/c850636/v850636606/dc604/022tztVC9wg.jpg',
#        'width': 320,
#        'height': 452},
#       {'type': 'r',
#        'url': 'https://sun9-26.userapi.com/c850636/v850636606/dc605/bW3Ewi8nDQA.jpg',
#        'width': 510,
#        'height': 721},
#       {'type': 's',
#        'url': 'https://sun9-7.userapi.com/c850636/v850636606/dc5fc/nCb5tRmBbAI.jpg',
#        'width': 53,
#        'height': 75},
#       {'type': 'w',
#        'url': 'https://sun9-20.userapi.com/c850636/v850636606/dc601/TbgJPS26UVQ.jpg',
#        'width': 906,
#        'height': 1280},
#       {'type': 'x',
#        'url': 'https://sun9-43.userapi.com/c850636/v850636606/dc5fe/0o6xI-diDbk.jpg',
#        'width': 427,
#        'height': 604},
#       {'type': 'y',
#        'url': 'https://sun9-15.userapi.com/c850636/v850636606/dc5ff/nLVoJPdYLX8.jpg',
#        'width': 571,
#        'height': 807},
#       {'type': 'z',
#        'url': 'https://sun9-71.userapi.com/c850636/v850636606/dc600/_An54EwTtRE.jpg',
#        'width': 764,
#        'height': 1080}],
#      'text': '',
#      'date': 1575971586,
#      'post_id': 33026,
#      'access_key': '6576089fc2c892cf61'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 9, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 1, 'user_reposted': 0},
#   'views': {'count': 5660},
#   'is_favorite': False},
#  {'id': 33025,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971433,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Вышка в прошлом году запустила новый проект, обеспечивающий социальный лифт детям из семей, попавших в сложные обстоятельства. Это те ребята, которые не подпадают под федеральные льготы, но между тем достойны поддержки. Финансирует проект университет. Так видит руководство вуза социальную ответственность университета перед обществом. Мы очень рады, что число участников проекта удвоится в 2020 году. https://www.hse.ru/news/admission/321757804.html',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://www.hse.ru/news/admission/321757804.html',
#      'title': 'Число участников программы «Социальный лифт» в 2020 году вырастет более чем в два раза',
#      'caption': 'www.hse.ru',
#      'description': 'Высшая школа экономики продолжит и расширит программу «Социальный лифт», в рамках которой в бакалавриат зачисляются вне конкурса абитуриенты, оказавшиеся в сложных жизненных обстоятельствах. Об этом 3 декабря было объявлено на круглом столе, посвященном благотворительности в высшем образовании.',
#      'photo': {'id': 457290253,
#       'album_id': -27,
#       'owner_id': 2000021717,
#       'sizes': [{'type': 'k',
#         'url': 'https://sun9-44.userapi.com/c857536/v857536902/11a602/ls6mstk95hs.jpg',
#         'width': 1074,
#         'height': 480},
#        {'type': 'l',
#         'url': 'https://sun9-12.userapi.com/c857536/v857536902/11a601/3KYePaHUXhA.jpg',
#         'width': 537,
#         'height': 240},
#        {'type': 'm',
#         'url': 'https://sun9-9.userapi.com/c857536/v857536902/11a5fe/wEK9aNIrTbY.jpg',
#         'width': 130,
#         'height': 87},
#        {'type': 'p',
#         'url': 'https://sun9-39.userapi.com/c857536/v857536902/11a600/S4vpNbLihE4.jpg',
#         'width': 260,
#         'height': 173},
#        {'type': 's',
#         'url': 'https://sun9-13.userapi.com/c857536/v857536902/11a5fd/a7HBY1JCB70.jpg',
#         'width': 75,
#         'height': 50},
#        {'type': 'x',
#         'url': 'https://sun9-62.userapi.com/c857536/v857536902/11a5ff/6_-8gIlXA6w.jpg',
#         'width': 150,
#         'height': 100}],
#       'text': '',
#       'date': 1575971433},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 9, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 2292},
#   'is_favorite': False},
#  {'id': 33024,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575971123,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Поздравляем! Основоположник "Русских хакеров" Максим Дьяков растит достойную смену. Новый состав студенческой организации успешно провел 7 декабря 12-часовой хакатон для новичков в Культурном центре НИУ ВШЭ на Покровке. https://www.hse.ru/news/edu/323373069.html',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://www.hse.ru/news/edu/323373069.html',
#      'title': 'Студенты Вышки заняли третье место на международном хакатоне Junction',
#      'caption': 'www.hse.ru',
#      'description': 'В этом году в масштабном мероприятии приняли участие 1500 участников из 100 стран. Команда студентов второго курса факультета компьютерных наук (Тимофей Смирнов, Игорь Законы и Айнур Нуриев) представила проект умного освещения.',
#      'photo': {'id': 457282109,
#       'album_id': -27,
#       'owner_id': 2000022491,
#       'sizes': [{'type': 'k',
#         'url': 'https://sun9-65.userapi.com/c206524/v206524513/9069/d3Gnd-Kpbfg.jpg',
#         'width': 800,
#         'height': 480},
#        {'type': 'l',
#         'url': 'https://sun9-39.userapi.com/c206524/v206524513/9068/4V1iYzC5i_U.jpg',
#         'width': 537,
#         'height': 240},
#        {'type': 'm',
#         'url': 'https://sun9-66.userapi.com/c206524/v206524513/9065/FERwd52dk7E.jpg',
#         'width': 130,
#         'height': 87},
#        {'type': 'p',
#         'url': 'https://sun9-25.userapi.com/c206524/v206524513/9067/OPDjvT81uew.jpg',
#         'width': 260,
#         'height': 173},
#        {'type': 's',
#         'url': 'https://sun9-20.userapi.com/c206524/v206524513/9064/SeHyYgJveNU.jpg',
#         'width': 75,
#         'height': 50},
#        {'type': 'x',
#         'url': 'https://sun9-50.userapi.com/c206524/v206524513/9066/r183RJKpO9Y.jpg',
#         'width': 150,
#         'height': 100}],
#       'text': '',
#       'date': 1575971123},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 8, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 3113},
#   'is_favorite': False},
#  {'id': 33023,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575970990,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Опубликованы решения Ученого совета по стоимости образовательных программ на 2020 год https://ba.hse.ru/icef#pagetop',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://ba.hse.ru/icef#pagetop',
#      'title': 'Стоимость обучения – 2020',
#      'caption': 'ba.hse.ru',
#      'description': '',
#      'photo': {'id': 457284290,
#       'album_id': -28,
#       'owner_id': 2000022257,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun1-16.userapi.com/c855416/v855416728/197d4c/oDLIdhsCgqs.jpg',
#         'width': 130,
#         'height': 68},
#        {'type': 'p',
#         'url': 'https://sun1-88.userapi.com/c855416/v855416728/197d4e/wpVKHsR54VQ.jpg',
#         'width': 260,
#         'height': 136},
#        {'type': 's',
#         'url': 'https://sun1-18.userapi.com/c855416/v855416728/197d4b/6f5q8GhzoU0.jpg',
#         'width': 75,
#         'height': 39},
#        {'type': 'x',
#         'url': 'https://sun1-27.userapi.com/c855416/v855416728/197d4d/b4ISXIaiRqc.jpg',
#         'width': 150,
#         'height': 78}],
#       'text': '',
#       'date': 1575969541},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 2552},
#   'is_favorite': False},
#  {'id': 33022,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575969388,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 3327,
#     'owner_id': -142774925,
#     'from_id': -142774925,
#     'date': 1575965580,
#     'post_type': 'post',
#     'text': 'Неужели всё-таки возможен вариант, что в будущем электроника полностью заменит силы человека? С новыми беспилотными курьерами, которые обещают осуществлять 80% доставок, этот вопрос больше не кажется мистическим ❗\n\n#инновационнаялогистика@popular_logistics \n#логистикараспределения@popular_logistics',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@-142774925-bespilotnye-letauschie-kurery-v-rossiiskih-gorodah-mogut-poy',
#        'title': '«Беспилотные летающие курьеры» в российских городах могут появиться через 3-4 года',
#        'caption': 'm.vk.com',
#        'description': 'Статья',
#        'photo': {'id': 457241446,
#         'album_id': -66,
#         'owner_id': -142774925,
#         'user_id': 100,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun9-23.userapi.com/c200524/v200524225/40aa/g0YUhHuAfMI.jpg',
#           'width': 130,
#           'height': 68},
#          {'type': 'o',
#           'url': 'https://sun9-47.userapi.com/c200524/v200524225/40ad/c4pIfmBWIzE.jpg',
#           'width': 130,
#           'height': 87},
#          {'type': 'p',
#           'url': 'https://sun9-11.userapi.com/c200524/v200524225/40ae/4Tps45cONeI.jpg',
#           'width': 200,
#           'height': 133},
#          {'type': 'q',
#           'url': 'https://sun9-44.userapi.com/c200524/v200524225/40af/msUMM8PetLs.jpg',
#           'width': 320,
#           'height': 213},
#          {'type': 'r',
#           'url': 'https://sun9-45.userapi.com/c200524/v200524225/40b0/t5WwAFT5NgA.jpg',
#           'width': 510,
#           'height': 319},
#          {'type': 's',
#           'url': 'https://sun9-56.userapi.com/c200524/v200524225/40a9/BYBlaMsSvH0.jpg',
#           'width': 75,
#           'height': 39},
#          {'type': 'x',
#           'url': 'https://sun9-60.userapi.com/c200524/v200524225/40ab/aQP2mCWZ37Q.jpg',
#           'width': 604,
#           'height': 316},
#          {'type': 'y',
#           'url': 'https://sun9-13.userapi.com/c200524/v200524225/40ac/kw_vb_YGxkg.jpg',
#           'width': 610,
#           'height': 319}],
#         'text': '',
#         'date': 1575702606},
#        'button': {'title': 'Читать',
#         'action': {'type': 'open_url',
#          'url': 'https://m.vk.com/@-142774925-bespilotnye-letauschie-kurery-v-rossiiskih-gorodah-mogut-poy'}}}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 1802},
#   'is_favorite': False},
#  {'id': 33021,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575878182,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 4,
#     'owner_id': -189213399,
#     'from_id': -189213399,
#     'date': 1574786652,
#     'post_type': 'post',
#     'text': 'Привет всем любителям спорта!⚽\n\nСпешим сообщить, что совсем скоро состоится Международный студенческий спортивный фестиваль “Students Euro Cup”, приуроченный к Чемпионату Европы по футболу EURO-2020 на базе НИУ ВШЭ СПБ. Фестиваль будет проводиться в формате турнира по мини-футболу (6*6 игроков).\n\nКогда?⏳\n15-17 декабря 2019 года.\n\nКто участвует?🥅\n24 студенческие команды из ведущих вузов России и Европы, состав каждой команды - 8 человек.\n\nГде?📍\nСанкт-Петербург, центр футбольной подготовки «Восхождение».\n\nНаш фестиваль - это прежде всего: \n1. Поддержка культуры молодежного спорта;\n2. Площадка для обмена опытом студентов не только из России, но и Европы.\n\nУчастников и зрителей турнира ждет насыщенная спортивная, образовательная и культурная программа, включающая в себя памятные подарки и розыгрыши призов от наших партнёров. Но самое главное - это дружеская атмосфера и отличное настроение студентов различных городов и стран в процессе коммуникации и обмена опытом.',
#     'signer_id': 153415561,
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 457239020,
#        'album_id': -7,
#        'owner_id': -189213399,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun9-48.userapi.com/c858428/v858428608/103b8f/Vxa22aDJTX0.jpg',
#          'width': 130,
#          'height': 87},
#         {'type': 'o',
#          'url': 'https://sun9-39.userapi.com/c858428/v858428608/103b94/4IZ2-5_DZkY.jpg',
#          'width': 130,
#          'height': 87},
#         {'type': 'p',
#          'url': 'https://sun9-69.userapi.com/c858428/v858428608/103b95/ymgtiy_Qtzw.jpg',
#          'width': 200,
#          'height': 135},
#         {'type': 'q',
#          'url': 'https://sun9-40.userapi.com/c858428/v858428608/103b96/0CveTyNc29c.jpg',
#          'width': 320,
#          'height': 216},
#         {'type': 'r',
#          'url': 'https://sun9-39.userapi.com/c858428/v858428608/103b97/qxVMMf__-b0.jpg',
#          'width': 510,
#          'height': 343},
#         {'type': 's',
#          'url': 'https://sun9-68.userapi.com/c858428/v858428608/103b8e/JpK5rBYGiHg.jpg',
#          'width': 75,
#          'height': 50},
#         {'type': 'w',
#          'url': 'https://sun9-62.userapi.com/c858428/v858428608/103b93/56AJAAuMifw.jpg',
#          'width': 2000,
#          'height': 1347},
#         {'type': 'x',
#          'url': 'https://sun9-65.userapi.com/c858428/v858428608/103b90/fhsT68fWNsY.jpg',
#          'width': 604,
#          'height': 406},
#         {'type': 'y',
#          'url': 'https://sun9-69.userapi.com/c858428/v858428608/103b91/gt-2aG08fiI.jpg',
#          'width': 807,
#          'height': 543},
#         {'type': 'z',
#          'url': 'https://sun9-65.userapi.com/c858428/v858428608/103b92/kT69JIwz_Jk.jpg',
#          'width': 1280,
#          'height': 862}],
#        'text': '',
#        'date': 1574786493,
#        'access_key': '32bf8f684d3eb61ff2'}}],
#     'post_source': {'type': 'mvk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 2293},
#   'is_favorite': False},
#  {'id': 33019,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575878062,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Вакансия для наших студентов от Леруа Мерлен https://hh.ru/vacancy/34679990',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://hh.ru/vacancy/34679990',
#      'title': 'Вакансия Практикант / Стажер (IT) в Москве, работа в Леруа Мерлен. Центральный офис',
#      'caption': 'hh.ru',
#      'description': 'Вакансия Практикант / Стажер (IT). Зарплата: не указана. Москва. Требуемый опыт: не требуется. Стажировка. Дата публикации: 21.11.2019.',
#      'photo': {'id': 457280139,
#       'album_id': -25,
#       'owner_id': 2000022015,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun9-33.userapi.com/c857524/v857524245/116b3a/RJy2Izwml2c.jpg',
#         'width': 130,
#         'height': 70},
#        {'type': 's',
#         'url': 'https://sun9-27.userapi.com/c857524/v857524245/116b39/rLBuj3JThD4.jpg',
#         'width': 75,
#         'height': 40},
#        {'type': 'x',
#         'url': 'https://sun9-63.userapi.com/c857524/v857524245/116b3b/5qmkfgDYn4k.jpg',
#         'width': 150,
#         'height': 81}],
#       'text': '',
#       'date': 1575878062},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 3319},
#   'is_favorite': False},
#  {'id': 33018,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1575877997,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 8513,
#     'owner_id': -17015209,
#     'from_id': -17015209,
#     'date': 1575388813,
#     'post_type': 'post',
#     'text': '#мероприятие_PwC\n\nВсе знают, зачем государству налоги. Мы знаем, как с ними жить бизнесу. \n \nХочешь познакомиться с налоговыми консультантами PwC? 😊\n \nПриходи 12 декабря на мероприятие PwC. Мы поговорим о налоговом консалтинге: про современные тренды и вызовы, про передовые технологии и навыки консультанта 21 века, про глобализацию налоговых вопросов. Мы расскажем, чем занимаемся сегодня, в чем видим источник вдохновения в работе, об актуальных вакансиях на зимнюю стажировку, и, конечно, ответим на твои вопросы. \n \nДата: 12 декабря, 18:30. \nАдрес: НИУ ВШЭ (Покровский бульвар, 11). \nАудитория: R-304.\n\nЗарегистрироваться можно здесь: https://vk.cc/a5ZLon\n \nЖдем студентов любых курсов. \nПриходи – будет интересно! 😉',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 457244359,
#        'album_id': -7,
#        'owner_id': -17015209,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun9-59.userapi.com/c857336/v857336926/72346/VQvtpk3Uyq8.jpg',
#          'width': 130,
#          'height': 71},
#         {'type': 'o',
#          'url': 'https://sun9-63.userapi.com/c857336/v857336926/7234b/itUo4HvuLaA.jpg',
#          'width': 130,
#          'height': 87},
#         {'type': 'p',
#          'url': 'https://sun9-23.userapi.com/c857336/v857336926/7234c/0bmxH1ZXw3k.jpg',
#          'width': 200,
#          'height': 133},
#         {'type': 'q',
#          'url': 'https://sun9-22.userapi.com/c857336/v857336926/7234d/TzXcOH_fluA.jpg',
#          'width': 320,
#          'height': 213},
#         {'type': 'r',
#          'url': 'https://sun9-25.userapi.com/c857336/v857336926/7234e/-1FwbLZwg0Y.jpg',
#          'width': 510,
#          'height': 340},
#         {'type': 's',
#          'url': 'https://sun9-48.userapi.com/c857336/v857336926/72345/UMaQdzYORe4.jpg',
#          'width': 75,
#          'height': 41},
#         {'type': 'w',
#          'url': 'https://sun9-42.userapi.com/c857336/v857336926/7234a/8jQDFbdqgYY.jpg',
#          'width': 2058,
#          'height': 1125},
#         {'type': 'x',
#          'url': 'https://sun9-72.userapi.com/c857336/v857336926/72347/EAhlkQCK0bM.jpg',
#          'width': 604,
#          'height': 330},
#         {'type': 'y',
#          'url': 'https://sun9-14.userapi.com/c857336/v857336926/72348/_yPVCaBw40A.jpg',
#          'width': 807,
#          'height': 441},
#         {'type': 'z',
#          'url': 'https://sun9-45.userapi.com/c857336/v857336926/72349/aDY7ai3aMr4.jpg',
#          'width': 1280,
#          'height': 700}],
#        'text': '',
#        'date': 1575387687,
#        'post_id': 8513,
#        'access_key': '4cba7b4f055ec22f28'}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 1941},
#   'is_favorite': False},
#  {'id': 33013,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1574758466,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 560,
#     'owner_id': -78620921,
#     'from_id': -78620921,
#     'date': 1574330092,
#     'post_type': 'post',
#     'text': '5-часовой хакатон от МТС\n \n🔴Стань участником соревнования и получи возможность попасть в команду МТС! \n \n🔺Дата: 7 декабря 2019 \n🔺Место: Дом Правительства Московской области (бул. Строителей, 1, Красногорск) \nПодробная информация и регистрация: https://mosrobot2019.ru/ \n \n🔴В этом году Форум посвящен развитию робототехники и станет дискуссионной и выставочной площадкой в сфере инноваций для лучших молодых инноваторов, предпринимателей, ученых, робототехников, а также представителей ведущих научных школ и инновационных лабораторий Подмосковья. \n \nРегистрация открытыпо ссылке https://rusinnovations.timepad.ru/event/1112112/ до 29.11. \nУспей принять участие!\n\n#mts #АИР #москва #хакатон #московскаяобласть #It',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://mosrobot2019.ru',
#        'title': 'Московский областной молодежный форум инноваций и предпринимательства',
#        'caption': 'mosrobot2019.ru',
#        'description': 'Московский областной молодежный форум инноваций и предпринимательства',
#        'photo': {'id': 457283968,
#         'album_id': -28,
#         'owner_id': 2000012434,
#         'sizes': [{'type': 'a',
#           'url': 'https://sun9-8.userapi.com/c858432/v858432978/f18f6/Lv1epT1sP48.jpg',
#           'width': 200,
#           'height': 89},
#          {'type': 'b',
#           'url': 'https://sun9-51.userapi.com/c858432/v858432978/f18f4/qUl93GOPqzQ.jpg',
#           'width': 400,
#           'height': 179},
#          {'type': 'c',
#           'url': 'https://sun9-49.userapi.com/c858432/v858432978/f18f8/xHU3_HKMVjY.jpg',
#           'width': 200,
#           'height': 200},
#          {'type': 'd',
#           'url': 'https://sun9-33.userapi.com/c858432/v858432978/f18f9/19EGm3OpQBU.jpg',
#           'width': 100,
#           'height': 100},
#          {'type': 'e',
#           'url': 'https://sun9-29.userapi.com/c858432/v858432978/f18fa/tol9l793qN8.jpg',
#           'width': 50,
#           'height': 50},
#          {'type': 'k',
#           'url': 'https://sun9-7.userapi.com/c858432/v858432978/f18f5/y1twmu2EhZs.jpg',
#           'width': 1073,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-17.userapi.com/c858432/v858432978/f18f7/sfIxMs1SsTw.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'o',
#           'url': 'https://sun9-41.userapi.com/c858432/v858432978/f18f3/6-CGzG2LBsM.jpg',
#           'width': 751,
#           'height': 336}],
#         'text': '',
#         'date': 1574330092},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 4708},
#   'is_favorite': False},
#  {'id': 33012,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1574758409,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 3596,
#     'owner_id': -123851409,
#     'from_id': -123851409,
#     'date': 1574679615,
#     'post_type': 'post',
#     'text': '25 ноября стартует набор в Tinkoff Internship — оплачиваемую образовательную программу, которая поможет отточить знания в области программирования и аналитики и поработать над реальными проектами Тинькофф. Программа начнется 29 января 2020 года в Москве, Санкт-Петербурге, Екатеринбурге, Ижевске, Рязани и Нижнем Новгороде. Коротко о том, что ждет студентов:\n\n💫 обучение под началом куратора по направлениям «Frontend-разработка», «Python-разработка», «Аналитика», «Управление проектами», «Системное администрирование» и не только; \n\n⭐ присутствие в офисе Тинькофф от 20 часов в неделю;\n\n🌟 три месяца занятий с реальными проектами Тинькофф;\n\n🏆 возможность попасть к нам в команду после окончания обучения.\n\nВыбрать направление и оставить заявку не позже 8 декабря можно тут: https://l.tinkoff.ru/tinternship20_vk',
#     'attachments': [{'type': 'doc',
#       'doc': {'id': 524983176,
#        'owner_id': 213287907,
#        'title': 'Tinkoff Internship.gif',
#        'size': 13785375,
#        'ext': 'gif',
#        'url': 'https://vk.com/doc213287907_524983176?hash=7e4b18765b879e9c20&dl=GIYDINZTGI3DS:1576675694:78a6c8bac243e2744c&api=1&no_preview=1',
#        'date': 1574678630,
#        'type': 3,
#        'preview': {'photo': {'sizes': [{'src': 'https://sun9-11.userapi.com/c856416/u213287907/d5/-3/m_af312816c8.jpg',
#            'width': 130,
#            'height': 100,
#            'type': 'm'},
#           {'src': 'https://sun9-25.userapi.com/c856416/u213287907/d5/-3/s_af312816c8.jpg',
#            'width': 100,
#            'height': 75,
#            'type': 's'},
#           {'src': 'https://sun9-28.userapi.com/c856416/u213287907/d5/-3/x_af312816c8.jpg',
#            'width': 604,
#            'height': 604,
#            'type': 'x'},
#           {'src': 'https://sun9-67.userapi.com/c856416/u213287907/d5/-3/y_af312816c8.jpg',
#            'width': 807,
#            'height': 807,
#            'type': 'y'},
#           {'src': 'https://sun9-66.userapi.com/c856416/u213287907/d5/-3/o_af312816c8.jpg',
#            'width': 800,
#            'height': 800,
#            'type': 'o'},
#           {'src': 'https://sun9-67.userapi.com/impc/c856416/u213287907/d5/-3/y_af312816c8.jpg?size=288x288&quality=90&sign=400cb5cb828d7121b221d2ea344265e0',
#            'width': 288,
#            'height': 288,
#            'type': 'i'},
#           {'src': 'https://sun9-67.userapi.com/impc/c856416/u213287907/d5/-3/y_af312816c8.jpg?size=192x192&quality=90&sign=8f017fcb5b634eb4630e0d93ad9ea45f',
#            'width': 192,
#            'height': 192,
#            'type': 'd'}]},
#         'video': {'src': 'https://vk.com/doc213287907_524983176?hash=7e4b18765b879e9c20&dl=GIYDINZTGI3DS:1576675694:78a6c8bac243e2744c&api=1&mp4=1',
#          'width': 800,
#          'height': 800,
#          'file_size': 318991}},
#        'access_key': 'fdcf449fd16998de1c'}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 4757},
#   'is_favorite': False},
#  {'id': 33011,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1574752946,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 560,
#     'owner_id': -78620921,
#     'from_id': -78620921,
#     'date': 1574330092,
#     'post_type': 'post',
#     'text': '5-часовой хакатон от МТС\n \n🔴Стань участником соревнования и получи возможность попасть в команду МТС! \n \n🔺Дата: 7 декабря 2019 \n🔺Место: Дом Правительства Московской области (бул. Строителей, 1, Красногорск) \nПодробная информация и регистрация: https://mosrobot2019.ru/ \n \n🔴В этом году Форум посвящен развитию робототехники и станет дискуссионной и выставочной площадкой в сфере инноваций для лучших молодых инноваторов, предпринимателей, ученых, робототехников, а также представителей ведущих научных школ и инновационных лабораторий Подмосковья. \n \nРегистрация открытыпо ссылке https://rusinnovations.timepad.ru/event/1112112/ до 29.11. \nУспей принять участие!\n\n#mts #АИР #москва #хакатон #московскаяобласть #It',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://mosrobot2019.ru',
#        'title': 'Московский областной молодежный форум инноваций и предпринимательства',
#        'caption': 'mosrobot2019.ru',
#        'description': 'Московский областной молодежный форум инноваций и предпринимательства',
#        'photo': {'id': 457283968,
#         'album_id': -28,
#         'owner_id': 2000012434,
#         'sizes': [{'type': 'a',
#           'url': 'https://sun9-8.userapi.com/c858432/v858432978/f18f6/Lv1epT1sP48.jpg',
#           'width': 200,
#           'height': 89},
#          {'type': 'b',
#           'url': 'https://sun9-51.userapi.com/c858432/v858432978/f18f4/qUl93GOPqzQ.jpg',
#           'width': 400,
#           'height': 179},
#          {'type': 'c',
#           'url': 'https://sun9-49.userapi.com/c858432/v858432978/f18f8/xHU3_HKMVjY.jpg',
#           'width': 200,
#           'height': 200},
#          {'type': 'd',
#           'url': 'https://sun9-33.userapi.com/c858432/v858432978/f18f9/19EGm3OpQBU.jpg',
#           'width': 100,
#           'height': 100},
#          {'type': 'e',
#           'url': 'https://sun9-29.userapi.com/c858432/v858432978/f18fa/tol9l793qN8.jpg',
#           'width': 50,
#           'height': 50},
#          {'type': 'k',
#           'url': 'https://sun9-7.userapi.com/c858432/v858432978/f18f5/y1twmu2EhZs.jpg',
#           'width': 1073,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-17.userapi.com/c858432/v858432978/f18f7/sfIxMs1SsTw.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'o',
#           'url': 'https://sun9-41.userapi.com/c858432/v858432978/f18f3/6-CGzG2LBsM.jpg',
#           'width': 751,
#           'height': 336}],
#         'text': '',
#         'date': 1574330092},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 1, 'user_reposted': 0},
#   'views': {'count': 3305},
#   'is_favorite': False},
#  {'id': 33009,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1574405668,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 2359,
#     'owner_id': -89765286,
#     'from_id': -89765286,
#     'date': 1574234988,
#     'post_type': 'post',
#     'text': 'День школьника на ФБМ \n\nУважаемые школьники! \n8 декабря 2019 года у вас будет уникальная возможность окунуться в студенческую жизнь образовательных программ направления «Бизнес-информатика». \n📆8 декабря (воскресенье)\n⌚11:00 – 15:00 \n🏢Факультет бизнеса и менеджмента НИУ ВШЭ, ул. Шаболовка, д. 26, аудитория К10 и другие\n\nРегистрация: https://vk.cc/a2MW6Y',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://bi.hse.ru/announcements/318449443.html',
#        'title': 'День Школьника на образовательной программе «Бизнес-информатика»',
#        'caption': 'bi.hse.ru',
#        'description': '',
#        'photo': {'id': 457285836,
#         'album_id': -27,
#         'owner_id': 2000011625,
#         'sizes': [{'type': 'a',
#           'url': 'https://sun9-9.userapi.com/c854324/v854324137/179679/okGbTbBMpvI.jpg',
#           'width': 200,
#           'height': 90},
#          {'type': 'b',
#           'url': 'https://sun9-66.userapi.com/c854324/v854324137/179677/oDUOAqxt0us.jpg',
#           'width': 400,
#           'height': 179},
#          {'type': 'c',
#           'url': 'https://sun9-7.userapi.com/c854324/v854324137/17967b/UFEKTHaJDRI.jpg',
#           'width': 200,
#           'height': 200},
#          {'type': 'd',
#           'url': 'https://sun9-64.userapi.com/c854324/v854324137/17967c/vJBGLUTtvC0.jpg',
#           'width': 100,
#           'height': 100},
#          {'type': 'e',
#           'url': 'https://sun9-17.userapi.com/c854324/v854324137/17967d/2mVnJf42lfw.jpg',
#           'width': 50,
#           'height': 50},
#          {'type': 'k',
#           'url': 'https://sun9-60.userapi.com/c854324/v854324137/179678/Q_snUOUOjG0.jpg',
#           'width': 1070,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-50.userapi.com/c854324/v854324137/17967a/gyV3Nvo1Wl0.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'o',
#           'url': 'https://sun9-36.userapi.com/c854324/v854324137/179676/j8RDt4ZmRe4.jpg',
#           'width': 896,
#           'height': 402}],
#         'text': '',
#         'date': 1574234988},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 7, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 2, 'user_reposted': 0},
#   'views': {'count': 4335},
#   'is_favorite': False},
#  {'id': 33007,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1574249632,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Приглашает бизнес-информатика!',
#   'copy_history': [{'id': 2359,
#     'owner_id': -89765286,
#     'from_id': -89765286,
#     'date': 1574234988,
#     'post_type': 'post',
#     'text': 'День школьника на ФБМ \n\nУважаемые школьники! \n8 декабря 2019 года у вас будет уникальная возможность окунуться в студенческую жизнь образовательных программ направления «Бизнес-информатика». \n📆8 декабря (воскресенье)\n⌚11:00 – 15:00 \n🏢Факультет бизнеса и менеджмента НИУ ВШЭ, ул. Шаболовка, д. 26, аудитория К10 и другие\n\nРегистрация: https://vk.cc/a2MW6Y',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://bi.hse.ru/announcements/318449443.html',
#        'title': 'День Школьника на образовательной программе «Бизнес-информатика»',
#        'caption': 'bi.hse.ru',
#        'description': '',
#        'photo': {'id': 457285836,
#         'album_id': -27,
#         'owner_id': 2000011625,
#         'sizes': [{'type': 'a',
#           'url': 'https://sun9-9.userapi.com/c854324/v854324137/179679/okGbTbBMpvI.jpg',
#           'width': 200,
#           'height': 90},
#          {'type': 'b',
#           'url': 'https://sun9-66.userapi.com/c854324/v854324137/179677/oDUOAqxt0us.jpg',
#           'width': 400,
#           'height': 179},
#          {'type': 'c',
#           'url': 'https://sun9-7.userapi.com/c854324/v854324137/17967b/UFEKTHaJDRI.jpg',
#           'width': 200,
#           'height': 200},
#          {'type': 'd',
#           'url': 'https://sun9-64.userapi.com/c854324/v854324137/17967c/vJBGLUTtvC0.jpg',
#           'width': 100,
#           'height': 100},
#          {'type': 'e',
#           'url': 'https://sun9-17.userapi.com/c854324/v854324137/17967d/2mVnJf42lfw.jpg',
#           'width': 50,
#           'height': 50},
#          {'type': 'k',
#           'url': 'https://sun9-60.userapi.com/c854324/v854324137/179678/Q_snUOUOjG0.jpg',
#           'width': 1070,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-50.userapi.com/c854324/v854324137/17967a/gyV3Nvo1Wl0.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'o',
#           'url': 'https://sun9-36.userapi.com/c854324/v854324137/179676/j8RDt4ZmRe4.jpg',
#           'width': 896,
#           'height': 402}],
#         'text': '',
#         'date': 1574234988},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 5245},
#   'is_favorite': False},
#  {'id': 33006,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1573854486,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '🍀Приходите на эко-фестиваль «Клеверок» от Зеленой Вышки в воскресенье, 17 ноября!🍀 \n \nНа фестивале выступят спикеры из Экологического движения «РазДельный Сбор» , ГК "ЭкоТехнологии", Repleo_zerowaste, ECOCUP Film Festival, БВШД и РосЭко, а также пройдет мастер-класс по росписи сумок. \nНиже вы можете ознакомиться с расписанием фестиваля: \n \n✔13:00 "Внедрение раздельного сбора отходов в России. Опыт ГК ЭкоТехнологии." - Елена Баранова \n✔13:40 "Искусство и экология" - Валерия Колтунова \n✔14:20 "Концепция «ноль отходов» в теории и на практике." - Анна Расторгуева \n✔15:00 "Раздельный сбор: как начать?" - Луферова Александра \n✔15:40 "Актуальные вопросы климата и экологии в журналистике." - Наталья Парамонова \n✔16:20 "Гид по экологичной жизни в мегаполисе: Полный спектр экологичного образа жизни." - Анна Кочегар и Михаил Антонов \n \n17:00 – 19:00 Мастер-класс по росписи сумок. \n \n🎨 В течение всего фестиваля можно будет посетить выставку работ художников Британской Высшей Школы Дизайна, которые вы сможете приобрести. Часть вырученных средств пойдет на благотворительность. \n \n📍Фестиваль пройдет в «БуквоДом» в парке «Сокольники» . \n \nЗарегистрироваться на отдельные лекции и мастер-класс вы сможете на сайте Букводома - https://vk.cc/9CVmi2 \nЕсли хотите посетить все лекции и мастер-класс, то можете регистрироваться по ссылке - https://vk.cc/a0HbNv \nЕсли же собираетесь прийти на несколько лекций или одну, просим регистрироваться отдельно на конкретное мероприятие.',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://bookvodom.moscow/events',
#      'title': 'Букводом',
#      'caption': 'bookvodom.moscow',
#      'description': '',
#      'photo': {'id': 457276433,
#       'album_id': -28,
#       'owner_id': 2000010409,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun9-31.userapi.com/c854320/v854320521/1664ff/S6FZ_sp8U6I.jpg',
#         'width': 130,
#         'height': 81},
#        {'type': 'p',
#         'url': 'https://sun9-3.userapi.com/c854320/v854320521/166501/Ohbln9QCpTU.jpg',
#         'width': 260,
#         'height': 163},
#        {'type': 's',
#         'url': 'https://sun9-61.userapi.com/c854320/v854320521/1664fe/VayDfROVi8Q.jpg',
#         'width': 75,
#         'height': 47},
#        {'type': 'x',
#         'url': 'https://sun9-23.userapi.com/c854320/v854320521/166500/WBB8VpPX628.jpg',
#         'width': 150,
#         'height': 94}],
#       'text': '',
#       'date': 1573854486},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 10, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 5323},
#   'is_favorite': False},
#  {'id': 33005,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1573854245,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Найдена карта Абрамова Владислава Витальевича. Влад, обратитесь к https://vk.com/fantomnotabene',
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 5193},
#   'is_favorite': False,
#   'edited': 1573854306},
#  {'id': 33001,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1573477263,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 701,
#     'owner_id': -101889313,
#     'from_id': -101889313,
#     'date': 1572996586,
#     'post_type': 'post',
# ...
#          'url': 'https://sun9-53.userapi.com/c845217/v845217590/1b9f72/EYGdZgkPZZQ.jpg',
#          'width': 200,
#          'height': 133},
#         {'type': 'q',
#          'url': 'https://sun9-64.userapi.com/c845217/v845217590/1b9f73/w3O-E-3akog.jpg',
#          'width': 320,
#          'height': 213},
#         {'type': 'r',
#          'url': 'https://sun9-14.userapi.com/c845217/v845217590/1b9f74/anpKXBDV1Bg.jpg',
#          'width': 510,
#          'height': 340},
#         {'type': 's',
#          'url': 'https://sun9-14.userapi.com/c845217/v845217590/1b9f6c/vZKNhDuISSI.jpg',
#          'width': 75,
#          'height': 36},
#         {'type': 'x',
#          'url': 'https://sun9-54.userapi.com/c845217/v845217590/1b9f6e/W0YVl5HGu7M.jpg',
#          'width': 604,
#          'height': 293},
#         {'type': 'y',
#          'url': 'https://sun9-33.userapi.com/c845217/v845217590/1b9f6f/c3kIVRywlGk.jpg',
#          'width': 807,
#          'height': 391},
#         {'type': 'z',
#          'url': 'https://sun9-10.userapi.com/c845217/v845217590/1b9f70/kazZsJmx2o4.jpg',
#          'width': 960,
#          'height': 465}],
#        'text': '',
#        'date': 1551438179,
#        'access_key': '2ccf21ddf6bb737360'}},
#      {'type': 'doc',
#       'doc': {'id': 492709378,
#        'owner_id': -108877455,
#        'title': 'Программа конференции.pdf',
#        'size': 919302,
#        'ext': 'pdf',
#        'url': 'https://vk.com/doc-108877455_492709378?hash=2c58c4e758137c506f&dl=GIYDINZTGI3DS:1576675694:c469df9dc5294f04d7&api=1&no_preview=1',
#        'date': 1551436400,
#        'type': 1,
#        'access_key': 'f365ede2267da076ef'}},
#      {'type': 'doc',
#       'doc': {'id': 492619501,
#        'owner_id': -108877455,
#        'title': 'Критерии статей 2019.pdf',
#        'size': 202921,
#        'ext': 'pdf',
#        'url': 'https://vk.com/doc-108877455_492619501?hash=13872f034d3068cf55&dl=GIYDINZTGI3DS:1576675694:27df49c5b5827280f3&api=1&no_preview=1',
#        'date': 1551363033,
#        'type': 1,
#        'access_key': 'ee2b49141822fc8a81'}}],
#     'post_source': {'type': 'api', 'platform': 'iphone'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 11, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 3, 'user_reposted': 0},
#   'views': {'count': 8160},
#   'is_favorite': False},
#  {'id': 32623,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1553244602,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'В лицее НИУ ВШЭ: https://nnov.hse.ru/management/announcements/251447629.html',
#   'copy_history': [{'id': 268,
#     'owner_id': -170789907,
#     'from_id': -170789907,
#     'date': 1552150140,
#     'post_type': 'post',
#     'text': 'Добрый вечер, воители и поэты!\nВеликий сёгун скончался, и мы должны незамедлительно отправиться в столицу... на встречу по японской истории.\n🈴🎎\nЯпония, 1358 год. Асикага Такаудзи умер, оставив наследнику раздираемую междоусобицей страну, своенравных вассалов и очаги восстаний в отдалённых провинциях. \n\n🔶 Как встретят японские разбойники корейских послов?\n🔶 Чем ответят мятежники на вторжение самураев?\n🔶 Закончит ли Ёсиакира дело отца? \n🔶 Что на самом деле означает быть сёгуном?\n\nА также охота генерала Хосокава за собственным братом, предательство самых верных сторонников Южного Двора и биографические справки о ключевых деятелях эпохи.\n\n— на лекции в субботу 23 марта 15:30 - 17:30 — \n\nНа этот раз к чаю будут печеньки, зарегистрировавшимся участникам мы заранее вышлем доступ к материалам на ГуглДиске, и видео-введение в тему будет заранее записано.\n\n🇯🇵 Для участия необходимо\n(1) зарегистрироваться в форме по ссылке \ndocs.google.com/forms/d/1YVI6uFK5IdI55tZnqIr92O_ohwj4ol1LsBHObPeudKc \n\n(2) лайкнуть этот пост (тогда мы пришлём вам дополнительную информацию и ответим на интересующие вопросы)\n\n(3) > взять паспорт / свидетельство о рождении и прийти в Лицей НИУ ВШЭ по адресу переулок Лялин, дом 3А, аудитория 204 (2 этаж) \nили \n> установить приложение Zoom и подключиться дистанционно по ссылке zoom.us/j/172123665 \n\n(4) если лекция окажется ценной для вас, подумать над тем, чтобы поддержать наш проект финансово :) будем вам весьма благодарны!\n\n😌 К вашим услугам, \nкоманда проекта "Повесть об Императоре"\nvk.com/topic-170789907_42555052',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 456239712,
#        'album_id': -7,
#        'owner_id': -170789907,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun9-29.userapi.com/c846218/v846218585/1bf416/BZkOvC6TvsM.jpg',
#          'width': 90,
#          'height': 130},
#         {'type': 'o',
#          'url': 'https://sun9-54.userapi.com/c846218/v846218585/1bf41a/-N8Fm58K6Ro.jpg',
#          'width': 130,
#          'height': 188},
#         {'type': 'p',
#          'url': 'https://sun9-63.userapi.com/c846218/v846218585/1bf41b/w9v8lpFdaJs.jpg',
#          'width': 200,
#          'height': 290},
#         {'type': 'q',
#          'url': 'https://sun9-71.userapi.com/c846218/v846218585/1bf41c/S7d06ngwZM4.jpg',
#          'width': 320,
#          'height': 464},
#         {'type': 'r',
#          'url': 'https://sun9-56.userapi.com/c846218/v846218585/1bf41d/14OgnzU3f44.jpg',
#          'width': 510,
#          'height': 739},
#         {'type': 's',
#          'url': 'https://sun9-21.userapi.com/c846218/v846218585/1bf415/OJa7q234hz8.jpg',
#          'width': 52,
#          'height': 75},
#         {'type': 'x',
#          'url': 'https://sun9-19.userapi.com/c846218/v846218585/1bf417/2jAjios657Y.jpg',
#          'width': 417,
#          'height': 604},
#         {'type': 'y',
#          'url': 'https://sun9-8.userapi.com/c846218/v846218585/1bf418/qesVndBkPAQ.jpg',
#          'width': 557,
#          'height': 807},
#         {'type': 'z',
#          'url': 'https://sun9-19.userapi.com/c846218/v846218585/1bf419/NNzYhb2FAM0.jpg',
#          'width': 745,
#          'height': 1080}],
#        'text': '',
#        'date': 1552036994,
#        'access_key': '370f5ee98ece1e54e3'}},
#      {'type': 'link',
#       'link': {'url': 'http://docs.google.com/forms/d/1YVI6uFK5IdI55tZnqIr92O_ohwj4ol1LsBHObPeudKc',
#        'title': 'лекция "Ёсиакира - второй сёгун Асикага"',
#        'description': 'Здравствуйте! Если Вы идёте на наше событие пешком, всё не так просто, как кажется)  Стоит пройти эту небольшую анкету и принести с собой паспорт, чтобы пройти в Лицей НИУ ВШЭ.',
#        'target': 'internal',
#        'photo': {'id': 456260987,
#         'album_id': -26,
#         'owner_id': 2000012214,
#         'sizes': [{'type': 'm',
#           'url': 'https://sun9-36.userapi.com/c850132/v850132254/fb30c/t2jiFlMyAjc.jpg',
#           'width': 130,
#           'height': 130},
#          {'type': 'p',
#           'url': 'https://sun9-36.userapi.com/c850132/v850132254/fb30e/IepPvhUZftM.jpg',
#           'width': 260,
#           'height': 260},
#          {'type': 's',
#           'url': 'https://sun9-62.userapi.com/c850132/v850132254/fb30b/3OBU3bEgIpM.jpg',
#           'width': 75,
#           'height': 75},
#          {'type': 'x',
#           'url': 'https://sun9-60.userapi.com/c850132/v850132254/fb30d/wF9kYY6C4Ds.jpg',
#           'width': 150,
#           'height': 150}],
#         'text': '',
#         'date': 1552036994},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 1, 'user_reposted': 0},
#   'views': {'count': 7777},
#   'is_favorite': False},
#  {'id': 32622,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1553244286,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'copy_history': [{'id': 324,
#     'owner_id': -108877455,
#     'from_id': -108877455,
#     'date': 1552659898,
#     'post_type': 'post',
#     'text': '🔥 У нас замечательная новость! Регистрация на кейс от Unilever открыта!\n\n💡 Наш партнер компания Unilever проведет кейс-чемпионат в рамках конференции по управлению проектами НИУ ВШЭ. Тебе и твоей команде предстоит запустить проект, для чего вам потребуются не только знания по УП, но и по маркетингу и финансам.\n\n🏆 Соревнование пройдет 30 мая, а победители получат фаст-трек на финальный этап отбора на летнюю стажировку в Unilever, а также подарки от компании!\n\n🎯 Если ты студент со специальностью маркетинг, менеджмент или экономика, то срочно регистрируйся тут: https://docs.google.com/forms/d/e/1FAIpQLSd2c8zTbwdVCKvthcjxlK4C8SrXLlwSRBgqEpD-gz3xroz5lQ/viewform\n\n🏁 Зови друзей и собирай свою команду из 3-4 человек. Не забудьте зарегистрировать каждого! Если у тебя нет команды, найти единомышленников можно здесь: https://vk.com/topic-108877455_39901339 \n\n⏰ Не забудь: \nПодать заявку до 29 марта\nА также регистрируйся и приходи на нашу конференцию! https://vk.com/wall-108877455_318',
#     'attachments': [{'type': 'photo',
#       'photo': {'id': 456239389,
#        'album_id': -7,
#        'owner_id': -108877455,
#        'user_id': 100,
#        'sizes': [{'type': 'm',
#          'url': 'https://sun9-58.userapi.com/c848736/v848736827/157d2a/0P3ZPISuFmY.jpg',
#          'width': 130,
#          'height': 63},
#         {'type': 'o',
#          'url': 'https://sun9-39.userapi.com/c848736/v848736827/157d2f/lty92RrRt04.jpg',
#          'width': 130,
#          'height': 87},
#         {'type': 'p',
#          'url': 'https://sun9-35.userapi.com/c848736/v848736827/157d30/I-Qrnb1B6G8.jpg',
#          'width': 200,
#          'height': 133},
#         {'type': 'q',
#          'url': 'https://sun9-51.userapi.com/c848736/v848736827/157d31/EubO-iEoGsc.jpg',
#          'width': 320,
#          'height': 213},
#         {'type': 'r',
#          'url': 'https://sun9-58.userapi.com/c848736/v848736827/157d32/t6dEmFr8ut8.jpg',
#          'width': 510,
#          'height': 340},
#         {'type': 's',
#          'url': 'https://sun9-25.userapi.com/c848736/v848736827/157d29/FW6FEd8RPP8.jpg',
#          'width': 75,
#          'height': 36},
#         {'type': 'w',
#          'url': 'https://sun9-21.userapi.com/c848736/v848736827/157d2e/ccgMyMzh8ac.jpg',
#          'width': 2560,
#          'height': 1243},
#         {'type': 'x',
#          'url': 'https://sun9-69.userapi.com/c848736/v848736827/157d2b/SCDGeQu9T6s.jpg',
#          'width': 604,
#          'height': 293},
#         {'type': 'y',
#          'url': 'https://sun9-9.userapi.com/c848736/v848736827/157d2c/J7e_z2S0RMQ.jpg',
#          'width': 807,
#          'height': 392},
#         {'type': 'z',
#          'url': 'https://sun9-41.userapi.com/c848736/v848736827/157d2d/l0-h__yCEBw.jpg',
#          'width': 1280,
#          'height': 621}],
#        'text': '',
#        'date': 1552659898,
#        'post_id': 324,
#        'access_key': '4c17a90a0ac78fd226'}},
#      {'type': 'link',
#       'link': {'url': 'https://docs.google.com/forms/d/e/1FAIpQLSd2c8zTbwdVCKvthcjxlK4C8SrXLlwSRBgqEpD-gz3xroz5lQ/viewform',
#        'title': 'Регистрация на кейс-чемпионат от компании Unilever',
#        'description': 'Регистрируйся сам и собирай команду из 3 или 4 человек! Найти единомышленников можно в обсуждении группы HSEPMCONF`19 VK. Если после окончания регистрации 29 марта состав твоей команды будет неполным, то мы поможем найти тебе команду.',
#        'target': 'internal',
#        'photo': {'id': 456266185,
#         'album_id': -26,
#         'owner_id': 2000015121,
#         'sizes': [{'type': 'k',
#           'url': 'https://sun9-24.userapi.com/c844521/v844521783/1cc5b7/2l3II5D6uRs.jpg',
#           'width': 1074,
#           'height': 480},
#          {'type': 'l',
#           'url': 'https://sun9-15.userapi.com/c844521/v844521783/1cc5b6/AIxqq-abs1M.jpg',
#           'width': 537,
#           'height': 240},
#          {'type': 'm',
#           'url': 'https://sun9-71.userapi.com/c844521/v844521783/1cc5b3/rirgJStwqrQ.jpg',
#           'width': 130,
#           'height': 70},
#          {'type': 'p',
#           'url': 'https://sun9-34.userapi.com/c844521/v844521783/1cc5b5/YMkgqecz73w.jpg',
#           'width': 260,
#           'height': 140},
#          {'type': 's',
#           'url': 'https://sun9-55.userapi.com/c844521/v844521783/1cc5b2/6wlfrh-vidg.jpg',
#           'width': 75,
#           'height': 39},
#          {'type': 'x',
#           'url': 'https://sun9-63.userapi.com/c844521/v844521783/1cc5b4/q65SVaziqd0.jpg',
#           'width': 150,
#           'height': 80}],
#         'text': '',
#         'date': 1552660311},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 1, 'user_reposted': 0},
#   'views': {'count': 6231},
#   'is_favorite': False},
#  {'id': 32621,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1553244139,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'ВШЭ Нижний Новгород: https://nnov.hse.ru/management/announcements/251447629.html',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://nnov.hse.ru/management/announcements/251447629.html',
#      'title': 'Конференция "Бизнес-тренды: цифровые технологии в менеджменте"',
#      'caption': 'nnov.hse.ru',
#      'description': '',
#      'photo': {'id': 456267814,
#       'album_id': -25,
#       'owner_id': 2000017245,
#       'sizes': [{'type': 'm',
#         'url': 'https://sun9-46.userapi.com/c850136/v850136551/10a35d/zoY55jVFUBQ.jpg',
#         'width': 130,
#         'height': 68},
#        {'type': 'p',
#         'url': 'https://sun9-64.userapi.com/c850136/v850136551/10a35f/TYakus-B9Ks.jpg',
#         'width': 260,
#         'height': 136},
#        {'type': 's',
#         'url': 'https://sun9-40.userapi.com/c850136/v850136551/10a35c/3TtGjqwhvWU.jpg',
#         'width': 75,
#         'height': 39},
#        {'type': 'x',
#         'url': 'https://sun9-56.userapi.com/c850136/v850136551/10a35e/qW-0hAqI5_s.jpg',
#         'width': 150,
#         'height': 78}],
#       'text': '',
#       'date': 1553023011},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 5508},
#   'is_favorite': False},
#  {'id': 32620,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1553243861,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'Шухов Лаб приглашает: https://www.hse.ru/ma/techcity/announcements/251438808.html',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://www.hse.ru/ma/techcity/announcements/251438808.html',
#      'title': 'Воркшоп «Проектирование интерактивных общественных пространств»',
#      'caption': 'www.hse.ru',
#      'description': '',
#      'photo': {'id': 456264055,
#       'album_id': -27,
#       'owner_id': 2000019150,
#       'sizes': [{'type': 'k',
#         'url': 'https://sun9-54.userapi.com/c856016/v856016966/a14d/3AAJqocrpmI.jpg',
#         'width': 1074,
#         'height': 480},
#        {'type': 'l',
#         'url': 'https://sun9-22.userapi.com/c856016/v856016966/a14c/UnvAbIZIyDg.jpg',
#         'width': 537,
#         'height': 240},
#        {'type': 'm',
#         'url': 'https://sun9-21.userapi.com/c856016/v856016966/a149/MpfWBW_XvXI.jpg',
#         'width': 130,
#         'height': 92},
#        {'type': 'p',
#         'url': 'https://sun9-62.userapi.com/c856016/v856016966/a14b/2rceSe2pezQ.jpg',
#         'width': 260,
#         'height': 184},
#        {'type': 's',
#         'url': 'https://sun9-52.userapi.com/c856016/v856016966/a148/OkzXasB8nTU.jpg',
#         'width': 75,
#         'height': 53},
#        {'type': 'x',
#         'url': 'https://sun9-31.userapi.com/c856016/v856016966/a14a/6B0iiWBK2rs.jpg',
#         'width': 150,
#         'height': 106}],
#       'text': '',
#       'date': 1553243861},
#      'is_favorite': False}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 0, 'user_reposted': 0},
#   'views': {'count': 5397},
#   'is_favorite': False}]

# %%
data['response']['items'][0]
# Out:
# {'id': 33029,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1575971849,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'Что меня огорчает',
#  'attachments': [{'type': 'link',
#    'link': {'url': 'https://www.hse.ru/our/news/323346844.html',
#     'title': 'Что меня огорчает',
#     'caption': 'www.hse.ru',
#     'description': 'Авторская колонка первого проректора Вадима Радаева',
#     'photo': {'id': 457289885,
#      'album_id': -26,
#      'owner_id': 2000021743,
#      'sizes': [{'type': 'k',
#        'url': 'https://sun9-71.userapi.com/c858024/v858024349/120e4c/to-wJyYBh9w.jpg',
#        'width': 1000,
#        'height': 480},
#       {'type': 'l',
#        'url': 'https://sun9-32.userapi.com/c858024/v858024349/120e4b/jvKn7gctoWs.jpg',
#        'width': 537,
#        'height': 240},
#       {'type': 'm',
#        'url': 'https://sun9-12.userapi.com/c858024/v858024349/120e48/c9FrIN8g3F0.jpg',
#        'width': 130,
#        'height': 87},
#       {'type': 'p',
#        'url': 'https://sun9-5.userapi.com/c858024/v858024349/120e4a/k4mOW6y9DRM.jpg',
#        'width': 260,
#        'height': 173},
#       {'type': 's',
#        'url': 'https://sun9-19.userapi.com/c858024/v858024349/120e47/Wr__bx8GuTU.jpg',
#        'width': 75,
#        'height': 50},
#       {'type': 'x',
#        'url': 'https://sun9-44.userapi.com/c858024/v858024349/120e49/p6wvV7kAM9Y.jpg',
#        'width': 150,
#        'height': 100}],
#      'text': '',
#      'date': 1575971849},
#     'is_favorite': False}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 12, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'views': {'count': 6670},
#  'is_favorite': False}

# %%
posts = pd.DataFrame(res)

# %%
posts["nlikes"] = posts["likes"].apply(lambda x: int(x["count"]))
posts["nreposts"] = posts["reposts"].apply(lambda x: int(x["count"]))
posts["nviews"] = posts["views"].apply(lambda x: int(x["count"]))

# %%
posts
# Out:
#        id  from_id  owner_id        date  marked_as_ads post_type  \
# 0   33029     -132      -132  1575971849              0      post
# 1   33028     -132      -132  1575971665              0      post
# 2   33027     -132      -132  1575971625              0      post
# 3   33026     -132      -132  1575971586              0      post
# 4   33025     -132      -132  1575971433              0      post
# ..    ...      ...       ...         ...            ...       ...
# 95  32624     -132      -132  1553244921              0      post
# 96  32623     -132      -132  1553244602              0      post
# 97  32622     -132      -132  1553244286              0      post
# 98  32621     -132      -132  1553244139              0      post
# 99  32620     -132      -132  1553243861              0      post
#
#                                                  text  \
# 0                                   Что меня огорчает
# 1
# 2
# 3
# 4   Вышка в прошлом году запустила новый проект, о...
# ..                                                ...
# 95
# 96  В лицее НИУ ВШЭ: https://nnov.hse.ru/managemen...
# 97
# 98  ВШЭ Нижний Новгород: https://nnov.hse.ru/manag...
# 99  Шухов Лаб приглашает: https://www.hse.ru/ma/te...
#
#                                           attachments     post_source  \
# 0   [{'type': 'link', 'link': {'url': 'https://www...  {'type': 'vk'}
# 1                                                 NaN  {'type': 'vk'}
# 2                                                 NaN  {'type': 'vk'}
# 3   [{'type': 'photo', 'photo': {'id': 457240210, ...  {'type': 'vk'}
# 4   [{'type': 'link', 'link': {'url': 'https://www...  {'type': 'vk'}
# ..                                                ...             ...
# 95                                                NaN  {'type': 'vk'}
# 96                                                NaN  {'type': 'vk'}
# 97                                                NaN  {'type': 'vk'}
# 98  [{'type': 'link', 'link': {'url': 'https://nno...  {'type': 'vk'}
# 99  [{'type': 'link', 'link': {'url': 'https://www...  {'type': 'vk'}
#
#                                              comments  \
# 0   {'count': 1, 'can_post': 1, 'groups_can_post':...
# 1   {'count': 0, 'can_post': 1, 'groups_can_post':...
# 2   {'count': 0, 'can_post': 1, 'groups_can_post':...
# 3   {'count': 0, 'can_post': 1, 'groups_can_post':...
# 4   {'count': 0, 'can_post': 1, 'groups_can_post':...
# ..                                                ...
# 95  {'count': 1, 'can_post': 1, 'groups_can_post':...
# 96  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 97  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 98  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 99  {'count': 0, 'can_post': 1, 'groups_can_post':...
#
#                                                 likes  \
# 0   {'count': 12, 'user_likes': 0, 'can_like': 1, ...
# 1   {'count': 14, 'user_likes': 0, 'can_like': 1, ...
# 2   {'count': 4, 'user_likes': 0, 'can_like': 1, '...
# 3   {'count': 9, 'user_likes': 0, 'can_like': 1, '...
# 4   {'count': 9, 'user_likes': 0, 'can_like': 1, '...
# ..                                                ...
# 95  {'count': 11, 'user_likes': 0, 'can_like': 1, ...
# 96  {'count': 3, 'user_likes': 0, 'can_like': 1, '...
# 97  {'count': 3, 'user_likes': 0, 'can_like': 1, '...
# 98  {'count': 1, 'user_likes': 0, 'can_like': 1, '...
# 99  {'count': 4, 'user_likes': 0, 'can_like': 1, '...
#
#                              reposts            views  is_favorite  \
# 0   {'count': 0, 'user_reposted': 0}  {'count': 6670}        False
# 1   {'count': 2, 'user_reposted': 0}  {'count': 3503}        False
# 2   {'count': 0, 'user_reposted': 0}  {'count': 2348}        False
# 3   {'count': 1, 'user_reposted': 0}  {'count': 5660}        False
# 4   {'count': 0, 'user_reposted': 0}  {'count': 2292}        False
# ..                               ...              ...          ...
# 95  {'count': 3, 'user_reposted': 0}  {'count': 8160}        False
# 96  {'count': 1, 'user_reposted': 0}  {'count': 7777}        False
# 97  {'count': 1, 'user_reposted': 0}  {'count': 6231}        False
# 98  {'count': 0, 'user_reposted': 0}  {'count': 5508}        False
# 99  {'count': 0, 'user_reposted': 0}  {'count': 5397}        False
#
#                                          copy_history  edited  signer_id  \
# 0                                                 NaN     NaN        NaN
# 1   [{'id': 400, 'owner_id': -130374393, 'from_id'...     NaN        NaN
# 2   [{'id': 95, 'owner_id': -185974612, 'from_id':...     NaN        NaN
# 3                                                 NaN     NaN        NaN
# 4                                                 NaN     NaN        NaN
# ..                                                ...     ...        ...
# 95  [{'id': 318, 'owner_id': -108877455, 'from_id'...     NaN        NaN
# 96  [{'id': 268, 'owner_id': -170789907, 'from_id'...     NaN        NaN
# 97  [{'id': 324, 'owner_id': -108877455, 'from_id'...     NaN        NaN
# 98                                                NaN     NaN        NaN
# 99                                                NaN     NaN        NaN
#
#     nlikes  nreposts  nviews
# 0       12         0    6670
# 1       14         2    3503
# 2        4         0    2348
# 3        9         1    5660
# 4        9         0    2292
# ..     ...       ...     ...
# 95      11         3    8160
# 96       3         1    7777
# 97       3         1    6231
# 98       1         0    5508
# 99       4         0    5397
#
# [100 rows x 20 columns]

# %%
# renew parameters and run

offset = '100'
PARAMETERS = "domain=" + group + '&' + 'count=' + count + 'offset=' + offset

# your code here
