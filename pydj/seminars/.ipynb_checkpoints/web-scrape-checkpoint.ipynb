# %% [markdown]
# ### Web-scraping
#
# Мы уже немного познакомились со структурой html-файлов, теперь попробуем выгрузить информацию из реальной страницы, а точнее, с реального сайта [nplus1.ru]().
#
# Наша задача: выгрузить недавние новости в датафрейм pandas, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, ничего особенного мы не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы page код html в виде текста.

# %%
from bs4 import BeautifulSoup  # не спрашивайте, почему BeautifulSoup

# %%
soup = BeautifulSoup(page.text)

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (*view-source* через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js bg-fixed" lang="" style="background-image:url(https://nplus1.ru/images/2020/03/06/c46b2174e1faa49509920b7877555fc6.jpg)">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <title>N+1: научные статьи, новости, открытия</title>
# <!-- for Google -->
# <meta content="N+1: научные статьи, новости, открытия" name="description"/>
# <meta content="" name="author"/>
# <meta content="" name="copyright"/>
# <!-- for Facebook -->
# <meta content="N+1: научные статьи, новости, открытия" property="og:title"/>
# <meta content="https://nplus1.ru/i/logo.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N+1: научные статьи, новости, открытия" property="og:description"/>
# <!-- for Twitter -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N+1: научные статьи, новости, открытия" name="twitter:title"/>
# <meta content="N+1: научные статьи, новости, открытия" name="twitter:description"/>
# <meta content="https://nplus1.ru/i/logo.png" name="twitter:image"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/css/main.min.css?v=1581699021" rel="stylesheet"/>
# <link href="/css/desktop.min.css?v=1452887696" rel="stylesheet"/>
# <link href="/css/tablet.min.css?v=1499281342" rel="stylesheet"/>
# <link href="/css/mobile.min.css?v=1567698280" rel="stylesheet"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
# <script src="/js/lib/adfox.asyn.code.ver3.js" type="text/javascript"> </script>
# <script src="/js/lib/adfox.asyn.code.scroll.js" type="text/javascript"> </script>
# <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script async="" id="__lxGc__rtr" src="//s.clickiocdn.com/t/195458/360.js" type="text/javascript"></script>
# <script async="" src="//s.luxupcdnc.com/t/common_402.js" type="text/javascript"></script>
# <!--  ad -->
# <script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# <!-- /ad -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body class="_main" style="background-image:url(https://nplus1.ru/images/2020/03/06/c46b2174e1faa49509920b7877555fc6.jpg)">
# <link href="//s.luxupcdnc.com/cp/all/cookies_policy.css" property="" rel="stylesheet"/>
# <script type="text/javascript">_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async="" src="//s.luxupcdnc.com/cp/all/cookies_policy.js" type="text/javascript"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
# <div id="viewport">
# <div id="shadow"></div>
# <div class="ad ad-top">
# <!-- bh1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: Верхняя перетяжка 100%-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15000335664353901"></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
# </script>
# </div>
# <header id="header-mobile">
# <div class="container">
# <a class="action-menu pull-left" href="#"><i class="icon icon-navicon"></i></a>
# <a class="link-logo" href="/"><img src="/i/logo-mobile.png"/></a>
# <a class="action-search pull-right" href="#"><i class="icon icon-search"></i></a>
# <form action="/search" class="form-search" method="get">
# <div class="control">
# <input name="q" placeholder="Найти" type="text" value=""/>
# </div>
# <a class="action-search-close" href="#">×</a>
# </form>
# </div>
# <nav class="nav-rubrics">
# <ul>
# <li>
# <a class="" href="/rubric/astronomy">Астрономия</a>
# </li>
# <li>
# <a class="" href="/rubric/physics">Физика</a>
# </li>
# <li>
# <a class="" href="/rubric/biology">Биология</a>
# </li>
# <li>
# <a class="" href="/rubric/robots-drones">Роботы и дроны</a>
# </li>
# <li>
# <a class="" href="/theme/explainatorium">Давайте разберемся</a>
# </li>
# <li>
# <a class="" href="/theme/bookshelf">Книжная полка</a>
# </li>
# <li>
# <a class="" href="/theme/Courses">Курсы</a>
# </li>
# <li>
# <a class="" href="/theme/coronavirus-history">Коронавирусные хроники</a>
# </li>
# </ul>
# </nav>
# </header>
# <div class="js-mediator-container" id="layout">
# <!-- header -->
# <header class="_middle" id="header">
# <div class="row">
# <div class="col col-logo">
# <a class="link-logo" href="/"></a>
# </div>
# <div class="col col-nav-main">
# <form action="/search" class="form-search" method="get">
# <div class="control">
# <input name="q" placeholder="Найти" type="text" value=""/>
# </div>
# <a class="action-search-close" href="#">×</a>
# </form>
# <nav class="nav-rubrics">
# <ul>
# <li>
# <a class="" href="/rubric/astronomy">Астрономия</a>
# </li>
# <li>
# <a class="" href="/rubric/physics">Физика</a>
# </li>
# <li>
# <a class="" href="/rubric/biology">Биология</a>
# </li>
# <li>
# <a class="" href="/rubric/robots-drones">Роботы и дроны</a>
# </li>
# <li>
# <a class="action-search" href="#"><i class="icon icon-search"></i></a>
# </li>
# </ul>
# </nav> <nav class="nav-themes">
# <ul>
# <li data-name="explainatorium">
# <a class="" href="/theme/explainatorium">Давайте разберемся</a>
# </li>
# <li data-name="bookshelf">
# <a class="" href="/theme/bookshelf">Книжная полка</a>
# </li>
# <li data-name="Courses">
# <a class="" href="/theme/Courses">Курсы</a>
# </li>
# <li data-name="coronavirus-history">
# <a class="" href="/theme/coronavirus-history">Коронавирусные хроники</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="container line-up">
# <div class="line line-second">
# <a class="action-line-toggle" href="https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus">
# <div class="heading"><span></span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Антон Нелихов «Изобретатель парейазавров»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/27/diamond-princess">
# <div class="heading"><span>Давайте разберемся</span></div>
# <div class="link"><span>Погода была прекрасная, «Принцесса» была ужасная</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/26/discoveries-that-changed-medicine">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Ольга Шестова, Лев Иноземцев «30 Нобелевских премий: Открытия, изменившие медицину»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/20/epic-first-mission-to-pluto">
# <div class="heading"><span>New Horizons</span></div>
# <div class="link"><span>Алан Стерн, Дэвид Гринспун «За новыми горизонтами. Первый полет к Плутону»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/17/3comma5-six/">
# <div class="heading"><span>Три с половиной</span></div>
# <div class="link"><span>Домашние роботы, аборты и одомашнивание волков</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/17/hanky-panky-one">
# <div class="heading"><span>Математика и жизнь</span></div>
# <div class="link"><span>Иншуры-муры</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/14/essential">
# <div class="heading"><span>Давайте разберемся</span></div>
# <div class="link"><span>Короткая жизнь одной смелой компании</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/13/age-of-conquests">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Ангелос Ханиотис «Эпоха завоеваний: Греческий мир от Александра до Адриана»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/11/the-life-and-times-of-black-holes">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Крис Импи «Чудовища доктора Эйнштейна: О черных дырах, больших и малых»</span></div>
# </a>
# <a class="container-link active" href="https://nplus1.ru/blog/2020/03/06/death-from-the-skies">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Филип Плейт «Смерть с небес. Наука о конце света»</span></div>
# </a>
# </div>
# </div>
# </header> <!-- /header -->
# <!--  hero -->
# <!-- /hero -->
# <!-- main section -->
# <section id="main">
# <!--   dynamic content -->
# <div class="row" data-adaptive="1" data-middle-class="row-wrap _indent-bottom-no" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-2" data-adaptive="1" data-mobile-toggle="col-2 col-1">
# <article class="item item-main item-main- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/03/10/89538960ca35775d572c46607846317e.gif)">
# <a data-id="23954" href="/news/2020/03/10/hyenasfail">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">16:22</span>
# </div>
# <h3>Не оправдавшие ожидания матерей гиены прожили меньше</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 col-ad-prev" data-adaptive="1" data-middle-class="_swap col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23953" href="/news/2020/03/10/vulnerable-robots">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">16:13</span>
# </div>
# <h3>Выражающий эмоции робот помог людям наладить общение друг с другом</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23956" href="/news/2020/03/10/gabapentin">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">15:17</span>
# </div>
# <h3>Противоэпилептический препарат помог при алкоголизме</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23938" href="/news/2020/03/10/liquid-crystal-chaos">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">13:53</span>
# </div>
# <h3>Жидкий кристалл из бактериофагов показал динамический хаос активного вещества</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _tablet-hidden col-ad" data-adaptive="1" data-middle-class="col-1 _swap _indent-bottom" data-mobile-class="col-1 _indent-bottom">
# <div class="ad ad-col border">
# </div>
# </div>
# <div class="col col-1 col-ad-next" data-adaptive="1" data-middle-class="col-full _indent-bottom-no">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23955" href="/news/2020/03/10/soryu">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">11:57</span>
# </div>
# <h3>Японцы вооружились первой в мире подлодкой на литий-ионных аккумуляторах</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23951" href="/news/2020/03/10/dispatcher">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-10">09:39</span>
# </div>
# <h3>Британские ВВС обзаведутся виртуальной диспетчерской</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23949" href="/news/2020/03/09/names-for-Bennu">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-09">вчера</span>
# </div>
# <h3>Детали рельефа на астероиде Бенну назвали в честь мифологических птиц</h3>
# </div>
# </a>
# </article> </div>
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 8 -->
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/02/27/0407c013e7f8c52290d90df7bfc60a8e.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/02/27/02ce98479cbe373f74fbcb6809a31ec0.jpg)">
# <a data-id="23758" href="/material/2020/03/10/singingFDDs">
# <div class="caption">
# <h3>Мелодия для флопотрона без оркестра</h3>
# <p class="subtitle">Как заставить дисководы петь</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/partners">Партнерский материал</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/find-avito">Найдено на «Авито»</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/03/06/d1ed3119fb3e46c89d9130e67c65305a.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/03/06/68ce86d26a855eaf6451816779dc1939.jpg)">
# <a data-id="23924" href="/material/2020/03/06/how-to-detect-the-virus">
# <div class="caption">
# <h3>Корона в стоге сена</h3>
# <p class="subtitle">Почему мы не можем быстро выявить всех носителей 2019-nCoV</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/medicine">Медицина</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/coronavirus-history">Коронавирусные хроники</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 8 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23950" href="/news/2020/03/09/solar">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-09">вчера</span>
# </div>
# <h3>На Солнце появилось «радиопятно» нового цикла</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23843" href="/news/2020/03/09/IgEclass-switch">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-09">вчера</span>
# </div>
# <h3>Ученые нашли в кишечнике спусковой механизм аллергии на арахис</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23948" href="/news/2020/03/08/longest-microwave-quantum-link">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-08">08 марта</span>
# </div>
# <h3>Физики построили рекордно длинную микроволновую квантовую связь</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23947" href="/news/2020/03/07/waymo-the-fifth">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-07">07 марта</span>
# </div>
# <h3>Пятое поколение беспилотных автомобилей Waymo разглядит знак STOP за полкилометра</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23940" href="/news/2020/03/07/oldovan-acheulian">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-07">07 марта</span>
# </div>
# <h3>Человек прямоходящий сохранил старые орудия после появления новых</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23945" href="/news/2020/03/07/lend-a-robohand">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-07">07 марта</span>
# </div>
# <h3>Полноразмерный экзоскелет Guardian XO показали в разных сценариях</h3>
# </div>
# </a>
# </article> </div>
# <!--  fixed 15 -->
# <div class="col col-1" data-adaptive="1">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/02/12/42d1acfaba39319c4487fcd20f15ddb4.jpg)">
# <a data-id="23673" href="/blog/2020/03/06/death-from-the-skies">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/06/1ccc6e9960399e0551870d97fc98b306.jpg" width="90"/>
# <div class="meta">
# <p class="name">Альпина нон-фикшн</p>
# <p class="specs">Научно-популярное издательство</p>
# </div>
# </div> <div class="lead">
# <p>
#                     Существует предположение, что палеонтологическая летопись жизни на Земле свидетельствует о периодических эпизодах массового вымирания, как если бы жизнь следовала какому-то графику повальных вымираний, после которых разнообразие видов снова восстанавливалось.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 15 -->
# <!--  fixed 16 -->
# <div class="col col-1 _swap" data-adaptive="1" data-middle-swap="0">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/01/30/f2b044df0b71c9506755e717781109a6.jpg)">
# <a data-id="23545" href="/blog/2020/01/30/2019-nCoV">
# <div class="caption">
# <div class="heading">
# <p>Блоги/Коронавирусные хроники</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2019/02/28/1e485d334c715cf3faf08091573981a6.jpg" width="90"/>
# <div class="meta">
# <p class="name">Редакция выясняет</p>
# <p class="specs"> </p>
# </div>
# </div> <div class="lead">
# <p>
#                     Сейчас число погибших от коронавируса превысило три тысячи человек, а количество заболевших добралось до отметки в 100 тысяч. Работающая и проверенная вакцина до сих пор не разработана. Мы собрали все, что известно про SARS-CoV-2 на настоящее время — и будем добавлять новости по мере поступления.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 16 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 17 -->
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/03/03/efc79604d907381ca8f290cfb51a60bd.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/03/03/d66730d237028e20c70f20fed4e1eff7.gif)">
# <a data-id="23879" href="/material/2020/03/05/honourary-naming">
# <div class="caption">
# <h3>Твое имя для твари</h3>
# <p class="subtitle">Узнай, какое животное назовут в твою честь</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/mezzanine">Мезонин</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/02/28/4daf647dee5a7707b3520b3614d95101.gif" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/02/28/8d1c041abed3adf0cde9fbcf03bb23be.gif)">
# <a data-id="23830" href="/material/2020/03/03/facial-recognition">
# <div class="caption">
# <h3>Подозрительные лица</h3>
# <p class="subtitle">N+1 пытается обмануть FindFace</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/partners">Партнерский материал</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/experiments">Эксперименты</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 17 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23943" href="/news/2020/03/07/lettucefine">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-07">07 марта</span>
# </div>
# <h3>Выращенный на МКС салат не уступил в пользе земному</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23934" href="/news/2020/03/06/memoryreplay">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-06">06 марта</span>
# </div>
# <h3>При вспоминании нейроны возбудились в последовательности запоминания</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23936" href="/news/2020/03/06/caffeinated-creativity">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-06">06 марта</span>
# </div>
# <h3>Кофеин не прибавил креативности</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23942" href="/news/2020/03/06/benzene">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-06">06 марта</span>
# </div>
# <h3>Электронная структура бензола оказалась суперпозицией структур Кекуле</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23937" href="/news/2020/03/06/msc-vs-cov">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-06">06 марта</span>
# </div>
# <h3>Китайцы применили стволовые клетки против коронавирусной пневмонии</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="23935" href="/news/2020/03/06/tomahawk">
# <div class="caption">
# <div class="date">
# <span class="name" title="2020-03-06">06 марта</span>
# </div>
# <h3>Американцы вооружатся наземной версией Tomahawk</h3>
# </div>
# </a>
# </article> </div>
# <!--  fixed 24 -->
# <div class="col col-1">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/02/11/e3c801d4b6d42ade09c41291618cd4ec.jpg)">
# <a data-id="23618" href="/blog/2020/02/26/discoveries-that-changed-medicine">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/06/1ccc6e9960399e0551870d97fc98b306.jpg" width="90"/>
# <div class="meta">
# <p class="name">Альпина нон-фикшн</p>
# <p class="specs">Научно-популярное издательство</p>
# </div>
# </div> <div class="lead">
# <p>
#                     Первоначально ВИЧ возник у шимпанзе. Вероятно, вирус передался людям через кровь от обезьян, на которых велась охота. Расчеты кратности мутирования вируса показывают, что первая передача от обезьяны человеку произошла в Западной Африке около 1900 года.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 24 -->
# <!--  fixed 25 -->
# <div class="col col-1 _swap" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-middle-swap="0">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/03/04/cd8ed8b0e1004433a14a48c92c605379.jpg)">
# <a data-id="23898" href="/blog/2020/03/04/iventor-of-pareiasaurus">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2020/03/04/be49ded439325c15614b8968763a9d3a.jpg" width="90"/>
# <div class="meta">
# <p class="name">«Фитон XXI»</p>
# <p class="specs">Книжное издательство</p>
# </div>
# </div> <div class="lead">
# <p>
#                     По глыбам сложно понять, какая кость лежит внутри. Каменщики боялись испортить остатки парейазавров и долгими часами корпели над конкрециями. Надо было следить за малейшими изгибами костей, не сбивать бугорков, не оставлять неочищенными углубления.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 25 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 26 -->
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/03/02/5b2509f515929e73287e53c9cdf6074d.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/03/02/6e548087c97370ab6fb21ad25e4e6413.jpg)">
# <a data-id="23864" href="/material/2020/03/02/second-moon">
# <div class="caption">
# <h3>Временная луна</h3>
# <p class="subtitle">Откуда у Земли берутся квазиспутники и почему они не задерживаются надолго</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/astronomy">Астрономия</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2020/02/28/1840f8b45a8ba8547759e5062db8a954.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2020/02/28/9bb559665eaaf52dd001017dd320edb1.jpg)">
# <a data-id="23838" href="/news/2020/02/28/joker">
# <div class="caption">
# <h3>Ели мясо мужики</h3>
# <p class="subtitle">Легенды 90-х помогут тебе узнать, скоро ли ты умрешь</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/mezzanine">Мезонин</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 26 -->
# </div>
# <!-- / dynamic content -->
# </section>
# <!-- / main section -->
# <div id="wrapper-footer">
# <section class="_middle" id="difficult">
# <!-- Slider main container -->
# <div class="swiper-container">
# <!-- Additional required wrapper -->
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">7.4</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/10/liquid-crystal-chaos">Жидкий кристалл из бактериофагов показал динамический хаос активного вещества</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">7.1</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/06/benzene">Электронная структура бензола оказалась суперпозицией структур Кекуле</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">6.8</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/03/praseodymium-superhydrides">Супергидрид празеодима не стал высокотемпературным сверхпроводником</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">5.6</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/06/memoryreplay">При вспоминании нейроны возбудились в последовательности запоминания</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">5.3</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/material/2020/03/10/singingFDDs">Мелодия для флопотрона без оркестра</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">5.2</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/02/volcanoes">Воду в мантии назвали причиной вулканизма в Японии и на северо-востоке Китая</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">5.1</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/09/IgEclass-switch">Ученые нашли в кишечнике спусковой механизм аллергии на арахис</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">4.8</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/08/longest-microwave-quantum-link">Физики построили рекордно длинную микроволновую квантовую связь</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">4.8</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/05/honeywell-goes-quantum">Honeywell построит рекордно мощный квантовый компьютер</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">4.7</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2020/03/03/galactic-warp">Искривление Млечного Пути оказалось динамическим</a></h3>
# </div>
# </div>
# <!-- If we need pagination -->
# <div class="swiper-pagination"></div>
# <div class="swiper-button-prev"></div>
# <div class="swiper-button-next"></div>
# </div>
# <h6>Самое сложное</h6>
# </section>
# <div class="container">
# <div class="line">
# <a class="action-line-toggle" href="https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus">
# <div class="heading"><span></span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Антон Нелихов «Изобретатель парейазавров»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/27/diamond-princess">
# <div class="heading"><span>Давайте разберемся</span></div>
# <div class="link"><span>Погода была прекрасная, «Принцесса» была ужасная</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/26/discoveries-that-changed-medicine">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Ольга Шестова, Лев Иноземцев «30 Нобелевских премий: Открытия, изменившие медицину»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/20/epic-first-mission-to-pluto">
# <div class="heading"><span>New Horizons</span></div>
# <div class="link"><span>Алан Стерн, Дэвид Гринспун «За новыми горизонтами. Первый полет к Плутону»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/17/3comma5-six/">
# <div class="heading"><span>Три с половиной</span></div>
# <div class="link"><span>Домашние роботы, аборты и одомашнивание волков</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/17/hanky-panky-one">
# <div class="heading"><span>Математика и жизнь</span></div>
# <div class="link"><span>Иншуры-муры</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/14/essential">
# <div class="heading"><span>Давайте разберемся</span></div>
# <div class="link"><span>Короткая жизнь одной смелой компании</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/13/age-of-conquests">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Ангелос Ханиотис «Эпоха завоеваний: Греческий мир от Александра до Адриана»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2020/02/11/the-life-and-times-of-black-holes">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Крис Импи «Чудовища доктора Эйнштейна: О черных дырах, больших и малых»</span></div>
# </a>
# <a class="container-link active" href="https://nplus1.ru/blog/2020/03/06/death-from-the-skies">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Филип Плейт «Смерть с небес. Наука о конце света»</span></div>
# </a>
# </div>
# </div>
# <script async="" src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "main",
#     page_language: "ru"
# });
# </script>
# <div class="ad ad-col border">
# </div>
# <!-- footer -->
# <footer id="footer">
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-logo">
# <a class="link-logo" href="/"><img src="/i/logo-alt.png"/></a>
# </div>
# <div class="col col-footer-desc">
# <nav class="nav-pages">
# <ul>
# <li>
# <a href="/about">О нас</a>
# </li>
# <li>
# <a href="/adv">Рекламодателям</a>
# </li>
# <li>
# <a href="/rules">Наши материалы</a>
# </li>
# <li>
# <a href="/vacancy">Вакансии</a>
# </li>
# <li>
# <a href="/difficult">Сложность</a>
# </li>
# </ul>
# </nav>
# <div class="desc">
# <p>© 2020 N+1 Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
# <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
# <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
# <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
# <p>
# <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
# </p>
# <p>
# <script async="" src="//s.luxupcdnc.com/t/consent_195458.js" type="text/javascript"></script>
# <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
# </p>
# <p>
# </p>
# </div>
# </div>
# <div class="col col-1 pull-right">
# <nav class="nav-social">
# <ul>
# <li>
# <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
# </li>
# <li>
# <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
# </li>
# <li>
# <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
# </li>
# <li>
# <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
# </li>
# <li>
# <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
# </li>
# <li>
# <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
# </li>
# <li>
# <a href="/rss"><i class="fa fa-rss"></i></a>
# </li>
# </ul>
# </nav>
# <div class="partners">
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# </div>
# </div>
# </div>
# </footer> <!-- / footer -->
# </div>
# </div>
# </div>
# <noscript><div><img alt="" src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/></div></noscript>
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1580993830"></script>
# <!-- / project scripts -->
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" width="1"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно. «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).
#
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Посмотрим на кусочки кода, соответствующие всем ссылкам на главной странице сайта:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# /
# #
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# /theme/explainatorium
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# /
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# #
# /theme/explainatorium
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus
# https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus
# https://nplus1.ru/blog/2020/02/27/diamond-princess
# https://nplus1.ru/blog/2020/02/26/discoveries-that-changed-medicine
# https://nplus1.ru/blog/2020/02/20/epic-first-mission-to-pluto
# https://nplus1.ru/blog/2020/02/17/3comma5-six/
# https://nplus1.ru/blog/2020/02/17/hanky-panky-one
# https://nplus1.ru/blog/2020/02/14/essential
# https://nplus1.ru/blog/2020/02/13/age-of-conquests
# https://nplus1.ru/blog/2020/02/11/the-life-and-times-of-black-holes
# https://nplus1.ru/blog/2020/03/06/death-from-the-skies
# /news/2020/03/10/hyenasfail
# /news/2020/03/10/vulnerable-robots
# /news/2020/03/10/gabapentin
# /news/2020/03/10/liquid-crystal-chaos
# /news/2020/03/10/soryu
# /news/2020/03/10/dispatcher
# /news/2020/03/09/names-for-Bennu
# /material/2020/03/10/singingFDDs
# /rubric/partners
# /theme/find-avito
# /material/2020/03/06/how-to-detect-the-virus
# /rubric/medicine
# /theme/coronavirus-history
# /news/2020/03/09/solar
# /news/2020/03/09/IgEclass-switch
# /news/2020/03/08/longest-microwave-quantum-link
# /news/2020/03/07/waymo-the-fifth
# /news/2020/03/07/oldovan-acheulian
# /news/2020/03/07/lend-a-robohand
# /blog/2020/03/06/death-from-the-skies
# /blog/2020/01/30/2019-nCoV
# /material/2020/03/05/honourary-naming
# /rubric/mezzanine
# /material/2020/03/03/facial-recognition
# /rubric/partners
# /theme/experiments
# /news/2020/03/07/lettucefine
# /news/2020/03/06/memoryreplay
# /news/2020/03/06/caffeinated-creativity
# /news/2020/03/06/benzene
# /news/2020/03/06/msc-vs-cov
# /news/2020/03/06/tomahawk
# /blog/2020/02/26/discoveries-that-changed-medicine
# /blog/2020/03/04/iventor-of-pareiasaurus
# /material/2020/03/02/second-moon
# /rubric/astronomy
# /news/2020/02/28/joker
# /rubric/mezzanine
# /news/2020/03/10/liquid-crystal-chaos
# /news/2020/03/06/benzene
# /news/2020/03/03/praseodymium-superhydrides
# /news/2020/03/06/memoryreplay
# /material/2020/03/10/singingFDDs
# /news/2020/03/02/volcanoes
# /news/2020/03/09/IgEclass-switch
# /news/2020/03/08/longest-microwave-quantum-link
# /news/2020/03/05/honeywell-goes-quantum
# /news/2020/03/03/galactic-warp
# https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus
# https://nplus1.ru/blog/2020/03/04/iventor-of-pareiasaurus
# https://nplus1.ru/blog/2020/02/27/diamond-princess
# https://nplus1.ru/blog/2020/02/26/discoveries-that-changed-medicine
# https://nplus1.ru/blog/2020/02/20/epic-first-mission-to-pluto
# https://nplus1.ru/blog/2020/02/17/3comma5-six/
# https://nplus1.ru/blog/2020/02/17/hanky-panky-one
# https://nplus1.ru/blog/2020/02/14/essential
# https://nplus1.ru/blog/2020/02/13/age-of-conquests
# https://nplus1.ru/blog/2020/02/11/the-life-and-times-of-black-holes
# https://nplus1.ru/blog/2020/03/06/death-from-the-skies
# /
# /about
# /adv
# /rules
# /vacancy
# /difficult
# https://nplus1.ru/personal-data-policy
# #
# https://t.me/nplusone
# http://vk.com/nplusone
# https://www.facebook.com/nplusone
# https://twitter.com/nplusodin
# https://ok.ru/nplus1
# https://soundcloud.com/nplus_1
# /rss

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
    if '/news' in link.get('href'):
        urls.append(link.get('href'))
urls
# Out:
# ['/news/2020/03/10/hyenasfail',
#  '/news/2020/03/10/vulnerable-robots',
#  '/news/2020/03/10/gabapentin',
#  '/news/2020/03/10/liquid-crystal-chaos',
#  '/news/2020/03/10/soryu',
#  '/news/2020/03/10/dispatcher',
#  '/news/2020/03/09/names-for-Bennu',
#  '/news/2020/03/09/solar',
#  '/news/2020/03/09/IgEclass-switch',
#  '/news/2020/03/08/longest-microwave-quantum-link',
#  '/news/2020/03/07/waymo-the-fifth',
#  '/news/2020/03/07/oldovan-acheulian',
#  '/news/2020/03/07/lend-a-robohand',
#  '/news/2020/03/07/lettucefine',
#  '/news/2020/03/06/memoryreplay',
#  '/news/2020/03/06/caffeinated-creativity',
#  '/news/2020/03/06/benzene',
#  '/news/2020/03/06/msc-vs-cov',
#  '/news/2020/03/06/tomahawk',
#  '/news/2020/02/28/joker',
#  '/news/2020/03/10/liquid-crystal-chaos',
#  '/news/2020/03/06/benzene',
#  '/news/2020/03/03/praseodymium-superhydrides',
#  '/news/2020/03/06/memoryreplay',
#  '/news/2020/03/02/volcanoes',
#  '/news/2020/03/09/IgEclass-switch',
#  '/news/2020/03/08/longest-microwave-quantum-link',
#  '/news/2020/03/05/honeywell-goes-quantum',
#  '/news/2020/03/03/galactic-warp']

# %% [markdown]
# Ссылки, которые у нас есть в списке `urls`, относительные: они неполные, начало ссылки (название сайта) отсутствует. Давайте превратим их в абсолютные – склеим с ссылкой https://nplus1.ru.

# %%
full_urls = ['https://nplus1.ru' + u for u in urls]
full_urls
# Out:
# ['https://nplus1.ru/news/2020/03/10/hyenasfail',
#  'https://nplus1.ru/news/2020/03/10/vulnerable-robots',
#  'https://nplus1.ru/news/2020/03/10/gabapentin',
#  'https://nplus1.ru/news/2020/03/10/liquid-crystal-chaos',
#  'https://nplus1.ru/news/2020/03/10/soryu',
#  'https://nplus1.ru/news/2020/03/10/dispatcher',
#  'https://nplus1.ru/news/2020/03/09/names-for-Bennu',
#  'https://nplus1.ru/news/2020/03/09/solar',
#  'https://nplus1.ru/news/2020/03/09/IgEclass-switch',
#  'https://nplus1.ru/news/2020/03/08/longest-microwave-quantum-link',
#  'https://nplus1.ru/news/2020/03/07/waymo-the-fifth',
#  'https://nplus1.ru/news/2020/03/07/oldovan-acheulian',
#  'https://nplus1.ru/news/2020/03/07/lend-a-robohand',
#  'https://nplus1.ru/news/2020/03/07/lettucefine',
#  'https://nplus1.ru/news/2020/03/06/memoryreplay',
#  'https://nplus1.ru/news/2020/03/06/caffeinated-creativity',
#  'https://nplus1.ru/news/2020/03/06/benzene',
#  'https://nplus1.ru/news/2020/03/06/msc-vs-cov',
#  'https://nplus1.ru/news/2020/03/06/tomahawk',
#  'https://nplus1.ru/news/2020/02/28/joker',
#  'https://nplus1.ru/news/2020/03/10/liquid-crystal-chaos',
#  'https://nplus1.ru/news/2020/03/06/benzene',
#  'https://nplus1.ru/news/2020/03/03/praseodymium-superhydrides',
#  'https://nplus1.ru/news/2020/03/06/memoryreplay',
#  'https://nplus1.ru/news/2020/03/02/volcanoes',
#  'https://nplus1.ru/news/2020/03/09/IgEclass-switch',
#  'https://nplus1.ru/news/2020/03/08/longest-microwave-quantum-link',
#  'https://nplus1.ru/news/2020/03/05/honeywell-goes-quantum',
#  'https://nplus1.ru/news/2020/03/03/galactic-warp']

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = full_urls[1]
page0 = requests.get(url0)
soup0 = BeautifulSoup(page0.text, 'lxml')

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="yes" name="apple-mobile-web-app-capable"/>,
#  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>,
#  <meta content="2020-03-10" itemprop="datePublished"/>,
#  <meta content="Григорий Копиев" name="mediator_author"/>,
#  <meta content="Люди в группах с таким роботом говорят чаще и ведут себя позитивнее" name="description"/>,
#  <meta content="Григорий Копиев" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="Выражающий эмоции робот помог людям наладить общение друг с другом" property="og:title"/>,
#  <meta content="https://nplus1.ru/images/2020/03/10/f926a47d919c9f0a10b0619a5497d931.jpg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2020/03/10/vulnerable-robots" property="og:url"/>,
#  <meta content="Люди в группах с таким роботом говорят чаще и ведут себя позитивнее" property="og:description"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Выражающий эмоции робот помог людям наладить общение друг с другом" name="twitter:title"/>,
#  <meta content="Люди в группах с таким роботом говорят чаще и ведут себя позитивнее" name="twitter:description"/>,
#  <meta content="https://nplus1.ru/images/2020/03/10/f926a47d919c9f0a10b0619a5497d931.jpg" name="twitter:image"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>]

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим методу `findAll()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.findAll('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Григорий Копиев" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.findAll('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Григорий Копиев" name="author"/>

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь этот объект внутри похож на словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.findAll('meta', 
                        {'name' : 'author'})[0]['content']
author
# Out:
# 'Григорий Копиев'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.findAll('meta', 
                      {'itemprop' : 'datePublished'})[0]['content']
title = soup0.findAll('meta', 
                       {'property' : 'og:title'})[0]['content']
description = soup0.findAll('meta', 
                             {'name' : 'description'})[0]['content']

# %% [markdown]
# Осталось вытащить рубрики и сложность текста. Если мы посмотрим на исходный код страницы, мы увидим, что нужная нам информация находится в тэгах `<p></p>`:

# %%
soup0.findAll('p')
# Out:
# [<p class="table">
#  <a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>
#  <a data-rubric="psychology" href="/rubric/psychology">Психология</a>
#  </p>, <p class="table">
#  <a href="/news/2020/03/10">
#  <time content="2020-03-10" data-unix="1583845982" itemprop="datePublished">
#  <span>16:13</span>
#  <span>10 Март 2020</span>
#  </time>
#  </a>
#  </p>, <p class="table">
#  <a href="/difficult/3.2">
#  <span>Сложность</span>
#  <span class="difficult-value">3.2</span>
#  </a>
#  </p>, <p class="title"></p>, <p class="credits">Margaret Traeger et al. / PNAS, 2020</p>, <p>Американские исследователи проверили, как поведение робота в группе с людьми влияет на их общее взаимодействие при выполнении задач. Выяснилось, что в группах с роботами, признающими свои ошибки и выражающих эмоции, взаимодействие налаживается на более высоком уровне, чем в случае с молчаливыми или нейтральными роботами. Статья <a href="https://www.pnas.org/content/early/2020/03/03/1910402117" rel="nofollow" target="_blank" title="Link: https://www.pnas.org/content/early/2020/03/03/1910402117">опубликована</a> в журнале <i>Proceedings of the National Academy of Sciences</i>.</p>, <p>Важную часть исследований в области робототехники составляет не разработка новых технологий, а изучение особенностей <a href="https://en.wikipedia.org/wiki/Human%E2%80%93robot_interaction" rel="nofollow" target="_blank" title="Link: https://en.wikipedia.org/wiki/Human%E2%80%93robot_interaction">взаимодействия людей с роботами</a>. Эти исследования зачастую приводят к контринтуитивным результатам, таким как эффект «зловещей долины», или выясняется, к примеру, что люди <a href="https://nplus1.ru/news/2017/08/07/faulty-robots" target="_blank">предпочитают</a> роботов, совершающих ошибки. Кроме того, исследования также <a href="https://nplus1.ru/news/2019/12/18/roboexplanation" target="_blank" title="Link: https://nplus1.ru/news/2019/12/18/roboexplanation">показывают</a>, что доверие к роботам и их привлекательность коррелируют с тем, как они объясняют свои действия и объясняют ли вообще.<br/></p>, <p>Группа ученых из Йельского университета во главе с Николасом Христакисом (Nicholas Christakis) соединила два типа исследований и проверила, как ошибки и объяснения влияют на взаимодействие в группе, состоящей из людей и робота. Фактически цель исследования заключалась в том, чтобы проверить, может ли различие в поведении робота повлиять не только на взаимодействие типа робот-человек, но и на взаимодействие типа человек-человек.</p>, <p><iframe allowfullscreen="true" class="embed-responsive-item" frameborder="0" height="349" src="//www.youtube.com/embed/WujARg_xqfE" width="620"></iframe><br/></p>, <p>Всего в исследовании участвовало 153 добровольца, которые вместе с небольшим человекоподобным роботом NAO по очереди образовывали 51 группу из четырех участников. Во время эксперимента группа из трех людей и робота сидела за столом с четырех сторон, а перед ними лежали планшеты с игрой. В ней участникам каждый раунд предлагался набор из различных отрезков рельсов, и за 40 секунд было необходимо построить оптимальный железнодорожный путь между двумя точками. Всего в игре было 30 раундов, после которых добровольцы заполняли опросник, а затем им объясняли гипотезу исследования и другие подробности, которые могли бы повлиять на результат, если бы они были известны заранее.</p>, <p></p>, <p class="title">Схема поведения робота и пример интерфейса игры</p>, <p class="credits">Margaret Traeger et al. / PNAS, 2020</p>, <p>Исследователи выбрали необычную схему эксперимента, в которой все исходы фактически были предопределены для того, чтобы ключевую метрику (длительность разговоров) было легче сравнивать. Отчасти это было сделано путем намеренных ошибок робота в определенных раундах, а отчасти благодаря намеренным багам в игре, не дающим пользователям правильно расположить один из отрезков рельсов в некоторых раундах. Если в раунде ошибался хотя бы один участник, вся команда проигрывала.</p>, <p>После эксперимента все участники заполняли <a href="https://en.wikipedia.org/wiki/Eysenck_Personality_Questionnaire" rel="nofollow" target="_blank" title="Link: https://en.wikipedia.org/wiki/Eysenck_Personality_Questionnaire">личностный опросник Айзека</a>, на основе которого рассчитывали степень открытости по отношению к другим участникам команды. Кроме того, исследователи записывали время разговоров, причем отдельно для каждого участника, чтобы узнать равномерность его распределения. ...
#                          Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                          только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                          и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>, <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>, <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>, <p>
#  <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
#  </p>, <p>
#  <script async="" src="//s.luxupcdnc.com/t/consent_195458.js" type="text/javascript"></script>
#  <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#  </p>, <p>
#  </p>]

# %% [markdown]
# Выберем из полученного списка первый элемент и найдем в нем все тэги `<a>`:

# %%
soup0.findAll('p')[0].findAll('a')
# Out:
# [<a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>,
#  <a data-rubric="psychology" href="/rubric/psychology">Психология</a>]

# %% [markdown]
# Получился список из одного элемента. Применим списковые включения – вытащим из каждого элемента (их могло бы быть больше) текст и поместим его в новый список `rubrics`.

# %%
rubrics = [r.text for r in soup0.findAll('p')[0].findAll('a')]
rubrics
# Out:
# ['Роботы и дроны', 'Психология']

# %%
soup0.findAll('span', {'class' : 'difficult-value'})
# Out:
# [<span class="difficult-value">3.2</span>]

# %% [markdown]
# И выберем оттуда текст.

# %%
diff = soup0.findAll('span', 
                      {'class' : 'difficult-value'})[0].text
diff
# Out:
# '3.2'

# %% [markdown]
# Теперь перейдем к тексту самой новости. Как можно заметить, текст сохранен в абзацах `<p></p>`, причем безо всяких атрибутов. Сообщим Python, что нас интересуют куски с пустым атрибутом `class`:

# %%
text_list = soup0.findAll('p', {'class' : None})

# %% [markdown]
# «Выцепим» все тексты (без тэгов) из полученного списка:

# %%
text = [t.text for t in text_list]

# %% [markdown]
# Склеим все элементы списка `text` через пробел:

# %%
final_text = ' '.join(text)
final_text
# Out:
# 'Американские исследователи проверили, как поведение робота в\xa0группе с\xa0людьми влияет на\xa0их\xa0общее взаимодействие при выполнении задач. Выяснилось, что в\xa0группах с\xa0роботами, признающими свои ошибки и выражающих эмоции, взаимодействие налаживается на\xa0более высоком уровне, чем в\xa0случае с\xa0молчаливыми или нейтральными роботами. Статья опубликована в\xa0журнале Proceedings of\xa0the National Academy of\xa0Sciences. Важную часть исследований в\xa0области робототехники составляет не\xa0разработка новых технологий, а\xa0изучение особенностей взаимодействия людей с\xa0роботами. Эти исследования зачастую приводят к\xa0контринтуитивным результатам, таким как эффект «зловещей долины», или выясняется, к примеру, что люди предпочитают роботов, совершающих ошибки. Кроме того, исследования также показывают, что доверие к\xa0роботам и\xa0их\xa0привлекательность коррелируют с\xa0тем, как они объясняют свои действия и\xa0объясняют\xa0ли вообще. Группа ученых из\xa0Йельского университета во\xa0главе с\xa0Николасом Христакисом (Nicholas Christakis) соединила два типа исследований и\xa0проверила, как ошибки и\xa0объяснения влияют на\xa0взаимодействие в\xa0группе, состоящей из\xa0людей и\xa0робота. Фактически цель исследования заключалась в\xa0том, чтобы проверить, может\xa0ли различие в\xa0поведении робота повлиять не\xa0только на\xa0взаимодействие типа робот-человек, но\xa0и\xa0на\xa0взаимодействие типа человек-человек.  Всего в\xa0исследовании участвовало 153\xa0добровольца, которые вместе с\xa0небольшим человекоподобным роботом NAO по\xa0очереди образовывали 51\xa0группу из\xa0четырех участников. Во\xa0время эксперимента группа из\xa0трех людей и\xa0робота сидела за\xa0столом с\xa0четырех сторон, а\xa0перед ними лежали планшеты с\xa0игрой. В\xa0ней участникам каждый раунд предлагался набор из\xa0различных отрезков рельсов, и\xa0за\xa040\xa0секунд было необходимо построить оптимальный железнодорожный путь между двумя точками. Всего в\xa0игре было 30\xa0раундов, после которых добровольцы заполняли опросник, а\xa0затем им\xa0объясняли гипотезу исследования и\xa0другие подробности, которые могли\xa0бы повлиять на\xa0результат, если\xa0бы они были известны заранее.  Исследователи выбрали необычную схему эксперимента, в\xa0которой все исходы фактически были предопределены для того, чтобы ключевую метрику (длительность разговоров) было легче сравнивать. Отчасти это было сделано путем намеренных ошибок робота в\xa0определенных раундах, а\xa0отчасти благодаря намеренным багам в\xa0игре, не\xa0дающим пользователям правильно расположить один из\xa0отрезков рельсов в\xa0некоторых раундах. Если в\xa0раунде ошибался хотя\xa0бы один участник, вся команда проигрывала. После эксперимента все участники заполняли личностный опросник Айзека, на\xa0основе которого рассчитывали степень открытости по\xa0отношению к\xa0другим участникам команды. Кроме того, исследователи записывали время разговоров, причем отдельно для каждого участника, чтобы узнать равномерность его распределения. Результаты экспериментов показали, что в\xa0группах, в\xa0которых робот выражал свои эмоции, участники в\xa0среднем говорили в\xa0два раза дольше, чем в\xa0других. Кроме того, оказалось, что в\xa0группах с\xa0роботом, не\xa0говорящим после каждого раунда, равномерность распределения разговора между частниками была ниже. Анализ опросников показал, что участники посчитали группы с\xa0эмоциональным роботом более активными, позитивными и\xa0веселыми. На восприятие робота людьми также влияет и его внешний вид. В 2018 году американские ученые провели большое исследование и выяснили, какие черты лица в роботах сильнее всего влияют на формирование доверия к ним и их привлекательность. Выяснилось, что отсутствие ключевых элементов лица, таких как рот или зрачки, сильнее всего повышает недоверие и негативное восприятие по отношению к роботу. Григорий Копиев Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter. Коэффициент сложности Коэффициент сложности Коэффициент сложност ...

# %% [markdown]
# Все здорово, только мешают отступы-переходы на новую строку `\n`. Заменим их на пробелы с помощью метода `.replace`:

# %%
final_text = final_text.replace('\n', ' ')

# %% [markdown]
# Не прошло и двух пар, как мы разобрались со всем :) Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить её в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Returns a tuple with url0, date, 
    author, description, title, 
    final_text, rubrics, diff.
    
    Parameters:
    
    url0 is a link to the news (string)
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'lxml')
    author = soup0.findAll('meta', 
                            {'name' : 'author'})[0]['content']
    date = soup0.findAll('meta', 
                          {'itemprop' : 'datePublished'})[0]['content']
    title = soup0.findAll('meta', 
                           {'property' : 'og:title'})[0]['content']
    description = soup0.findAll('meta', 
                                 {'name' : 'description'})[0]['content']
    rubrics = [r.text for r in soup0.findAll('p')[0].find_all('a')]
    diff = soup0.findAll('span', {'class' : 'difficult-value'})[0].text
    text_list = soup0.findAll('p', {'class' : None})
    text = [t.text for t in text_list]
    final_text = ' '.join(text)
    final_text = final_text.replace('\n', ' ')
    
    return url0, date, author, description, title, final_text, rubrics, diff
